# %% [markdown]
# # FTX.US API Python Tutorial

# %% [markdown]
# ## 1. Get imports

# %%
import datetime
import requests
import pandas as pd
from client import FtxClient
#from local_settings import ftx as settings

# %% [markdown]
# ## 2. Using the FTX Market API

# %% [markdown]
# > Using the Markets API is easy. The Markets API allows us to get all of the market data. We’ll be greeted with the following information when we make a request.

# %%
# GET /markets
api_url = 'https://ftx.us/api'
api = '/markets'
url = api_url+api
url

'https://ftx.us/api/markets'
# Out:
# 'https://ftx.us/api/markets'

# %% [markdown]
# > Now we’ll use requests to get the market response data.

# %%
markets = requests.get(url).json()
data = markets['result']
data
# Out:
# [{'name': 'AAVE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 78.91,
#   'bid': 78.87,
#   'ask': 78.94,
#   'price': 78.91,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.001644736842105263,
#   'change24h': 0.07141887304820095,
#   'changeBod': 0.036925098554533506,
#   'quoteVolume24h': 121603.718,
#   'volumeUsd24h': 121603.718,
#   'priceHigh24h': 79.34,
#   'priceLow24h': 72.66},
#  {'name': 'AAVE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 78.95,
#   'bid': 78.86,
#   'ask': 78.94,
#   'price': 78.94,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.0018965735238336073,
#   'change24h': 0.07284588203316118,
#   'changeBod': 0.037183024569701746,
#   'quoteVolume24h': 45723.3619,
#   'volumeUsd24h': 45718.78956381,
#   'priceHigh24h': 79.33,
#   'priceLow24h': 72.68},
#  {'name': 'ALGO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.368,
#   'bid': 0.3681,
#   'ask': 0.3689,
#   'price': 0.3681,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.01154672395273899,
#   'change24h': -0.001085481682496608,
#   'changeBod': 0.004639737991266376,
#   'quoteVolume24h': 236069.7768,
#   'volumeUsd24h': 236069.7768,
#   'priceHigh24h': 0.3764,
#   'priceLow24h': 0.3569},
#  {'name': 'ALGO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3739,
#   'bid': 0.368,
#   'ask': 0.3689,
#   'price': 0.3689,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.011786766675596035,
#   'change24h': 0.0038095238095238095,
#   'changeBod': 0.009026258205689279,
#   'quoteVolume24h': 13682.4933,
#   'volumeUsd24h': 13681.12505067,
#   'priceHigh24h': 0.3754,
#   'priceLow24h': 0.357},
#  {'name': 'AUD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.652,
#   'bid': 0.6473,
#   'ask': 0.6481,
#   'price': 0.6481,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AUD',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.001848144155244109,
#   'changeBod': 0.0018550007729169888,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 0.652,
#   'priceLow24h': 0.6437},
#  {'name': 'AVAX/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-07,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.0008978,
#   'bid': 0.000895,
#   'ask': 0.0008969,
#   'price': 0.0008969,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.00033437360677663843,
#   'change24h': -0.01731127424126219,
#   'changeBod': -0.01666483938164675,
#   'quoteVolume24h': 0.77483091,
#   'volumeUsd24h': 15484.903863540992,
#   'priceHigh24h': 0.0009153,
#   'priceLow24h': 0.0008893},
#  {'name': 'AVAX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 17.9385,
#   'bid': 17.907,
#   'ask': 17.911,
#   'price': 17.911,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.003948392837281726,
#   'change24h': 0.04498249708284714,
#   'changeBod': 0.022404886263093303,
#   'quoteVolume24h': 2510433.6932,
#   'volumeUsd24h': 2510433.6932,
#   'priceHigh24h': 18.0995,
#   'priceLow24h': 16.9775},
#  {'name': 'AVAX/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 18.09,
#   'bid': 17.888,
#   'ask': 17.9125,
#   'price': 17.9125,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.002561461146532283,
#   'change24h': 0.04592432558682705,
#   'changeBod': 0.021994636846009014,
#   'quoteVolume24h': 23319.8052,
#   'volumeUsd24h': 23317.47321948,
#   'priceHigh24h': 18.091,
#   'priceLow24h': 16.992},
#  {'name': 'BAT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.308725,
#   'bid': 0.307225,
#   'ask': 0.307425,
#   'price': 0.307425,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BAT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0027572784040223825,
#   'change24h': 0.041148082296164595,
#   'changeBod': 0.0263750938986729,
#   'quoteVolume24h': 11685.36135,
#   'volumeUsd24h': 11685.36135,
#   'priceHigh24h': 0.3088,
#   'priceLow24h': 0.2918},
#  {'name': 'BCH/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.005921,
#   'bid': 0.005928,
#   'ask': 0.005936,
#   'price': 0.005928,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 432.0,
#   'change1h': -0.00016866250632484398,
#   'change24h': -0.0219435736677116,
#   'changeBod': -0.0182179529645578,
#   'quoteVolume24h': 9.131289105,
#   'volumeUsd24h': 182487.73005341808,
#   'priceHigh24h': 0.006116,
#   'priceLow24h': 0.005882},
#  {'name': 'BCH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 118.55,
#   'bid': 118.425,
#   'ask': 118.45,
#   'price': 118.45,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 720.0,
#   'change1h': -0.004621848739495798,
#   'change24h': 0.03994732221246708,
#   'changeBod': 0.021781324131981885,
#   'quoteVolume24h': 1807932.395325,
#   'volumeUsd24h': 1807932.395325,
#   'priceHigh24h': 119.45,
#   'priceLow24h': 112.45},
#  {'name': 'BCH/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 118.625,
#   'bid': 118.45,
#   'ask': 118.475,
#   'price': 118.475,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 504.0,
#   'change1h': -0.004411764705882353,
#   'change24h': 0.039938556067588324,
#   'changeBod': 0.022217428817946507,
#   'quoteVolume24h': 301792.642475,
#   'volumeUsd24h': 301762.4632107525,
#   'priceHigh24h': 119.425,
#   'priceLow24h': 112.475},
#  {'name': 'BRZ/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.18773,
#   'bid': 0.18609,
#   'ask': 0.18644,
#   'price': 0.18644,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BRZ',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.001396498012675905,
#   'change24h': -0.021158187641098336,
#   'changeBod': -0.00405982905982906,
#   'quoteVolume24h': 156.6771,
#   'volumeUsd24h': 156.6771,
#   'priceHigh24h': 0.1905,
#   'priceLow24h': 0.18609},
#  {'name': 'BRZ/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.17802,
#   'bid': 0.1856,
#   'ask': 0.18629,
#   'price': 0.1856,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BRZ',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.00032338040314756927,
#   'change24h': -0.023620390341417222,
#   'changeBod': -0.0074866310160427805,
#   'quoteVolume24h': 0.8901,
#   'volumeUsd24h': 0.89001099,
#   'priceHigh24h': 0.19039,
#   'priceLow24h': 0.17802},
#  {'name': 'BTC/AUD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 29566.0,
#   'bid': 30767.0,
#   'ask': 30974.0,
#   'price': 30767.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'AUD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': -0.0033365727243278263,
#   'change24h': 0.06060188217449757,
#   'changeBod': 0.04062098356219982,
#   'quoteVolume24h': 14.6905,
#   'volumeUsd24h': 9.519444,
#   'priceHigh24h': 31340.0,
#   'priceLow24h': 28855.0},
#  {'name': 'BTC/BRZ',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 108050.0,
#   'bid': 107105.0,
#   'ask': 107540.0,
#   'price': 107540.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'BRZ',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': -0.0042592592592592595,
#   'change24h': 0.09089064719009941,
#   'changeBod': 0.05271401301943126,
#   'quoteVolume24h': 4165.778,
#   'volumeUsd24h': 775.58454804,
#   'priceHigh24h': 108725.0,
#   'priceLow24h': 98355.0},
#  {'name': 'BTC/EUR',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 19727.0,
#   'bid': 20704.0,
#   'ask': 20765.0,
#   'price': 20704.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'EUR',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.002457239219465189,
#   'change24h': 0.06212486533627456,
#   'changeBod': 0.04202526548895264,
#   'quoteVolume24h': 720958.2389,
#   'volumeUsd24h': 694282.7840607,
#   'priceHigh24h': 21025.0,
#   'priceLow24h': 19371.0},
#  {'name': 'BTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 19972.0,
#   'bid': 19986.0,
#   'ask': 19987.0,
#   'price': 19986.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': -0.003042849304135282,
#   'change24h': 0.06342449717995105,
#   'changeBod': 0.04131714687646538,
#   'quoteVolume24h': 89064267.5238,
#   'volumeUsd24h': 89064267.5238,
#   'priceHigh24h': 20292.0,
#   'priceLow24h': 18687.0},
#  {'name': 'BTC/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 19971.0,
#   'bid': 19986.0,
#   'ask': 19989.0,
#   'price': 19986.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.00299311583358276,
#   'change24h': 0.06348108338211036,
#   'changeBod': 0.04126289465457956,
#   'quoteVolume24h': 4469192.2035,
#   'volumeUsd24h': 4468745.28427965,
#   'priceHigh24h': 20296.0,
#   'priceLow24h': 18687.0},
#  {'name': 'CAD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.7371,
#   'bid': 0.7306,
#   'ask': 0.7312,
#   'price': 0.7312,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CAD',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.0051700680272108845,
#   'changeBod': 0.001369487811558477,
#   'quoteVolume24h': 49.3857,
#   'volumeUsd24h': 49.3857,
#   'priceHigh24h': 0.738,
#   'priceLow24h': 0.7259},
#  {'name': 'CUSDT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0220075,
#   'bid': 0.022005,
#   'ask': 0.0220275,
#   'price': 0.0220075,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CUSDT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.0009079559641357395,
#   'changeBod': 0.0,
#   'quoteVolume24h': 125.54291,
#   'volumeUsd24h': 125.54291,
#   'priceHigh24h': 0.0220325,
#   'priceLow24h': 0.022005},
#  {'name': 'CUSDT/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.022035,
#   'bid': 0.022005,
#   'ask': 0.0220275,
#   'price': 0.0220275,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CUSDT',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': -0.00011348161597821153,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 0.022035,
#   'priceLow24h': 0.0220275},
#  {'name': 'DAI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.0,
#   'bid': 0.9991,
#   'ask': 1.0,
#   'price': 1.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DAI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0007004903432402681,
#   'quoteVolume24h': 1438.69092,
#   'volumeUsd24h': 1438.69092,
#   'priceHigh24h': 1.0,
#   'priceLow24h': 0.9992},
#  {'name': 'DAI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.9991,
#   'bid': 0.999,
#   'ask': 1.0001,
#   'price': 0.9991,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DAI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': -0.00040020010005002504,
#   'changeBod': -0.0010997800439912018,
#   'quoteVolume24h': 5005.502,
#   'volumeUsd24h': 5005.0014498,
#   'priceHigh24h': 1.0002,
#   'priceLow24h': 0.9991},
#  {'name': 'DOGE/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 3.12e-06,
#   'bid': 3.11e-06,
#   'ask': 3.12e-06,
#   'price': 3.12e-06,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.003215434083601286,
#   'change24h': -0.04,
#   'changeBod': -0.018867924528301886,
#   'quoteVolume24h': 5.08906136,
#   'volumeUsd24h': 101704.28786231719,
#   'priceHigh24h': 3.25e-06,
#   'priceLow24h': 3.09e-06},
#  {'name': 'DOGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.062273,
#   'bid': 0.062273,
#   'ask': 0.062279,
#   'price': 0.062273,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.002610673329489397,
#   'change24h': 0.01973210191917207,
#   'changeBod': 0.01986570586308549,
#   'quoteVolume24h': 2177382.811571,
#   'volumeUsd24h': 2177382.811571,
#   'priceHigh24h': 0.062799,
#   'priceLow24h': 0.0597665},
#  {'name': 'DOGE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.062438,
#   'bid': 0.0622395,
#   'ask': 0.0622645,
#   'price': 0.0622645,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.002666944306514392,
#   'change24h': 0.02006897173141982,
#   'changeBod': 0.0198016558704785,
#   'quoteVolume24h': 119420.9978895,
#   'volumeUsd24h': 119409.05578971106,
#   'priceHigh24h': 0.062794,
#   'priceLow24h': 0.0597795},
#  {'name': 'ETH/AUD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 2095.3,
#   'bid': 2120.2,
#   'ask': 2133.7,
#   'price': 2120.2,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'AUD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': -0.004834545881248533,
#   'change24h': 0.058617934891152385,
#   'changeBod': 0.03263198909020066,
#   'quoteVolume24h': 16.2839,
#   'volumeUsd24h': 10.5519672,
#   'priceHigh24h': 2442.2,
#   'priceLow24h': 1980.8},
#  {'name': 'ETH/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.0690475,
#   'bid': 0.068855,
#   'ask': 0.06894,
#   'price': 0.06894,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': -0.001050534323492121,
#   'change24h': 0.0009800718719372753,
#   'changeBod': -0.007700611730838431,
#   'quoteVolume24h': 4.7549454275,
#   'volumeUsd24h': 95027.02056790859,
#   'priceHigh24h': 0.0697475,
#   'priceLow24h': 0.0682575},
#  {'name': 'ETH/EUR',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1341.7,
#   'bid': 1422.4,
#   'ask': 1428.5,
#   'price': 1422.4,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'EUR',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.004966771598461,
#   'change24h': 0.060147573973317436,
#   'changeBod': 0.030948756976154235,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1440.8,
#   'priceLow24h': 1327.3},
#  {'name': 'ETH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1376.9,
#   'bid': 1376.9,
#   'ask': 1377.0,
#   'price': 1376.9,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': -0.0049143600491436,
#   'change24h': 0.0638182801514332,
#   'changeBod': 0.032855749756207336,
#   'quoteVolume24h': 91245906.9485,
#   'volumeUsd24h': 91245906.9485,
#   'priceHigh24h': 1392.1,
#   'priceLow24h': 1278.6},
#  {'name': 'ETH/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1377.0,
#   'bid': 1376.9,
#   'ask': 1377.1,
#   'price': 1377.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.004338394793926247,
#   'change24h': 0.06397774687065369,
#   'changeBod': 0.032775819395484886,
#   'quoteVolume24h': 1894883.924,
#   'volumeUsd24h': 1894694.4356076,
#   'priceHigh24h': 1389.7,
#   'priceLow24h': 1278.2},
#  {'name': 'ETHW/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 11.158,
#   'bid': 11.137,
#   'ask': 11.192,
#   'price': 11.158,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETHW',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.022599859845830413,
#   'change24h': 0.00035861574323112785,
#   'changeBod': 0.019740449643575214,
#   'quoteVolume24h': 1473822.741245,
#   'volumeUsd24h': 1473822.741245,
#   'priceHigh24h': 11.967,
#   'priceLow24h': 9.0},
#  {'name': 'EUR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.9633,
#   'bid': 0.9647,
#   'ask': 0.9653,
#   'price': 0.9647,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'EUR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.00041446482229820747,
#   'change24h': 0.00031107424305267526,
#   'changeBod': 0.0014533374857261497,
#   'quoteVolume24h': 488.6742,
#   'volumeUsd24h': 488.6742,
#   'priceHigh24h': 0.9706,
#   'priceLow24h': 0.9597},
#  {'name': 'GBP/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.0784,
#   'bid': 1.076,
#   'ask': 1.0778,
#   'price': 1.0778,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'GBP',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0003709886848451122,
#   'change24h': 0.020643939393939395,
#   'changeBod': 0.0023249325769552683,
#   'quoteVolume24h': 187841.3352,
#   'volumeUsd24h': 187841.3352,
#   'priceHigh24h': 1.0919,
#   'priceLow24h': 1.054},
#  {'name': 'GRT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1041,
#   'bid': 0.10405,
#   'ask': 0.10415,
#   'price': 0.1041,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'GRT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.006205250596658711,
#   'change24h': 0.0415207603801901,
#   'changeBod': 0.01709819247679531,
#   'quoteVolume24h': 261560.5513,
#   'volumeUsd24h': 261560.5513,
#   'priceHigh24h': 0.1053,
#   'priceLow24h': 0.09865},
#  {'name': 'KSHIB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.011059,
#   'bid': 0.011285,
#   'ask': 0.011318,
#   'price': 0.011285,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'KSHIB',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.006077153426105338,
#   'change24h': 0.0289960791465305,
#   'changeBod': 0.016849882861776896,
#   'quoteVolume24h': 847.09005,
#   'volumeUsd24h': 847.09005,
#   'priceHigh24h': 0.01151,
#   'priceLow24h': 0.010815},
#  {'name': 'LINK/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.00041195,
#   'bid': 0.00041315,
#   'ask': 0.00041365,
#   'price': 0.00041315,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.0059654248843438035,
#   'change24h': 0.024296516672864758,
#   'changeBod': 0.001090380421613763,
#   'quoteVolume24h': 7.90932744,
#   'volumeUsd24h': 158066.9710681351,
#   'priceHigh24h': 0.0004164,
#   'priceLow24h': 0.0003989},
#  {'name': 'LINK/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 8.258,
#   'bid': 8.259,
#   'ask': 8.2625,
#   'price': 8.259,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.003218949286365017,
#   'change24h': 0.08921859545004945,
#   'changeBod': 0.04392340264172407,
#   'quoteVolume24h': 1870349.0818,
#   'volumeUsd24h': 1870349.0818,
#   'priceHigh24h': 8.313,
#   'priceLow24h': 7.4665},
#  {'name': 'LINK/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 8.276,
#   'bid': 8.255,
#   'ask': 8.2625,
#   'price': 8.2625,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': 0.0037050534499514093,
#   'change24h': 0.0904711627293124,
#   'changeBod': 0.04462987546621152,
#   'quoteVolume24h': 275114.7212,
#   'volumeUsd24h': 275087.20972788,
#   'priceHigh24h': 8.3165,
#   'priceLow24h': 7.471},
#  {'name': 'LTC/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.0027375,
#   'bid': 0.002735,
#   'ask': 0.0027375,
#   'price': 0.0027375,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.00018261504747991235,
#   'change24h': -0.025367156208277702,
#   'changeBod': -0.015022038319690564,
#   'quoteVolume24h': 5.0532724025,
#   'volumeUsd24h': 100989.04979022755,
#   'priceHigh24h': 0.00281675,
#   'priceLow24h': 0.00272475},
#  {'name': 'LTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 54.67,
#   'bid': 54.69,
#   'ask': 54.705,
#   'price': 54.69,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.0049126637554585155,
#   'change24h': 0.03579545454545455,
#   'changeBod': 0.025405456079497516,
#   'quoteVolume24h': 900709.92235,
#   'volumeUsd24h': 900709.92235,
#   'priceHigh24h': 55.4,
#   'priceLow24h': 51.895},
#  {'name': 'LTC/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 54.665,
#   'bid': 54.675,
#   'ask': 54.69,
#   'price': 54.675,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.005004549590536852,
#   'change24h': 0.03551136363636364,
#   'changeBod': 0.02531645569620253,
#   'quoteVolume24h': 523964.25695,
#   'volumeUsd24h': 523911.860524305,
#   'priceHigh24h': 55.39,
#   'priceLow24h': 51.9},
#  {'name': 'MATIC/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 3.876e-05,
#   'bid': 3.871e-05,
#   'ask': 3.878e-05,
#   'price': 3.876e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MATIC',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.003342761635381846,
#   'change24h': -0.008695652173913044,
#   'changeBod': -0.012987012987012988,
#   'quoteVolume24h': 1.4952629,
#   'volumeUsd24h': 29882.65176103972,
#   'priceHigh24h': 3.966e-05,
#   'priceLow24h': 3.82e-05},
#  {'name': 'MATIC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.774205,
#   'bid': 0.774105,
#   'ask': 0.774344,
#   'price': 0.774205,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MATIC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.006903655397024322,
#   'change24h': 0.05410023554399771,
#   'changeBod': 0.026489407684168936,
#   'quoteVolume24h': 1559919.57039,
#   'volumeUsd24h': 1559919.57039,
#   'priceHigh24h': 0.782243,
#   'priceLow24h': 0.726466},
#  {'name': 'MKR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 754.0,
#   'bid': 752.5,
#   'ask': 753.0,
#   'price': 753.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MKR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.003968253968253968,
#   'change24h': 0.10735294117647058,
#   'changeBod': 0.0502092050209205,
#   'quoteVolume24h': 214645.345,
#   'volumeUsd24h': 214645.345,
#   'priceHigh24h': 758.0,
#   'priceLow24h': 674.0},
#  {'name': 'NEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.752,
#   'bid': 3.748,
#   'ask': 3.751,
#   'price': 3.751,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'NEAR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.012894736842105263,
#   'change24h': 0.03618784530386741,
#   'changeBod': 0.018739815317762087,
#   'quoteVolume24h': 115251.6349,
#   'volumeUsd24h': 115251.6349,
#   'priceHigh24h': 3.807,
#   'priceLow24h': 3.558},
#  {'name': 'NEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.749,
#   'bid': 3.745,
#   'ask': 3.75,
#   'price': 3.749,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'NEAR',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.012641559125625495,
#   'change24h': 0.03592152528322741,
#   'changeBod': 0.019026909486273443,
#   'quoteVolume24h': 7516.5415,
#   'volumeUsd24h': 7515.78984585,
#   'priceHigh24h': 3.805,
#   'priceLow24h': 3.559},
#  {'name': 'PAXG/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 1622.4,
#   'bid': 1620.7,
#   'ask': 1623.1,
#   'price': 1622.4,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'PAXG',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.003317360855141909,
#   'changeBod': 0.002285784889108544,
#   'quoteVolume24h': 53931.92619,
#   'volumeUsd24h': 53931.92619,
#   'priceHigh24h': 1641.0,
#   'priceLow24h': 1611.0},
#  {'name': 'PAXG/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 1619.0,
#   'bid': 1620.6,
#   'ask': 1623.5,
#   'price': 1620.6,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'PAXG',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -6.17017338187203e-05,
#   'change24h': -0.005827863321268634,
#   'changeBod': 0.0009882643607164916,
#   'quoteVolume24h': 649.72285,
#   'volumeUsd24h': 649.657877715,
#   'priceHigh24h': 1640.2,
#   'priceLow24h': 1613.2},
#  {'name': 'SHIB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 100000.0,
#   'minProvideSize': 100000.0,
#   'last': 1.13e-05,
#   'bid': 1.128e-05,
#   'ask': 1.13e-05,
#   'price': 1.13e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SHIB',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.008771929824561403,
#   'change24h': 0.03102189781021898,
#   'changeBod': 0.01618705035971223,
#   'quoteVolume24h': 36301.029,
#   'volumeUsd24h': 36301.029,
#   'priceHigh24h': 1.153e-05,
#   'priceLow24h': 1.078e-05},
#  {'name': 'SOL/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.00173075,
#   'bid': 0.0017285,
#   'ask': 0.00173025,
#   'price': 0.00173025,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.002450273854136639,
#   'change24h': 0.007276961141027507,
#   'changeBod': -0.016763744850120756,
#   'quoteVolume24h': 17.616709305,
#   'volumeUsd24h': 352067.8466220108,
#   'priceHigh24h': 0.00178225,
#   'priceLow24h': 0.001703},
#  {'name': 'SOL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 34.545,
#   'bid': 34.545,
#   'ask': 34.5525,
#   'price': 34.545,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.006970894717930291,
#   'change24h': 0.06950464396284829,
#   'changeBod': 0.02302509809728289,
#   'quoteVolume24h': 24237453.105725,
#   'volumeUsd24h': 24237453.105725,
#   'priceHigh24h': 35.005,
#   'priceLow24h': 31.8575},
#  {'name': 'SOL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 34.5675,
#   'bid': 34.5475,
#   'ask': 34.5575,
#   'price': 34.5575,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.006325929120839623,
#   'change24h': 0.07022297925054197,
#   'changeBod': 0.023395276523284225,
#   'quoteVolume24h': 1910189.61075,
#   'volumeUsd24h': 1909998.591788925,
#   'priceHigh24h': 35.015,
#   'priceLow24h': 31.8725},
#  {'name': 'SUSHI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 5.59e-05,
#   'bid': 5.609e-05,
#   'ask': 5.634e-05,
#   'price': 5.609e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 576.0,
#   'change1h': 0.01099495313626532,
#   'change24h': 0.03125574554145983,
#   'changeBod': 0.019447473645946928,
#   'quoteVolume24h': 6.254466995,
#   'volumeUsd24h': 124994.78129397951,
#   'priceHigh24h': 5.627e-05,
#   'priceLow24h': 5.414e-05},
#  {'name': 'SUSHI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 1.126,
#   'bid': 1.1215,
#   'ask': 1.1236,
#   'price': 1.1236,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.010886189833558255,
#   'change24h': 0.0987678466653628,
#   'changeBod': 0.062204575534127435,
#   'quoteVolume24h': 232805.9895,
#   'volumeUsd24h': 232805.9895,
#   'priceHigh24h': 1.129,
#   'priceLow24h': 1.0126},
#  {'name': 'SUSHI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 1.1248,
#   'bid': 1.1216,
#   'ask': 1.123,
#   'price': 1.123,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.009075388624314853,
#   'change24h': 0.09807372641048205,
#   'changeBod': 0.06083506518042698,
#   'quoteVolume24h': 90855.10115,
#   'volumeUsd24h': 90846.015639885,
#   'priceHigh24h': 1.1287,
#   'priceLow24h': 1.0124},
#  {'name': 'TRX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.060445,
#   'bid': 0.0603775,
#   'ask': 0.060395,
#   'price': 0.060395,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'TRX',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 720.0,
#   'change1h': 0.0003312629399585921,
#   'change24h': 0.019324894514767932,
#   'changeBod': 0.013381433784974202,
#   'quoteVolume24h': 31317.9293,
#   'volumeUsd24h': 31317.9293,
#   'priceHigh24h': 0.06061,
#   'priceLow24h': 0.0589825},
#  {'name': 'TRX/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0604575,
#   'bid': 0.0603775,
#   'ask': 0.0603975,
#   'price': 0.0603975,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'TRX',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 504.0,
#   'change1h': 0.0,
#   'change24h': 0.019711294951882494,
#   'changeBod': 0.013678512986195612,
#   'quoteVolume24h': 25837.2614325,
#   'volumeUsd24h': 25834.67770635675,
#   'priceHigh24h': 0.06061,
#   'priceLow24h': 0.058975},
#  {'name': 'UNI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 0.05,
#   'minProvideSize': 0.05,
#   'last': 0.00032085,
#   'bid': 0.0003207,
#   'ask': 0.000321,
#   'price': 0.00032085,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 168.0,
#   'change1h': 0.01422475106685633,
#   'change24h': 0.07182228161015533,
#   'changeBod': 0.04053834927841738,
#   'quoteVolume24h': 13.159425375,
#   'volumeUsd24h': 262989.55578749033,
#   'priceHigh24h': 0.00032435,
#   'priceLow24h': 0.0002967},
#  {'name': 'UNI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 6.411,
#   'bid': 6.41,
#   'ask': 6.413,
#   'price': 6.411,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.010720479268484944,
#   'change24h': 0.13973333333333332,
#   'changeBod': 0.08239068039844673,
#   'quoteVolume24h': 363782.5374,
#   'volumeUsd24h': 363782.5374,
#   'priceHigh24h': 6.45,
#   'priceLow24h': 5.555},
#  {'name': 'UNI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.05,
#   'minProvideSize': 0.05,
#   'last': 6.442,
#   'bid': 6.411,
#   'ask': 6.416,
#   'price': 6.416,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.012147026344849345,
#   'change24h': 0.1410279210385915,
#   'changeBod': 0.08396688629836122,
#   'quoteVolume24h': 146863.4197,
#   'volumeUsd24h': 146848.73335803,
#   'priceHigh24h': 6.452,
#   'priceLow24h': 5.557},
#  {'name': 'USDT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.9999,
#   'bid': 0.9998,
#   'ask': 0.9999,
#   'price': 0.9999,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'USDT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': 0.0,
#   'change24h': -0.0001,
#   'changeBod': 0.0,
#   'quoteVolume24h': 1261481.22628,
#   'volumeUsd24h': 1261481.22628,
#   'priceHigh24h': 1.0001,
#   'priceLow24h': 0.9998},
#  {'name': 'WBTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 20257.0,
#   'bid': 19981.0,
#   'ask': 19995.0,
#   'price': 19995.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'WBTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.003538323532343267,
#   'change24h': 0.0637335745065702,
#   'changeBod': 0.04167752018754884,
#   'quoteVolume24h': 1160.7833,
#   'volumeUsd24h': 1160.7833,
#   'priceHigh24h': 20295.0,
#   'priceLow24h': 18704.0},
#  {'name': 'YFI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.00025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.42725,
#   'bid': 0.42675,
#   'ask': 0.42975,
#   'price': 0.42725,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 576.0,
#   'change1h': 0.000585480093676815,
#   'change24h': -0.007549361207897794,
#   'changeBod': -0.014985590778097982,
#   'quoteVolume24h': 1.657088,
#   'volumeUsd24h': 33116.70719670621,
#   'priceHigh24h': 0.43675,
#   'priceLow24h': 0.42275},
#  {'name': 'YFI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 8580.0,
#   'bid': 8530.0,
#   'ask': 8545.0,
#   'price': 8545.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.0017523364485981308,
#   'change24h': 0.06083178150217256,
#   'changeBod': 0.028279181708784597,
#   'quoteVolume24h': 161441.705,
#   'volumeUsd24h': 161441.705,
#   'priceHigh24h': 8620.0,
#   'priceLow24h': 7940.0},
#  {'name': 'YFI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 8545.0,
#   'bid': 8535.0,
#   'ask': 8550.0,
#   'price': 8545.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.002335084646818447,
#   'change24h': 0.059516429014259145,
#   'changeBod': 0.028279181708784597,
#   'quoteVolume24h': 65808.395,
#   'volumeUsd24h': 65801.8141605,
#   'priceHigh24h': 8615.0,
#   'priceLow24h': 7955.0}]

# %% [markdown]
# > Since JSON format isn’t that easy to read, let’s convert it into a pandas dataframe.

# %%
df = pd.DataFrame(data)
df = df.set_index('name')
# using iloc to make it readable
df.iloc[:,:4].head()
# Out:
#            enabled  postOnly  priceIncrement  sizeIncrement
# name
# AAVE/USD      True     False          0.0100           0.01
# AAVE/USDT     True     False          0.0100           0.01
# ALGO/USD      True     False          0.0001           1.00
# ALGO/USDT     True     False          0.0001           1.00
# AUD/USD       True     False          0.0001           1.00

# %% [markdown]
# > Pretty easy, right? This will become second nature soon enough.

# %% [markdown]
# ## 3. Get an Individual Market Data

# %% [markdown]
# > You can use the following to get a single market.

# %%
# GET /markets/{market_name}
market_name = 'ETH/USD'
path = f'/markets/{market_name}'
url = api_url + path
url

'https://ftx.us/api/markets/ETH/USD'
# Out:
# 'https://ftx.us/api/markets/ETH/USD'

# %% [markdown]
# > Now let’s make the request and output the response as a dataframe.

# %%
res = requests.get(url).json()
df = pd.DataFrame(res)['result']
df = pd.DataFrame(data)
df = df.set_index('name')
# using iloc to make it readable
df.iloc[:,:].head()
# Out:
#            enabled  postOnly  priceIncrement  sizeIncrement  minProvideSize  \
# name
# AAVE/USD      True     False          0.0100           0.01            0.01
# AAVE/USDT     True     False          0.0100           0.01            0.01
# ALGO/USD      True     False          0.0001           1.00            1.00
# ALGO/USDT     True     False          0.0001           1.00            1.00
# AUD/USD       True     False          0.0001           1.00            1.00
#
#               last      bid      ask    price  type  ... restricted  \
# name                                                 ...
# AAVE/USD   78.9100  78.8700  78.9400  78.9100  spot  ...      False
# AAVE/USDT  78.9500  78.8600  78.9400  78.9400  spot  ...      False
# ALGO/USD    0.3680   0.3681   0.3689   0.3681  spot  ...      False
# ALGO/USDT   0.3739   0.3680   0.3689   0.3689  spot  ...      False
# AUD/USD     0.6520   0.6473   0.6481   0.6481  spot  ...      False
#
#           highLeverageFeeExempt largeOrderThreshold  change1h  change24h  \
# name
# AAVE/USD                   True               960.0 -0.001645   0.071419
# AAVE/USDT                  True               672.0 -0.001897   0.072846
# ALGO/USD                   True               960.0 -0.011547  -0.001085
# ALGO/USDT                  True               672.0 -0.011787   0.003810
# AUD/USD                    True               280.0  0.000000  -0.001848
#
#            changeBod  quoteVolume24h   volumeUsd24h  priceHigh24h  priceLow24h
# name
# AAVE/USD    0.036925     121603.7180  121603.718000       79.3400      72.6600
# AAVE/USDT   0.037183      45723.3619   45718.789564       79.3300      72.6800
# ALGO/USD    0.004640     236069.7768  236069.776800        0.3764       0.3569
# ALGO/USDT   0.009026      13682.4933   13681.125051        0.3754       0.3570
# AUD/USD     0.001855          0.0000       0.000000        0.6520       0.6437
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 4. Get Historical Data

# %% [markdown]
# > You can also get historical data for any of the markets. Let’s get the data as daily bars starting from 2022.

# %%
# GET /markets/{market_name}/candles?resolution={resolution}&start_time={start_time}&end_time={end_time}
# Days is 60 seconds * 60 minutes * 24
resolution = 60*60*24
resolution
# Out:
# 86400

# %%
start = datetime.datetime(2022,1,1).timestamp()
start
# Out:
# 1641016800.0

# %% [markdown]
# > We’ll now construct the URL string and request as we’ve done above.

# %%
'''
# GET /markets/{market_name}
market_name = 'ETH/USD'
path = f'/markets/{market_name}'
url = api_url + path
url

'https://ftx.us/api/markets/ETH/USD'
'''
path = f'/markets/{market_name}/candles?resolution={resolution}&start={start}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/candles?resolution=86400&start=1641016800.0'

# %% [markdown]
# > And we’ll put the data into the dataframe and clean up the index.

# %%
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df['date'] = pd.to_datetime(df['startTime'])
df = df.set_index('date')
df = df.drop(columns=['startTime', 'time'])
df
# Out:
#                                open      high       low     close  \
# date
# 2020-03-23 00:00:00+00:00   130.355   136.935   129.625   136.775
# 2020-03-24 00:00:00+00:00   136.770   144.210   132.855   138.790
# 2020-03-25 00:00:00+00:00   138.785   142.980   132.750   136.115
# 2020-03-26 00:00:00+00:00   136.105   140.125   133.615   138.890
# 2020-03-27 00:00:00+00:00   138.890   141.955   129.320   131.425
# ...                             ...       ...       ...       ...
# 2022-09-23 00:00:00+00:00  1326.300  1361.100  1261.800  1327.500
# 2022-09-24 00:00:00+00:00  1327.500  1351.100  1306.700  1316.900
# 2022-09-25 00:00:00+00:00  1316.900  1336.200  1269.900  1294.600
# 2022-09-26 00:00:00+00:00  1294.600  1340.000  1278.600  1336.300
# 2022-09-27 00:00:00+00:00  1336.300  1392.100  1332.600  1376.900
#
#                                  volume
# date
# 2020-03-23 00:00:00+00:00  0.000000e+00
# 2020-03-24 00:00:00+00:00  0.000000e+00
# 2020-03-25 00:00:00+00:00  0.000000e+00
# 2020-03-26 00:00:00+00:00  0.000000e+00
# 2020-03-27 00:00:00+00:00  0.000000e+00
# ...                                 ...
# 2022-09-23 00:00:00+00:00  1.169653e+08
# 2022-09-24 00:00:00+00:00  4.605234e+07
# 2022-09-25 00:00:00+00:00  4.395761e+07
# 2022-09-26 00:00:00+00:00  4.590856e+07
# 2022-09-27 00:00:00+00:00  5.094751e+07
#
# [918 rows x 5 columns]

# %% [markdown]
# ## 5. Get Order Book Data

# %% [markdown]
# > We can also get the order book at varying depths.
# Let’s take a look at the order book for ETH/USD.

# %%
# GET /markets/{market_name}/orderbook?depth={depth}
depth = 20
path =  f'/markets/{market_name}/orderbook?depth={depth}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/orderbook?depth=20'

# %%
res = requests.get(url).json()
bids = pd.DataFrame(res['result']['bids'])
asks = pd.DataFrame(res['result']['asks'])
bids.columns = ['Bid Price', 'Bid Amount']
asks.columns = ['Ask Price','Ask Amount']
bids.head()
# Out:
#    Bid Price  Bid Amount
# 0     1376.7       0.571
# 1     1376.6       8.900
# 2     1376.5      40.634
# 3     1376.4       4.450
# 4     1376.3       4.021

# %% [markdown]
# > Let’s show the ask dataframe.

# %%
asks.head()
# Out:
#    Ask Price  Ask Amount
# 0     1376.8       8.068
# 1     1376.9      10.663
# 2     1377.0       4.052
# 3     1377.1     103.414
# 4     1377.2       1.678

# %% [markdown]
# > Now let’s merge the two dataframes and rename the columns.

# %%
df = pd.merge(bids, asks, left_index=True, right_index=True)
df.head()
# Out:
#    Bid Price  Bid Amount  Ask Price  Ask Amount
# 0     1376.7       0.571     1376.8       8.068
# 1     1376.6       8.900     1376.9      10.663
# 2     1376.5      40.634     1377.0       4.052
# 3     1376.4       4.450     1377.1     103.414
# 4     1376.3       4.021     1377.2       1.678

# %% [markdown]
# > And we can get the summary statistics using describe. Notice the depth as the count variable.

# %%
df.describe()
# Out:
#         Bid Price  Bid Amount    Ask Price  Ask Amount
# count    20.00000   20.000000    20.000000   20.000000
# mean   1375.74000   22.477600  1377.760000   27.436300
# std       0.60819   37.904502     0.609918   58.011683
# min    1374.70000    0.022000  1376.800000    0.978000
# 25%    1375.27500    4.342750  1377.275000    4.450000
# 50%    1375.75000    8.884500  1377.750000    7.531000
# 75%    1376.22500   27.869750  1378.225000    9.814750
# max    1376.70000  167.822000  1378.900000  250.064000

# %% [markdown]
# ## 6. Get Trades

# %% [markdown]
# > Getting the recent trades for any market is also easy.

# %%
# GET /markets/{market_name}/trades
path = f'/markets/{market_name}/trades'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/trades'

# %%
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df.head()
# Out:
#          id   price   size  side  liquidation  \
# 0  44774972  1377.0  0.003   buy        False
# 1  44774968  1376.9  0.011  sell        False
# 2  44774966  1376.6  0.783   buy        False
# 3  44774965  1376.6  0.003   buy        False
# 4  44776317  1376.2  0.019  sell        False
#
#                                time
# 0  2022-09-27T05:18:19.106170+00:00
# 1  2022-09-27T05:18:13.098480+00:00
# 2  2022-09-27T05:18:04.879291+00:00
# 3  2022-09-27T05:18:04.096403+00:00
# 4  2022-09-27T05:17:58.077421+00:00

# %% [markdown]
# ## 7. Working with FTX Futures

# %% [markdown]
# > Now that you’ve learned how to use the Markets API, using the Futures API is just as easy. I’ll get you started. One thing to note is that futures are not available through the ftx.us API.<br><br>
# First, check out the futures API documentation. You’ll notice we need to make a get request to /futures. Let’s create the request URL and use requests to get the data.

# %%
url = 'https://ftx.com/api/futures'
res = requests.get(url).json()
res
# Out:
# {'success': True,
#  'result': [{'name': '1INCH-PERP',
#    'underlying': '1INCH',
#    'description': '1INCH Token Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6305,
#    'bid': 0.6302,
#    'ask': 0.6306,
#    'index': 0.6304894916666667,
#    'mark': 0.6302,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.5987,
#    'upperBound': 0.662,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.6302,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.00833988985051141,
#    'change24h': 0.036854228364593615,
#    'changeBod': 0.009288917360666239,
#    'volumeUsd24h': 4709403.6981,
#    'volume': 7592508.0,
#    'openInterest': 8054861.0,
#    'openInterestUsd': 5076173.4022},
#   {'name': '1INCH-0930',
#    'underlying': '1INCH',
#    'description': '1INCH Token September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6284,
#    'bid': 0.6264,
#    'ask': 0.6275,
#    'index': 0.6311289666666666,
#    'mark': 0.6275,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.596,
#    'upperBound': 0.6626,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.6275,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.00759133322789815,
#    'change24h': 0.030208504350681332,
#    'changeBod': 0.01226004194224875,
#    'volumeUsd24h': 64610.8507,
#    'volume': 106633.0,
#    'openInterest': 116624.0,
#    'openInterestUsd': 73181.56},
#   {'name': '1INCH-1230',
#    'underlying': '1INCH',
#    'description': '1INCH Token December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6117,
#    'bid': 0.6077,
#    'ask': 0.6114,
#    'index': 0.6304894916666667,
#    'mark': 0.6114,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.5788,
#    'upperBound': 0.662,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.6114,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0004904364884747426,
#    'change24h': 0.03679837205358657,
#    'changeBod': 0.009577278731836196,
#    'volumeUsd24h': 264.5998,
#    'volume': 445.0,
#    'openInterest': 21655.0,
#    'openInterestUsd': 13239.867},
#   {'name': 'AAPL-0930',
#    'underlying': 'AAPL',
#    'description': 'Apple September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 151.27,
#    'bid': 151.14,
#    'ask': 152.34,
#    'index': 152.24,
#    'mark': 151.27,
#    'imfFactor': 0.00125,
#    'lowerBound': 143.66,
#    'upperBound': 159.85,
#    'underlyingDescription': 'Apple',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 151.27,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.012042550344550746,
#    'changeBod': 0.0,
#    'volumeUsd24h': 9065.5713,
#    'volume': 59.71,
#    'openInterest': 8738.28,
#    'openInterestUsd': 1321839.6156},
#   {'name': 'AAPL-1230',
#    'underlying': 'AAPL',
#    'description': 'Apple December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 151.24,
#    'bid': 151.62,
#    'ask': 152.24,
#    'index': 152.24,
#    'mark': 151.58,
#    'imfFactor': 0.00125,
#    'lowerBound': 144.06,
#    'upperBound': 159.85,
#    'underlyingDescription': 'Apple',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 151.58,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0009885981677980624,
#    'change24h': 0.008784773060029283,
#    'changeBod': 0.003110316987624909,
#    'volumeUsd24h': 136924.1657,
#    'volume': 899.97,
#    'openInterest': 676.52,
#    'openInterestUsd': 102546.9016},
#   {'name': 'AAVE-PERP',
#    'underlying': 'AAVE',
#    'description': 'Aave Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 78.97,
#    'bid': 78.97,
#    'ask': 78.98,
#    'index': 78.91793579866666,
#    'mark': 78.97,
#    'imfFactor': 0.0025,
#    'lowerBound': 74.98,
#    'upperBound': 82.9,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 78.97,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0011383759170250443,
#    'change24h': 0.07121540965816603,
#    'changeBod': 0.03635170603674541,
#    'volumeUsd24h': 12584644.1769,
#    'volume': 166257.7,
#    'openInterest': 179894.29,
#    'openInterestUsd': 14206252.0813},
#   {'name': 'AAVE-0930',
#    'underlying': 'AAVE',
#    'description': 'Aave September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 78.6,
#    'bid': 78.79,
#    'ask': 79.37,
#    'index': 78.91587186133333,
#    'mark': 78.79,
#    'imfFactor': 0.0025,
#    'lowerBound': 74.9,
#    'upperBound': 82.86,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 78.79,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0021529888551165147,
#    'change24h': 0.06732592793280953,
#    'changeBod': 0.03671052631578947,
#    'volumeUsd24h': 7795.1458,
#    'volume': 101.01,
#    'openInterest': 2267.76,
#    'openInterestUsd': 178676.8104},
#   {'name': 'AAVE-1230',
#    'underlying': 'AAVE',
#    'description': 'Aave December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 78.56,
#    'bid': 78.04,
#    'ask': 78.8,
#    'index': 78.91793579866666,
#    'mark': 78.56,
#    'imfFactor': 0.0025,
#    'lowerBound': 74.46,
#    'upperBound': 82.86,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 78.56,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.07601698397479797,
#    'changeBod': 0.04066763809776129,
#    'volumeUsd24h': 537.1674,
#    'volume': 7.2,
#    'openInterest': 984.51,
#    'openInterestUsd': 77343.1056},
#   {'name': 'ABNB-0930',
#    'underlying': 'ABNB',
#    'description': 'Airbnb September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.025,
#    'last': 105.18,
#    'bid': 103.8,
#    'ask': 104.38,
#    'index': 103.565,
#    'mark': 104.295,
#    'imfFactor': 0.005,
#    'lowerBound': 98.39,
#    'upperBound': 109.585,
#    'underlyingDescription': 'Airbnb',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 104.295,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0016273393002441008,
#    'change24h': 0.0199501246882793,
#    'changeBod': 0.0027883274842555646,
#    'volumeUsd24h': 68.367,
#    'volume': 0.65,
#    'openInterest': 150.0,
#    'openInterestUsd': 15644.25},
#   {'name': 'ABNB-1230',
#    'underlying': 'ABNB',
#    'description': 'Airbnb December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.025,
#    'last': 110.24,
#    'bid': 103.895,
#    'ask': 104.35,
#    'index': 103.565,
#    'mark': 104.525,
#    'imfFactor': 0.005,
#    'lowerBound': 98.39,
#    'upperBound': 109.55,
#    'underlyingDescription': 'Airbnb',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 104.525,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0009576250897773521,
#    'change24h': 0.02010442590152735,
#    'changeBod': 0.003070869919869488,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 100.0,
#    'openInterestUsd': 10452.5},
#   {'name': 'ACB-0930',
#    'underlying': 'ACB',
#    'description': 'Aurora Cannabis Inc September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 1.174,
#    'bid': 1.165,
#    'ask': 1.176,
#    'index': 1.176,
#    'mark': 1.174,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.115,
#    'upperBound': 1.234,
#    'underlyingDescription': 'Aurora Cannabis Inc',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1.174,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.01839464882943144,
#    'changeBod': 0.003418803418803419,
#    'volumeUsd24h': 11936.1607,
#    'volume': 9625.5,
#    'openInterest': 0.1,
#    'openInterestUsd': 0.1174},
#   {'name': 'ACB-1230',
#    'underlying': 'ACB',
#    'description': 'Aurora Cannabis Inc December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 1.25,
#    'bid': 1.15,
#    'ask': 1.235,
#    'index': 1.176,
#    'mark': 1.235,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.118,
#    'upperBound': 1.293,
#    'underlyingDescription': 'Aurora Cannabis Inc',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1.235,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.012,
#    'changeBod': 0.0,
#    'volumeUsd24h': 2008.8231,
#    'volume': 1675.8,
#    'openInterest': 2429.2,
#    'openInterestUsd': 3000.062},
#   {'name': 'ADA-PERP',
#    'underlying': 'ADA',
#    'description': 'Cardano Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.45659,
#    'bid': 0.45632,
#    'ask': 0.45659,
#    'index': 0.4564873692825397,
#    'mark': 0.45658,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.43362,
#    'upperBound': 0.47931,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.45658,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0090827211268217,
#    'change24h': 0.032635983263598324,
#    'changeBod': 0.021157631061012705,
#    'volumeUsd24h': 47703884.828085,
#    'volume': 106967114.0,
#    'openInterest': 123194719.0,
#    'openInterestUsd': 56248244.80102},
#   {'name': 'ADA-0930',
#    'underlying': 'ADA',
#    'description': 'Cardano September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.457035,
#    'bid': 0.45551,
#    'ask': 0.455975,
#    'index': 0.45675879722698415,
#    'mark': 0.456075,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.43335,
#    'upperBound': 0.479595,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.456075,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.008672687555019399,
#    'change24h': 0.03403126523301554,
#    'changeBod': 0.023392797038034333,
#    'volumeUsd24h': 476862.09298,
#    'volume': 1058364.0,
#    'openInterest': 7351451.0,
#    'openInterestUsd': 3352813.014825},
#   {'name': 'ADA-1230',
#    'underlying': 'ADA',
#    'description': 'Cardano December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.446235,
#    'bid': 0.445955,
#    'ask': 0.4476,
#    'index': 0.4564873692825397,
#    'mark': 0.446235,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.423475,
#    'upperBound': 0.47931,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.446235,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.008917268184342032,
#    'change24h': 0.03286770747740345,
#    'changeBod': 0.020338866785567292,
#    'volumeUsd24h': 32236.777615,
#    'volume': 73074.0,
#    'openInterest': 3302393.0,
#    'openInterestUsd': 1473643.340355},
#   {'name': 'AGLD-PERP',
#    'underlying': 'AGLD',
#    'description': 'Adventure Gold Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 0.332,
#    'bid': 0.332,
#    'ask': 0.3325,
#    'index': 0.33348517777777775,
#    'mark': 0.332,
#    'imfFactor': 0.001,
#    'lowerBound': 0.317,
#    'upperBound': 0.35,
#    'underlyingDescription': 'Adventure Gold',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.332,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.007473841554559043,
#    'change24h': 0.019969278033794162,
#    'changeBod': 0.016845329249617153,
#    'volumeUsd24h': 1474573.6197,
#    'volume': 4541220.1,
#    'openInterest': 1444624.1,
#    'openInterestUsd': 479615.2012},
#   {'name': 'ALCX-PERP',
#    'underlying': 'ALCX',
#    'description': 'Alchemix Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 21.3,
#    'bid': 21.3,
#    'ask': 21.4,
#    'index': 21.6,
#    'mark': 21.3,
#    'imfFactor': 0.025,
#    'lowerBound': 20.3,
#    'upperBound': 22.6,
#    'underlyingDescription': 'Alchemix',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 21.3,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.014285714285714285,
#    'change24h': 0.05970149253731343,
#    'changeBod': 0.054455445544554455,
#    'volumeUsd24h': 232675.9054,
#    'volume': 11258.281,
#    'openInterest': 23840.764,
#    'openInterestUsd': 507808.2732},
#   {'name': 'ALGO-PERP',
#    'underlying': 'ALGO',
#    'description': 'Algorand Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.3684,
#    'bid': 0.3684,
#    'ask': 0.3685,
#    'index': 0.36826235509039684,
#    'mark': 0.3684,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3497,
#    'upperBound': 0.3866,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.3684,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.00967741935483871,
#    'change24h': 0.001359064963305246,
#    'changeBod': 0.003541269408880414,
#    'volumeUsd24h': 31063157.0287,
#    'volume': 84806159.0,
#    'openInterest': 42374508.0,
#    'openInterestUsd': 15610768.7472},
#   {'name': 'ALGO-0930',
#    'underlying': 'ALGO',
#    'description': 'Algorand September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.3707,
#    'bid': 0.3683,
#    'ask': 0.3699,
#    'index': 0.368259101162929,
#    'mark': 0.3697,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3499,
#    'upperBound': 0.3875,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.3697,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.010174029451137885,
#    'change24h': 0.00598639455782313,
#    'changeBod': 0.0027122321670735015,
#    'volumeUsd24h': 71493.8938,
#    'volume': 195378.0,
#    'openInterest': 439742.0,
#    'openInterestUsd': 162572.6174},
#   {'name': 'ALGO-1230',
#    'underlying': 'ALGO',
#    'description': 'Algorand December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.3729,
#    'bid': 0.3694,
#    'ask': 0.3716,
#    'index': 0.36826235509039684,
#    'mark': 0.3716,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3499,
#    'upperBound': 0.3897,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.3716,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.011702127659574468,
#    'change24h': 0.00026917900403768504,
#    'changeBod': 0.011707051456575007,
#    'volumeUsd24h': 20204.3691,
#    'volume': 54806.0,
#    'openInterest': 389345.0,
#    'openInterestUsd': 144680.602},
#   {'name': 'ALICE-PERP',
#    'underlying': 'ALICE',
#    'description': 'MyNeighborAlice Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 1.7625,
#    'bid': 1.76,
#    'ask': 1.7625,
#    'index': 1.7619608666666666,
#    'mark': 1.7625,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.675,
#    'upperBound': 1.85,
#    'underlyingDescription': 'MyNeighborAlice',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.7625,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.00141643059490085,
#    'change24h': 0.05223880597014925,
#    'changeBod': 0.026200873362445413,
#    'volumeUsd24h': 1211195.43575,
#    'volume': 712128.4,
#    'openInterest': 863547.0,
#    'openInterestUsd': 1522001.5875},
#   {'name': 'ALPHA-PERP',
#    'underlying': 'ALPHA',
#    'description': 'Alpha Finance Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.10875,
#    'bid': 0.10875,
#    'ask': 0.1088,
#    'index': 0.10872203536507936,
#    'mark': 0.1088,
#    'imfFactor': 0.00025,
#    'lowerBound': 0.1033,
#    'upperBound': 0.1142,
#    'underlyingDescription': 'Alpha Finance',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.1088,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0013767783386874712,
#    'change24h': 0.059912323429128105,
#    'changeBod': 0.03569728700618753,
#    'volumeUsd24h': 803160.8295,
#    'volume': 7622037.0,
#    'openInterest': 7120876.0,
#    'openInterestUsd': 774751.3088},
#   {'name': 'ALT-PERP',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1913.75,
#    'bid': 1913.2,
#    'ask': 1913.35,
#    'index': 1912.1795463677379,
#    'mark': 1913.4,
#    'imfFactor': 0.0008,
#    'lowerBound': 1816.6,
#    'upperBound': 2008.8,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1913.4,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 2.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.001643578304766377,
#    'change24h': 0.04210010348020261,
#    'changeBod': 0.025704253665335443,
#    'volumeUsd24h': 3063918.27225,
#    'volume': 1631.279,
#    'openInterest': 5244.004,
#    'openInterestUsd': 10033877.2536},
#   {'name': 'ALT-0930',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1915.1,
#    'bid': 1908.3,
#    'ask': 1911.9,
#    'index': 1912.924931206012,
#    'mark': 1912.1,
#    'imfFactor': 0.0008,
#    'lowerBound': 1816.35,
#    'upperBound': 2008.55,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1912.1,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.001514360313315927,
#    'change24h': 0.04269822227069473,
#    'changeBod': 0.028425440365738873,
#    'volumeUsd24h': 49753.77135,
#    'volume': 26.705,
#    'openInterest': 596.572,
#    'openInterestUsd': 1140705.3212},
#   {'name': 'ALT-1230',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1877.7,
#    'bid': 1878.45,
#    'ask': 1886.65,
#    'index': 1912.1795463677379,
#    'mark': 1877.7,
#    'imfFactor': 0.0008,
#    'lowerBound': 1782.0,
#    'upperBound': 2007.75,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1877.7,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0023113094763688533,
#    'change24h': 0.043166666666666666,
#    'changeBod': 0.02511328274280723,
#    'volumeUsd24h': 1948.919,
#    'volume': 1.049,
#    'openInterest': 131.548,
#    'openInterestUsd': 247007.6796},
#   {'name': 'AMC-0930',
#    'underlying': 'AMC',
#    'description': 'AMC Entertainment Holdings September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 12.78,
#    'bid': 12.7925,
#    'ask': 13.2,
#    'index': 13.05,
#    'mark': 12.795,
#    'imfFactor': 0.0025,
#    'indexAdjustment': 6.0,
#    'lowerBound': 10.1875,
#    'upperBound': 15.66,
#    'underlyingDescription': 'AMC Entertainment Holdings',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 12.795,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0001953506544246923,
#    'change24h': -0.1108408617095205,
#    'changeBod': 0.0035294117647058825,
#    'volumeUsd24h': 12009.465,
#    'volume': 931.2,
#    'openInterest': 33833.4,
#    'openInterestUsd': 432898.353},
#   {'name': 'AMC-1230',
#    'underlying': 'AMC',
#    'description': 'AMC Entertainment Holdings December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 7.1275,
#    'bid': 6.8925,
#    'ask': 7.125,
#    'index': 7.05,
#    'mark': 7.125,
#    'imfFactor': 0.0025,
#    'lowerBound': 5.64,
#    'upperBound': 8.535,
#    'underlyingDescription': 'AMC Entertainment Holdings',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 7.125,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.10965323336457357,
#    'changeBod': 0.02591792656587473,
#    'volumeUsd24h': 1262.79025,
#    'volume': 179.3,
#    'openInterest': 1362.3,
#    'openInterestUsd': 9706.3875},
#   {'name': 'AMD-0930',
#    'underlying': 'AMD',
#    'description': 'Advanced Micro Devices September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 66.75,
#    'bid': 66.72,
#    'ask': 67.29,
#    'index': 67.06,
#    'mark': 66.75,
#    'imfFactor': 0.001,
#    'lowerBound': 63.36,
#    'upperBound': 70.41,
#    'underlyingDescription': 'Advanced Micro Devices',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 66.75,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.03162628753808211,
#    'changeBod': -0.003285053008809915,
#    'volumeUsd24h': 4026.0493,
#    'volume': 59.98,
#    'openInterest': 934.76,
#    'openInterestUsd': 62395.23},
#   {'name': 'AMD-1230',
#    'underlying': 'AMD',
#    'description': 'Advanced Micro Devices December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 67.18,
#    'bid': 66.83,
#    'ask': 67.16,
#    'index': 67.06,
#    'mark': 67.18,
#    'imfFactor': 0.001,
#    'lowerBound': 63.71,
#    'upperBound': 70.48,
#    'underlyingDescription': 'Advanced Micro Devices',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 67.18,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.02155549082435188,
#    'changeBod': 0.00358530026889752,
#    'volumeUsd24h': 5027.4492,
#    'volume': 74.83,
#    'openInterest': 1149.74,
#    'openInterestUsd': 77239.5332},
#   {'name': 'AMPL-PERP',
#    'underlying': 'AMPL',
#    'description': 'Ampleforth Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 10.0,
#    'last': 1.1715,
#    'bid': 1.1705,
#    'ask': 1.1725,
#    'index': 1.169333381037143,
#    'mark': 1.1715,
#    'imfFactor': 0.0005,
#    'lowerBound': 1.1109,
#    'upperBound': 1.2301,
#    'underlyingDescription': 'Ampleforth',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.1715,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0018744142455482662,
#    'change24h': 0.009913793103448277,
#    'changeBod': 0.011483336211362459,
#    'volumeUsd24h': 146353.679,
#    'volume': 125570.0,
#    'openInterest': 435980.0,
#    'openInterestUsd': 510750.57},
#   {'name': 'AMZN-0930',
#    'underlying': 'AMZN',
#    'description': 'Amazon September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 116.7,
#    'bid': 115.1,
#    'ask': 115.8,
#    'index': 115.4,
#    'mark': 115.9,
#    'imfFactor': 0.00067,
#    'lowerBound': 109.7,
#    'upperBound': 121.6,
#    'underlyingDescription': 'Amazon',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 115.9,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0025817555938037868,
#    'change24h': 0.03113879003558719,
#    'changeBod': 0.004332755632582322,
#    'volumeUsd24h': 411.4682,
#    'volume': 3.586,
#    'openInterest': 11000.701,
#    'openInterestUsd': 1274981.2459},
#   {'name': 'AMZN-1230',
#    'underlying': 'AMZN',
#    'description': 'Amazon December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 114.9,
#    'bid': 115.2,
#    'ask': 115.9,
#    'index': 115.4,
#    'mark': 114.9,
#    'imfFactor': 0.00067,
#    'lowerBound': 109.4,
#    'upperBound': 121.1,
#    'underlyingDescription': 'Amazon',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 114.9,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0026041666666666665,
#    'change24h': 0.01412180052956752,
#    'changeBod': 0.0017436791630340018,
#    'volumeUsd24h': 430.6203,
#    'volume': 3.75,
#    'openInterest': 135.958,
#    'openInterestUsd': 15621.5742},
#   {'name': 'ANC-PERP',
#    'underlying': 'ANC',
#    'description': 'Anchor Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': False,
#    'postOnly': False,
#    'priceIncrement': 0.00025,
#    'sizeIncrement': 1.0,
#    'last': None,
#    'bid': None,
#    'ask': None,
#    'index': 0.09922338466666666,
#    'mark': 0.09957610466666666,
#    'imfFactor': 0.0003,
#    'lowerBound': 0.137,
#    'upperBound': 0.1515,
#    'underlyingDescription': 'Anchor',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.09957610466666666,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.3108920092272203,
#    'change24h': -0.3108920092272203,
#    'changeBod': -0.3108920092272203,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 0.0,
#    'openInterestUsd': 0.0},
#   {'name': 'APE-PERP',
#    'underlying': 'APE',
#    'description': 'ApeCoin Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.676,
#    'bid': 5.677,
#    'ask': 5.6775,
#    'index': 5.677,
#    'mark': 5.6765,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.392,
#    'upperBound': 5.9605,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 5.6765,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.007691635346560616,
#    'change24h': 0.010412958348166607,
#    'changeBod': 0.030030847396116857,
#    'volumeUsd24h': 45011703.93485,
#    'volume': 8128871.6,
#    'openInterest': 6388476.4,
#    'openInterestUsd': 36264186.2846},
#   {'name': 'APE-0930',
#    'underlying': 'APE',
#    'description': 'ApeCoin September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.641,
#    'bid': 5.656,
#    'ask': 5.677,
#    'index': 5.677,
#    'mark': 5.6555,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.371,
#    'upperBound': 5.9605,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 5.6555,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.006935908691834943,
#    'change24h': 0.006495817761167468,
#    'changeBod': 0.030427256991892138,
#    'volumeUsd24h': 5797.53915,
#    'volume': 1048.0,
#    'openInterest': 35692.3,
#    'openInterestUsd': 201857.80265},
#   {'name': 'APE-1230',
#    'underlying': 'APE',
#    'description': 'ApeCoin December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.549,
#    'bid': 5.5275,
#    'ask': 5.552,
#    'index': 5.6695,
#    'mark': 5.549,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.265,
#    'upperBound': 5.9525,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 5.549,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.00813298775583162,
#    'change24h': 0.010102848821334304,
#    'changeBod': 0.03362205457762876,
#    'volumeUsd24h': 161871.1236,
#    'volume': 30089.7,
#    'openInterest': 208767.4,
#    'openInterestUsd': 1158450.3026},
#   {'name': 'AR-PERP',
#    'underlying': 'AR',
#    'description': 'Arweave Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 9.726,
#    'bid': 9.719,
#    'ask': 9.724,
#    'index': 9.726125785,
#    'mark': 9.723,
#    'imfFactor': 0.0025,
#    'lowerBound': 9.236,
#    'upperBound': 10.212,
#    'underlyingDescription': 'Arweave',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 9.723,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0021551724137931034,
#    'change24h': 0.054098005203816135,
#    'changeBod': 0.030087933043754636,
#    'volumeUsd24h': 1690867.804,
#    'volume': 178929.7,
#    'openInterest': 257729.2,
#    'openInterestUsd': 2505901.0116},
#   {'name': 'ARKK-0930',
#    'underlying': 'ARKK',
#    'description': 'ARK Innovation ETF September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 37.68,
#    'bid': 37.73,
#    'ask': 37.93,
#    'index': 37.7,
#    'mark': 37.73,
#    'imfFactor': 0.005,
#    'lowerBound': 35.82,
#    'upperBound': 39.61,
#    'underlyingDescription': 'ARK Innovation ETF',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 37.73,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.001326963906581741,
#    'change24h': -0.009191176470588236,
#    'changeBod': 0.003457446808510638,
#    'volumeUsd24h': 55472.3923,
#    'volume': 1432.81,
#    'openInterest': 11416.24,
#    'openInterestUsd': 430734.7352},
#   {'name': 'ARKK-1230',
#    'underlying': 'ARKK',
#    'description': 'ARK Innovation ETF December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 37.88,
#    'bid': 37.77,
#    'ask': 37.93,
#    'index': 37.7,
#    'mark': 37.88,
#    'imfFactor': 0.005,
#    'lowerBound': 35.82,
#    'upperBound': 39.76,
#    'underlyingDescription': 'ARK Innovation ETF',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 37.88,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.00785751702462022,
#    'changeBod': 0.006376195536663124,
#    'volumeUsd24h': 17597.2102,
#    'volume': 466.72,
#    'openInterest': 2251.16,
#    'openInterestUsd': 85273.9408},
#   {'name': 'ASD-PERP',
#    'underlying': 'ASD',
#    'description': 'AscendEx Token (BTMX) Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 0.1,
#    'last': 0.10701,
#    'bid': 0.1067,
#    'ask': 0.10694,
#    'index': 0.1067,
#    'mark': 0.10698,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.10137,
#    'upperBound': 0.11222,
#    'underlyingDescription': 'AscendEx Token (BTMX)',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.10698,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0018730099269526129,
#    'change24h': 0.040357872216279296,
#    'changeBod': 0.002154566744730679,
#    'volumeUsd24h': 429901.568377,
#    'volume': 4111277.3,
#    'openInterest': 17242898.7,
#    'openInterestUsd': 1844645.302926},
#   {'name': 'ATLAS-PERP',
#    'underlying': 'ATLAS',
#    'description': 'Atlas Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-07,
#    'sizeIncrement': 10.0,
#    'last': 0.00460275,
#    'bid': 0.00459,
#    'ask': 0.004603,
#    'index': 0.00459525,
#    'mark': 0.00460275,
#    'imfFactor': 2.5e-05,
#    'lowerBound': 0.0043655,
#    'upperBound': 0.0048295,
#    'underlyingDescription': 'Atlas',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.00460275,
#    'imfWeight': 4.0,
#    'mmfWeight': 4.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.002113821138211382,
#    'change24h': 0.03601373023465196,
#    'changeBod': 0.0143801652892562,
#    'volumeUsd24h': 145568.89679,
#    'volume': 32385390.0,
#    'openInterest': 146348290.0,
#    'openInterestUsd': 673604.5917975},
#   {'name': 'ATOM-PERP',
#    'underlying': 'ATOM',
#    'description': 'Cosmos Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 14.2655,
#    'bid': 14.2655,
#    'ask': 14.266,
#    'index': 14.280583338895237,
#    'mark': 14.2655,
#    'imfFactor': 0.0004,
#    'lowerBound': 13.561,
#    'upperBound': 14.9945,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 14.2655,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.00021025335529312823,
#    'change24h': 0.017111689422836977,
#    'changeBod': 0.030595289698020518,
#    'volumeUsd24h': 172940276.533765,
#    'volume': 12188080.19,
#    'openInterest': 3846787.09,
#    'openInterestUsd': 54876341.232395},
#   {'name': 'ATOM-0930',
#    'underlying': 'ATOM',
#    'description': 'Cosmos September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 14.216,
#    'bid': 14.204,
#    'ask': 14.2505,
#    'index': 14.295421417153968,
#    'mark': 14.216,
#    'imfFactor': 0.0004,
#    'lowerBound': 13.5525,
#    'upperBound': 15.0095,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 14.216,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0011267605633802818,
#    'change24h': 0.014197046443604195,
#    'changeBod': 0.030331581808298605,
#    'volumeUsd24h': 59130.597405,
#    'volume': 4062.95,
#    'openInterest': 19306.6,
#    'openInterestUsd': 274462.6256},
#   {'name': 'ATOM-1230',
#    'underlying': 'ATOM',
#    'description': 'Cosmos December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 13.9285,
#    'bid': 13.858,
#    'ask': 13.943,
#    'index': 14.280583338895237,
#    'mark': 13.9285,
#    'imfFactor': 0.0004,
#    'lowerBound': 13.211,
#    'upperBound': 14.9945,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 13.9285,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0040005766596986955,
#    'change24h': 0.017421475529583636,
#    'changeBod': 0.035537712352700646,
#    'volumeUsd24h': 536202.74678,
#    'volume': 39118.21,
#    'openInterest': 148457.79,
#    'openInterestUsd': 2067794.328015},
#   {'name': 'AUDIO-PERP',
#    'underlying': 'AUDIO',
#    'description': 'Audius Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 0.226,
#    'bid': 0.2255,
#    'ask': 0.226,
#    'index': 0.2257399291812143,
#    'mark': 0.226,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.2145,
#    'upperBound': 0.237,
#    'underlyingDescription': 'Audius',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.226,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.006593406593406593,
#    'change24h': 0.08133971291866028,
#    'changeBod': 0.03908045977011494,
#    'volumeUsd24h': 681429.90475,
#    'volume': 3117239.8,
#    'openInterest': 3876166.7,
#    'openInterestUsd': 876013.6742},
#   {'name': 'AVAX-PERP',
#    'underlying': 'AVAX',
#    'description': 'Avalanche Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.889,
#    'bid': 17.889,
#    'ask': 17.89,
#    'index': 17.896548929238094,
#    'mark': 17.89,
#    'imfFactor': 0.0007,
#    'lowerBound': 16.997,
#    'upperBound': 18.791,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 17.89,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0032870912028525267,
#    'change24h': 0.044488556749182624,
#    'changeBod': 0.02065267001369238,
#    'volumeUsd24h': 44374127.807,
#    'volume': 2545739.2,
#    'openInterest': 2561400.3,
#    'openInterestUsd': 45823451.367},
#   {'name': 'AVAX-0930',
#    'underlying': 'AVAX',
#    'description': 'Avalanche September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.879,
#    'bid': 17.858,
#    'ask': 17.875,
#    'index': 17.919346420892857,
#    'mark': 17.879,
#    'imfFactor': 0.0007,
#    'lowerBound': 16.988,
#    'upperBound': 18.815,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 17.879,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0027331548415885764,
#    'change24h': 0.045739018541264546,
#    'changeBod': 0.021540395383384755,
#    'volumeUsd24h': 608858.9366,
#    'volume': 34925.0,
#    'openInterest': 34603.8,
#    'openInterestUsd': 618681.3402},
#   {'name': 'AVAX-1230',
#    'underlying': 'AVAX',
#    'description': 'Avalanche December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.551,
#    'bid': 17.456,
#    'ask': 17.537,
#    'index': 17.896548929238094,
#    'mark': 17.537,
#    'imfFactor': 0.0007,
#    'lowerBound': 16.61,
#    'upperBound': 18.791,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 17.537,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.00153723525392849,
#    'change24h': 0.0499311500927977,
#    'changeBod': 0.025735509153652688,
#    'volumeUsd24h': 16718.0048,
#    'volume': 977.1,
#    'openInterest': 34592.1,
#    'openInterestUsd': 606641.6577},
#   {'name': 'AXS-PERP',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 12.675,
#    'bid': 12.672,
#    'ask': 12.675,
#    'index': 12.710001651111112,
#    'mark': 12.694,
#    'imfFactor': 0.001,
#    'lowerBound': 12.069,
#    'upperBound': 13.345,
#    'underlyingDescription': 'Axie Infinity',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 12.694,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0034542314335060447,
#    'change24h': 0.038618883979708724,
#    'changeBod': 0.020335985853227233,
#    'volumeUsd24h': 12776291.4354,
#    'volume': 1029547.8,
#    'openInterest': 1595146.8,
#    'openInterestUsd': 20248793.4792},
#   {'name': 'AXS-0930',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 12.716,
#    'bid': 12.565,
#    'ask': 12.659,
#    'index': 12.710001651111112,
#    'mark': 12.683,
#    'imfFactor': 0.001,
#    'lowerBound': 12.061,
#    'upperBound': 13.345,
#    'underlyingDescription': 'Axie Infinity',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 12.683,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -7.883948281299275e-05,
#    'change24h': 0.0398458637369845,
#    'changeBod': 0.026215713245408206,
#    'volumeUsd24h': 13343.8419,
#    'volume': 1089.2,
#    'openInterest': 71897.4,
#    'openInterestUsd': 911874.7242},
#   {'name': 'AXS-1230',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 10.604,
#    'bid': 10.783,
#    'ask': 10.946,
#    'index': 12.697951136666667,
# ...
#   {'name': 'XLM-PERP',
#    'underlying': 'XLM',
#    'description': 'Stellar Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.115675,
#    'bid': 0.115675,
#    'ask': 0.1157,
#    'index': 0.11568317795809524,
#    'mark': 0.1157,
#    'imfFactor': 5e-05,
#    'lowerBound': 0.1099,
#    'upperBound': 0.12145,
#    'underlyingDescription': 'Stellar',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.1157,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.006653788366602275,
#    'change24h': -0.005800214822771214,
#    'changeBod': 0.015580425718674566,
#    'volumeUsd24h': 8609192.522775,
#    'volume': 75241481.0,
#    'openInterest': 110268391.0,
#    'openInterestUsd': 12758052.8387},
#   {'name': 'XMR-PERP',
#    'underlying': 'XMR',
#    'description': 'Monero Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 151.01,
#    'bid': 151.01,
#    'ask': 151.02,
#    'index': 151.11129106301587,
#    'mark': 151.02,
#    'imfFactor': 0.002,
#    'lowerBound': 143.54,
#    'upperBound': 158.66,
#    'underlyingDescription': 'Monero',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 151.02,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.004154302670623145,
#    'change24h': 0.07258522727272727,
#    'changeBod': 0.036228900782214905,
#    'volumeUsd24h': 4756152.2653,
#    'volume': 32645.05,
#    'openInterest': 52292.59,
#    'openInterestUsd': 7897226.9418},
#   {'name': 'XRP-PERP',
#    'underlying': 'XRP',
#    'description': 'XRP Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.475175,
#    'bid': 0.475225,
#    'ask': 0.4753,
#    'index': 0.4753425,
#    'mark': 0.475125,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.4516,
#    'upperBound': 0.4992,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.475125,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.00042076473991479514,
#    'change24h': -0.012829835861209225,
#    'changeBod': 0.017616191904047975,
#    'volumeUsd24h': 251360647.813975,
#    'volume': 534167046.0,
#    'openInterest': 206734672.0,
#    'openInterestUsd': 98224811.034},
#   {'name': 'XRP-0930',
#    'underlying': 'XRP',
#    'description': 'XRP September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.4746,
#    'bid': 0.47475,
#    'ask': 0.4749,
#    'index': 0.475815,
#    'mark': 0.4751,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.451725,
#    'upperBound': 0.4996,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.4751,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 8.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 5.2623270009998424e-05,
#    'change24h': -0.010929530550640158,
#    'changeBod': 0.018380579818873588,
#    'volumeUsd24h': 1160651.2444,
#    'volume': 2473550.0,
#    'openInterest': 3542359.0,
#    'openInterestUsd': 1682974.7609},
#   {'name': 'XRP-1230',
#    'underlying': 'XRP',
#    'description': 'XRP December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.475,
#    'bid': 0.4727,
#    'ask': 0.47345,
#    'index': 0.475815,
#    'mark': 0.474475,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.450075,
#    'upperBound': 0.4996,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.474475,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 8.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0018475506756756757,
#    'change24h': -0.00960183687314095,
#    'changeBod': 0.021529684051886537,
#    'volumeUsd24h': 224374.786775,
#    'volume': 478998.0,
#    'openInterest': 1507184.0,
#    'openInterestUsd': 715121.1284},
#   {'name': 'XTZ-PERP',
#    'underlying': 'XTZ',
#    'description': 'Tezos Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.5377,
#    'bid': 1.5379,
#    'ask': 1.5381,
#    'index': 1.5355900596507936,
#    'mark': 1.5379,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.4589,
#    'upperBound': 1.6133,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.5379,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.004310063344870371,
#    'change24h': 0.06724496877168633,
#    'changeBod': 0.04391800162910671,
#    'volumeUsd24h': 3699858.8431301,
#    'volume': 2509679.595,
#    'openInterest': 5095927.586,
#    'openInterestUsd': 7837027.0345094},
#   {'name': 'XTZ-0930',
#    'underlying': 'XTZ',
#    'description': 'Tezos September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.5163,
#    'bid': 1.5312,
#    'ask': 1.5408,
#    'index': 1.5362582819164021,
#    'mark': 1.5304,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.454,
#    'upperBound': 1.613,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1.5304,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0034093889325990034,
#    'change24h': 0.06042128603104213,
#    'changeBod': 0.03910917979359044,
#    'volumeUsd24h': 34825.9968441,
#    'volume': 23589.649,
#    'openInterest': 652344.212,
#    'openInterestUsd': 998347.5820448},
#   {'name': 'XTZ-1230',
#    'underlying': 'XTZ',
#    'description': 'Tezos December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.5012,
#    'bid': 1.51,
#    'ask': 1.5211,
#    'index': 1.5362582819164021,
#    'mark': 1.5087,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.4326,
#    'upperBound': 1.613,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1.5087,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.003058307293398045,
#    'change24h': 0.05829124579124579,
#    'changeBod': 0.043721895537876164,
#    'volumeUsd24h': 894.9451636,
#    'volume': 623.035,
#    'openInterest': 266449.998,
#    'openInterestUsd': 401993.1119826},
#   {'name': 'YFI-PERP',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8540.0,
#    'bid': 8540.0,
#    'ask': 8545.0,
#    'index': 8541.036458333334,
#    'mark': 8540.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 8115.0,
#    'upperBound': 8970.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 8540.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 50.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.002918855808523059,
#    'change24h': 0.06021104903786468,
#    'changeBod': 0.025825825825825825,
#    'volumeUsd24h': 4761618.255,
#    'volume': 573.311,
#    'openInterest': 824.978,
#    'openInterestUsd': 7045312.12},
#   {'name': 'YFI-0930',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8270.0,
#    'bid': 8515.0,
#    'ask': 8595.0,
#    'index': 8543.8228,
#    'mark': 8525.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 8100.0,
#    'upperBound': 8970.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 8525.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0011716461628588166,
#    'change24h': 0.049876847290640396,
#    'changeBod': 0.025872442839951864,
#    'volumeUsd24h': 118035.525,
#    'volume': 14.212,
#    'openInterest': 27.709,
#    'openInterestUsd': 236219.225},
#   {'name': 'YFI-1230',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8200.0,
#    'bid': 8400.0,
#    'ask': 8580.0,
#    'index': 8543.8228,
#    'mark': 8400.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 8010.0,
#    'upperBound': 8970.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 8400.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.05,
#    'changeBod': 0.021897810218978103,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 5.95,
#    'openInterestUsd': 49980.0},
#   {'name': 'YFII-PERP',
#    'underlying': 'YFII',
#    'description': 'DFI.Money Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.25,
#    'sizeIncrement': 0.001,
#    'last': 896.25,
#    'bid': 895.75,
#    'ask': 896.25,
#    'index': 895.7223919233334,
#    'mark': 896.25,
#    'imfFactor': 0.025,
#    'lowerBound': 851.0,
#    'upperBound': 940.75,
#    'underlyingDescription': 'DFI.Money',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 896.25,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.003613118399110617,
#    'change24h': 0.04427614331488494,
#    'changeBod': 0.017598637524836785,
#    'volumeUsd24h': 1468993.31475,
#    'volume': 1677.944,
#    'openInterest': 2169.788,
#    'openInterestUsd': 1944672.495},
#   {'name': 'ZEC-PERP',
#    'underlying': 'ZEC',
#    'description': 'Zcash Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.05,
#    'last': 59.91,
#    'bid': 59.89,
#    'ask': 59.93,
#    'index': 59.895336111111114,
#    'mark': 59.91,
#    'imfFactor': 0.001,
#    'lowerBound': 56.91,
#    'upperBound': 62.92,
#    'underlyingDescription': 'Zcash',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 59.91,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 3.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0015,
#    'change24h': 0.05810667608618863,
#    'changeBod': 0.019224225927186117,
#    'volumeUsd24h': 4836656.315,
#    'volume': 83296.95,
#    'openInterest': 58409.5,
#    'openInterestUsd': 3499313.145},
#   {'name': 'ZIL-PERP',
#    'underlying': 'ZIL',
#    'description': 'Zilliqa Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 10.0,
#    'last': 0.03259,
#    'bid': 0.03258,
#    'ask': 0.0326,
#    'index': 0.03258124725555556,
#    'mark': 0.03259,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.03096,
#    'upperBound': 0.03421,
#    'underlyingDescription': 'Zilliqa',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.03259,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0015318627450980392,
#    'change24h': 0.04925949774629749,
#    'changeBod': 0.024198617221873036,
#    'volumeUsd24h': 1501951.6725,
#    'volume': 47448850.0,
#    'openInterest': 121664710.0,
#    'openInterestUsd': 3965052.8989},
#   {'name': 'ZM-0930',
#    'underlying': 'ZM',
#    'description': 'Zoom September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.005,
#    'last': 75.0,
#    'bid': 73.5,
#    'ask': 73.85,
#    'index': 73.56,
#    'mark': 73.8,
#    'imfFactor': 0.002,
#    'lowerBound': 69.9,
#    'upperBound': 77.55,
#    'underlyingDescription': 'Zoom',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 73.8,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.002702702702702703,
#    'change24h': -0.011386470194239785,
#    'changeBod': 0.0,
#    'volumeUsd24h': 365.30875,
#    'volume': 4.815,
#    'openInterest': 1118.025,
#    'openInterestUsd': 82510.245},
#   {'name': 'ZM-1230',
#    'underlying': 'ZM',
#    'description': 'Zoom December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.005,
#    'last': 75.25,
#    'bid': 73.5,
#    'ask': 73.85,
#    'index': 73.56,
#    'mark': 74.05,
#    'imfFactor': 0.002,
#    'lowerBound': 69.9,
#    'upperBound': 77.55,
#    'underlyingDescription': 'Zoom',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 74.05,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0020297699594046007,
#    'change24h': -0.013324450366422385,
#    'changeBod': 0.0033875338753387536,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 0.0,
#    'openInterestUsd': 0.0},
#   {'name': 'ZRX-PERP',
#    'underlying': 'ZRX',
#    'description': '0x Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.00025,
#    'sizeIncrement': 1.0,
#    'last': 0.27475,
#    'bid': 0.27475,
#    'ask': 0.275,
#    'index': 0.27494422333333335,
#    'mark': 0.27475,
#    'imfFactor': 0.0003,
#    'lowerBound': 0.26125,
#    'upperBound': 0.28875,
#    'underlyingDescription': '0x',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.27475,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.004528985507246377,
#    'change24h': 0.039735099337748346,
#    'changeBod': 0.026143790849673203,
#    'volumeUsd24h': 571843.249,
#    'volume': 2139970.0,
#    'openInterest': 4139162.0,
#    'openInterestUsd': 1137234.7595}]}

# %%
df = pd.DataFrame(res['result'])
df.head()
# Out:
#          name underlying                         description       type  \
# 0  1INCH-PERP      1INCH       1INCH Token Perpetual Futures  perpetual
# 1  1INCH-0930      1INCH  1INCH Token September 2022 Futures     future
# 2  1INCH-1230      1INCH   1INCH Token December 2022 Futures     future
# 3   AAPL-0930       AAPL        Apple September 2022 Futures     future
# 4   AAPL-1230       AAPL         Apple December 2022 Futures     future
#
#                       expiry  perpetual  expired  enabled  postOnly  \
# 0                       None       True    False     True     False
# 1  2022-09-30T03:00:00+00:00      False    False     True     False
# 2  2022-12-30T03:00:00+00:00      False    False     True     False
# 3  2022-09-30T20:00:00+00:00      False    False     True     False
# 4  2022-12-30T21:00:00+00:00      False    False     True     False
#
#    priceIncrement  ...      group  closeOnly  change1h  change24h  changeBod  \
# 0          0.0001  ...  perpetual      False -0.008340   0.036854   0.009289
# 1          0.0001  ...  quarterly      False -0.007591   0.030209   0.012260
# 2          0.0001  ...  quarterly      False -0.000490   0.036798   0.009577
# 3          0.0100  ...  quarterly      False  0.000000   0.012043   0.000000
# 4          0.0100  ...  quarterly      False -0.000989   0.008785   0.003110
#
#    volumeUsd24h      volume  openInterest  openInterestUsd indexAdjustment
# 0  4.709404e+06  7592508.00    8054861.00     5.076173e+06             NaN
# 1  6.461085e+04   106633.00     116624.00     7.318156e+04             NaN
# 2  2.645998e+02      445.00      21655.00     1.323987e+04             NaN
# 3  9.065571e+03       59.71       8738.28     1.321840e+06             NaN
# 4  1.369242e+05      899.97        676.52     1.025469e+05             NaN
#
# [5 rows x 36 columns]

# %%
df = pd.DataFrame(res['result'])
# Using iloc to make it readable
df.iloc[:,:4].head()
# Out:
#          name underlying                         description       type
# 0  1INCH-PERP      1INCH       1INCH Token Perpetual Futures  perpetual
# 1  1INCH-0930      1INCH  1INCH Token September 2022 Futures     future
# 2  1INCH-1230      1INCH   1INCH Token December 2022 Futures     future
# 3   AAPL-0930       AAPL        Apple September 2022 Futures     future
# 4   AAPL-1230       AAPL         Apple December 2022 Futures     future

# %% [markdown]
# ## 8. The Bottom Line

# %% [markdown]
# > FTX and its U.S. counterpart FTX.US are two of the best exchanges in the crypto space. If you’re interested in algo trading or simply looking for a great data source, FTX has an easy-to-use REST API to get you what you need.
