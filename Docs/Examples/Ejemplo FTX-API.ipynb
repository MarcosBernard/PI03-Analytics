# %% [markdown]
# # FTX.US API Python Tutorial

# %% [markdown]
# ## 1. Get imports

# %%
import datetime
import requests
import pandas as pd
from client import FtxClient
#from local_settings import ftx as settings

# %% [markdown]
# ## 2. Using the FTX Market API

# %% [markdown]
# > Using the Markets API is easy. The Markets API allows us to get all of the market data. We’ll be greeted with the following information when we make a request.

# %%
# GET /markets
api_url = 'https://ftx.us/api'
api = '/markets'
url = api_url+api
url

'https://ftx.us/api/markets'
# Out:
# 'https://ftx.us/api/markets'

# %% [markdown]
# > Now we’ll use requests to get the market response data.

# %%
markets = requests.get(url).json()
data = markets['result']
data
# Out:
# [{'name': 'AAVE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 79.18,
#   'bid': 79.14,
#   'ask': 79.21,
#   'price': 79.18,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.0007583417593528817,
#   'change24h': 0.07669295621430514,
#   'changeBod': 0.040473061760841,
#   'quoteVolume24h': 121597.742,
#   'volumeUsd24h': 121597.742,
#   'priceHigh24h': 79.34,
#   'priceLow24h': 72.66},
#  {'name': 'AAVE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 79.05,
#   'bid': 79.12,
#   'ask': 79.2,
#   'price': 79.12,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.00025271670457417233,
#   'change24h': 0.07602339181286549,
#   'changeBod': 0.03954802259887006,
#   'quoteVolume24h': 45627.0429,
#   'volumeUsd24h': 45625.522150660145,
#   'priceHigh24h': 79.33,
#   'priceLow24h': 72.68},
#  {'name': 'ALGO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3717,
#   'bid': 0.3704,
#   'ask': 0.3711,
#   'price': 0.3711,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.007754010695187166,
#   'change24h': 0.0051462621885157095,
#   'changeBod': 0.012827510917030568,
#   'quoteVolume24h': 236697.6745,
#   'volumeUsd24h': 236697.6745,
#   'priceHigh24h': 0.3764,
#   'priceLow24h': 0.3569},
#  {'name': 'ALGO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3739,
#   'bid': 0.3703,
#   'ask': 0.3712,
#   'price': 0.3712,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.007221182134260497,
#   'change24h': 0.005417118093174431,
#   'changeBod': 0.015317286652078774,
#   'quoteVolume24h': 13866.7899,
#   'volumeUsd24h': 13866.327719892633,
#   'priceHigh24h': 0.3754,
#   'priceLow24h': 0.357},
#  {'name': 'AUD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.652,
#   'bid': 0.6473,
#   'ask': 0.6481,
#   'price': 0.6481,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AUD',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.001848144155244109,
#   'changeBod': 0.0018550007729169888,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 0.652,
#   'priceLow24h': 0.6437},
#  {'name': 'AVAX/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-07,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.0008978,
#   'bid': 0.0008931,
#   'ask': 0.0008945,
#   'price': 0.0008945,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.003675651592782357,
#   'change24h': -0.02165591162638084,
#   'changeBod': -0.019296129810327814,
#   'quoteVolume24h': 0.77483091,
#   'volumeUsd24h': 15538.54762124068,
#   'priceHigh24h': 0.0009153,
#   'priceLow24h': 0.0008893},
#  {'name': 'AVAX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 17.9165,
#   'bid': 17.924,
#   'ask': 17.9245,
#   'price': 17.924,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.0031422930396818776,
#   'change24h': 0.04638197262033334,
#   'changeBod': 0.02314695892913206,
#   'quoteVolume24h': 2509384.8249,
#   'volumeUsd24h': 2509384.8249,
#   'priceHigh24h': 18.0995,
#   'priceLow24h': 16.9775},
#  {'name': 'AVAX/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 18.09,
#   'bid': 17.909,
#   'ask': 17.93,
#   'price': 17.93,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.0035290521577236223,
#   'change24h': 0.04581644259091837,
#   'changeBod': 0.022993096365607348,
#   'quoteVolume24h': 23639.79025,
#   'volumeUsd24h': 23639.002335790967,
#   'priceHigh24h': 18.091,
#   'priceLow24h': 16.992},
#  {'name': 'BAT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.308725,
#   'bid': 0.3083,
#   'ask': 0.308625,
#   'price': 0.308625,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BAT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0011353499310680398,
#   'change24h': 0.045477642276422765,
#   'changeBod': 0.030381437275686502,
#   'quoteVolume24h': 11685.36135,
#   'volumeUsd24h': 11685.36135,
#   'priceHigh24h': 0.3088,
#   'priceLow24h': 0.2918},
#  {'name': 'BCH/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.005937,
#   'bid': 0.005928,
#   'ask': 0.005939,
#   'price': 0.005937,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 432.0,
#   'change1h': 0.0008428860418071476,
#   'change24h': -0.01721569276609833,
#   'changeBod': -0.016727393176548526,
#   'quoteVolume24h': 9.138802759,
#   'volumeUsd24h': 183270.59496354786,
#   'priceHigh24h': 0.006116,
#   'priceLow24h': 0.005882},
#  {'name': 'BCH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 118.9,
#   'bid': 118.825,
#   'ask': 118.85,
#   'price': 118.85,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 720.0,
#   'change1h': -0.0016799664006719867,
#   'change24h': 0.04736726151134611,
#   'changeBod': 0.025231830925167134,
#   'quoteVolume24h': 1802244.5479,
#   'volumeUsd24h': 1802244.5479,
#   'priceHigh24h': 119.45,
#   'priceLow24h': 112.45},
#  {'name': 'BCH/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 119.225,
#   'bid': 118.85,
#   'ask': 118.875,
#   'price': 118.875,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 504.0,
#   'change1h': -0.001260239445494644,
#   'change24h': 0.0473568281938326,
#   'changeBod': 0.025668679896462467,
#   'quoteVolume24h': 307355.821075,
#   'volumeUsd24h': 307345.57690548355,
#   'priceHigh24h': 119.425,
#   'priceLow24h': 112.475},
#  {'name': 'BRZ/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.18773,
#   'bid': 0.18598,
#   'ask': 0.18614,
#   'price': 0.18614,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BRZ',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0016090967603518559,
#   'change24h': -0.021345951629863302,
#   'changeBod': -0.005662393162393162,
#   'quoteVolume24h': 156.6771,
#   'volumeUsd24h': 156.6771,
#   'priceHigh24h': 0.1905,
#   'priceLow24h': 0.18609},
#  {'name': 'BRZ/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.17802,
#   'bid': 0.18587,
#   'ask': 0.18614,
#   'price': 0.18587,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BRZ',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.001778592217311631,
#   'change24h': -0.022251446607048923,
#   'changeBod': -0.006042780748663101,
#   'quoteVolume24h': 0.8901,
#   'volumeUsd24h': 0.890070332967,
#   'priceHigh24h': 0.19039,
#   'priceLow24h': 0.17802},
#  {'name': 'BTC/AUD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 29566.0,
#   'bid': 30931.0,
#   'ask': 31001.0,
#   'price': 30931.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'AUD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': 0.002203285487476914,
#   'change24h': 0.06570424476295479,
#   'changeBod': 0.04616789555570588,
#   'quoteVolume24h': 14.6905,
#   'volumeUsd24h': 9.519444,
#   'priceHigh24h': 31340.0,
#   'priceLow24h': 28855.0},
#  {'name': 'BTC/BRZ',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 108050.0,
#   'bid': 107480.0,
#   'ask': 108000.0,
#   'price': 108000.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'BRZ',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': -0.0014792899408284023,
#   'change24h': 0.0971149939049167,
#   'changeBod': 0.057216974205863635,
#   'quoteVolume24h': 4165.778,
#   'volumeUsd24h': 775.0429969,
#   'priceHigh24h': 108725.0,
#   'priceLow24h': 98355.0},
#  {'name': 'BTC/EUR',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 19727.0,
#   'bid': 20772.0,
#   'ask': 20844.0,
#   'price': 20772.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'EUR',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': 0.0028000386212223617,
#   'change24h': 0.06534003487537184,
#   'changeBod': 0.0454476823191907,
#   'quoteVolume24h': 801037.2589,
#   'volumeUsd24h': 771398.8803207,
#   'priceHigh24h': 21025.0,
#   'priceLow24h': 19371.0},
#  {'name': 'BTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 20057.0,
#   'bid': 20054.0,
#   'ask': 20055.0,
#   'price': 20055.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': -0.0003489183531053733,
#   'change24h': 0.06885892447902787,
#   'changeBod': 0.04491220757567863,
#   'quoteVolume24h': 88987021.2567,
#   'volumeUsd24h': 88987021.2567,
#   'priceHigh24h': 20292.0,
#   'priceLow24h': 18687.0},
#  {'name': 'BTC/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 20043.0,
#   'bid': 20056.0,
#   'ask': 20057.0,
#   'price': 20056.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.00019940179461615153,
#   'change24h': 0.06885525474312514,
#   'changeBod': 0.04490986766697926,
#   'quoteVolume24h': 4483479.5776,
#   'volumeUsd24h': 4483330.143225678,
#   'priceHigh24h': 20296.0,
#   'priceLow24h': 18687.0},
#  {'name': 'CAD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.7371,
#   'bid': 0.7311,
#   'ask': 0.7316,
#   'price': 0.7316,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CAD',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.00041022836045398605,
#   'change24h': -0.004625850340136055,
#   'changeBod': 0.001917282936181868,
#   'quoteVolume24h': 49.3857,
#   'volumeUsd24h': 49.3857,
#   'priceHigh24h': 0.738,
#   'priceLow24h': 0.7259},
#  {'name': 'CUSDT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0220075,
#   'bid': 0.022005,
#   'ask': 0.0220275,
#   'price': 0.0220075,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CUSDT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.0009079559641357395,
#   'changeBod': 0.0,
#   'quoteVolume24h': 125.54291,
#   'volumeUsd24h': 125.54291,
#   'priceHigh24h': 0.0220325,
#   'priceLow24h': 0.022005},
#  {'name': 'CUSDT/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.022035,
#   'bid': 0.022005,
#   'ask': 0.0220275,
#   'price': 0.0220275,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CUSDT',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': -0.00011348161597821153,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 0.022035,
#   'priceLow24h': 0.0220275},
#  {'name': 'DAI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.0,
#   'bid': 0.9991,
#   'ask': 1.0,
#   'price': 1.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DAI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0007004903432402681,
#   'quoteVolume24h': 1438.69092,
#   'volumeUsd24h': 1438.69092,
#   'priceHigh24h': 1.0,
#   'priceLow24h': 0.9992},
#  {'name': 'DAI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.9991,
#   'bid': 0.999,
#   'ask': 1.0001,
#   'price': 0.9991,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DAI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': -0.00040020010005002504,
#   'changeBod': -0.0010997800439912018,
#   'quoteVolume24h': 5005.502,
#   'volumeUsd24h': 5005.33516661834,
#   'priceHigh24h': 1.0002,
#   'priceLow24h': 0.9991},
#  {'name': 'DOGE/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 3.11e-06,
#   'bid': 3.11e-06,
#   'ask': 3.12e-06,
#   'price': 3.11e-06,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.0,
#   'change24h': -0.043076923076923075,
#   'changeBod': -0.0220125786163522,
#   'quoteVolume24h': 5.09923464,
#   'volumeUsd24h': 102260.6342402113,
#   'priceHigh24h': 3.25e-06,
#   'priceLow24h': 3.09e-06},
#  {'name': 'DOGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.062474,
#   'bid': 0.0624775,
#   'ask': 0.0625005,
#   'price': 0.0624775,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.0012901261278587112,
#   'change24h': 0.024859748695908925,
#   'changeBod': 0.023214870619063216,
#   'quoteVolume24h': 2164570.3130095,
#   'volumeUsd24h': 2164570.3130095,
#   'priceHigh24h': 0.062799,
#   'priceLow24h': 0.0597665},
#  {'name': 'DOGE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.062438,
#   'bid': 0.0624695,
#   'ask': 0.062486,
#   'price': 0.0624695,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': 0.0011378478649326507,
#   'change24h': 0.02451844623572149,
#   'changeBod': 0.02315925674181687,
#   'quoteVolume24h': 126221.8963145,
#   'volumeUsd24h': 126217.68933869584,
#   'priceHigh24h': 0.062794,
#   'priceLow24h': 0.0597795},
#  {'name': 'ETH/AUD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 2095.3,
#   'bid': 2125.8,
#   'ask': 2140.2,
#   'price': 2125.8,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'AUD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': 0.0006119086843963285,
#   'change24h': 0.06199730229305091,
#   'changeBod': 0.035359438924605496,
#   'quoteVolume24h': 16.2839,
#   'volumeUsd24h': 10.5519672,
#   'priceHigh24h': 2442.2,
#   'priceLow24h': 1980.8},
#  {'name': 'ETH/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.0690475,
#   'bid': 0.06886,
#   'ask': 0.068885,
#   'price': 0.068885,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': 0.0008717762440973483,
#   'change24h': -0.0011962156088012469,
#   'changeBod': -0.008492263404102194,
#   'quoteVolume24h': 4.88493614,
#   'volumeUsd24h': 97963.06762995507,
#   'priceHigh24h': 0.0697475,
#   'priceLow24h': 0.0682575},
#  {'name': 'ETH/EUR',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1341.7,
#   'bid': 1427.1,
#   'ask': 1433.3,
#   'price': 1427.1,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'EUR',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': 0.0010521885521885522,
#   'change24h': 0.06143547787281517,
#   'changeBod': 0.03435529462926723,
#   'quoteVolume24h': 120.753,
#   'volumeUsd24h': 116.285139,
#   'priceHigh24h': 1440.8,
#   'priceLow24h': 1327.3},
#  {'name': 'ETH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1381.2,
#   'bid': 1381.1,
#   'ask': 1381.2,
#   'price': 1381.2,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': 0.0007970436924860518,
#   'change24h': 0.06796566921827882,
#   'changeBod': 0.036081314229990245,
#   'quoteVolume24h': 91183900.9301,
#   'volumeUsd24h': 91183900.9301,
#   'priceHigh24h': 1392.1,
#   'priceLow24h': 1278.6},
#  {'name': 'ETH/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1379.7,
#   'bid': 1381.1,
#   'ask': 1381.3,
#   'price': 1381.1,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': 0.00028970811907003694,
#   'change24h': 0.06797092483761212,
#   'changeBod': 0.03585089627240681,
#   'quoteVolume24h': 1894182.0872,
#   'volumeUsd24h': 1894118.9541110336,
#   'priceHigh24h': 1389.7,
#   'priceLow24h': 1278.2},
#  {'name': 'ETHW/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 11.137,
#   'bid': 11.109,
#   'ask': 11.158,
#   'price': 11.137,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETHW',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.027166317260656884,
#   'change24h': -0.009163701067615658,
#   'changeBod': 0.017821239261560956,
#   'quoteVolume24h': 1478805.453682,
#   'volumeUsd24h': 1478805.453682,
#   'priceHigh24h': 11.967,
#   'priceLow24h': 9.0},
#  {'name': 'EUR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.9633,
#   'bid': 0.9647,
#   'ask': 0.9648,
#   'price': 0.9647,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'EUR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.00041446482229820747,
#   'change24h': 0.00031107424305267526,
#   'changeBod': 0.0014533374857261497,
#   'quoteVolume24h': 488.6742,
#   'volumeUsd24h': 488.6742,
#   'priceHigh24h': 0.9706,
#   'priceLow24h': 0.9597},
#  {'name': 'GBP/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.0784,
#   'bid': 1.0766,
#   'ask': 1.0784,
#   'price': 1.0784,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'GBP',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0001854943424225561,
#   'change24h': 0.021018746449536073,
#   'changeBod': 0.0028829163954245327,
#   'quoteVolume24h': 186054.4264,
#   'volumeUsd24h': 186054.4264,
#   'priceHigh24h': 1.0919,
#   'priceLow24h': 1.054},
#  {'name': 'GRT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.10455,
#   'bid': 0.1045,
#   'ask': 0.1046,
#   'price': 0.10455,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'GRT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.002861230329041488,
#   'change24h': 0.0481203007518797,
#   'changeBod': 0.02149487054225696,
#   'quoteVolume24h': 261366.512,
#   'volumeUsd24h': 261366.512,
#   'priceHigh24h': 0.1053,
#   'priceLow24h': 0.09865},
#  {'name': 'KSHIB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.011059,
#   'bid': 0.011337,
#   'ask': 0.011384,
#   'price': 0.011337,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'KSHIB',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 8.821453775582216e-05,
#   'change24h': 0.03044900927104163,
#   'changeBod': 0.02153541178590737,
#   'quoteVolume24h': 847.09005,
#   'volumeUsd24h': 847.09005,
#   'priceHigh24h': 0.01151,
#   'priceLow24h': 0.010815},
#  {'name': 'LINK/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.00041195,
#   'bid': 0.00041335,
#   'ask': 0.0004136,
#   'price': 0.00041335,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.00989494258490105,
#   'change24h': 0.02504649721016739,
#   'changeBod': 0.001574993942330991,
#   'quoteVolume24h': 7.964560235,
#   'volumeUsd24h': 159722.2011881113,
#   'priceHigh24h': 0.0004164,
#   'priceLow24h': 0.0003989},
#  {'name': 'LINK/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 8.258,
#   'bid': 8.2925,
#   'ask': 8.296,
#   'price': 8.2925,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.01121882812023657,
#   'change24h': 0.09457497360084477,
#   'changeBod': 0.04815774505466726,
#   'quoteVolume24h': 1871168.1307,
#   'volumeUsd24h': 1871168.1307,
#   'priceHigh24h': 8.313,
#   'priceLow24h': 7.4665},
#  {'name': 'LINK/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 8.282,
#   'bid': 8.289,
#   'ask': 8.2955,
#   'price': 8.289,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': 0.010792024876531919,
#   'change24h': 0.09389640382711976,
#   'changeBod': 0.04798027688223023,
#   'quoteVolume24h': 277260.9763,
#   'volumeUsd24h': 277251.73519165994,
#   'priceHigh24h': 8.3165,
#   'priceLow24h': 7.471},
#  {'name': 'LTC/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.0027375,
#   'bid': 0.00273425,
#   'ask': 0.0027355,
#   'price': 0.0027355,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.0024614823593764245,
#   'change24h': -0.026339206264459868,
#   'changeBod': -0.01574165692183143,
#   'quoteVolume24h': 5.0597887025,
#   'volumeUsd24h': 101469.58090147932,
#   'priceHigh24h': 0.00281675,
#   'priceLow24h': 0.00272475},
#  {'name': 'LTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 54.815,
#   'bid': 54.85,
#   'ask': 54.875,
#   'price': 54.85,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.0035425560904714325,
#   'change24h': 0.04050080622213791,
#   'changeBod': 0.02840536233242711,
#   'quoteVolume24h': 902780.24605,
#   'volumeUsd24h': 902780.24605,
#   'priceHigh24h': 55.4,
#   'priceLow24h': 51.895},
#  {'name': 'LTC/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 54.775,
#   'bid': 54.84,
#   'ask': 54.855,
#   'price': 54.84,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.003271537622682661,
#   'change24h': 0.040409789413773475,
#   'changeBod': 0.02841068917018284,
#   'quoteVolume24h': 524301.2441,
#   'volumeUsd24h': 524283.76913953415,
#   'priceHigh24h': 55.39,
#   'priceLow24h': 51.9},
#  {'name': 'MATIC/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 3.876e-05,
#   'bid': 3.867e-05,
#   'ask': 3.87e-05,
#   'price': 3.87e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MATIC',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.002577319587628866,
#   'change24h': -0.010230179028132993,
#   'changeBod': -0.014514896867838044,
#   'quoteVolume24h': 1.4952629,
#   'volumeUsd24h': 29986.173083782163,
#   'priceHigh24h': 3.966e-05,
#   'priceLow24h': 3.82e-05},
#  {'name': 'MATIC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.775344,
#   'bid': 0.776019,
#   'ask': 0.77617,
#   'price': 0.776019,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MATIC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.0033328452866246945,
#   'change24h': 0.05747422469686935,
#   'changeBod': 0.028894522331502758,
#   'quoteVolume24h': 1559980.99697,
#   'volumeUsd24h': 1559980.99697,
#   'priceHigh24h': 0.782243,
#   'priceLow24h': 0.726466},
#  {'name': 'MKR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 755.0,
#   'bid': 755.0,
#   'ask': 756.0,
#   'price': 755.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MKR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0013227513227513227,
#   'change24h': 0.11192930780559647,
#   'changeBod': 0.05299860529986053,
#   'quoteVolume24h': 214704.246,
#   'volumeUsd24h': 214704.246,
#   'priceHigh24h': 758.0,
#   'priceLow24h': 674.0},
#  {'name': 'NEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.77,
#   'bid': 3.761,
#   'ask': 3.764,
#   'price': 3.764,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'NEAR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.004759386567953464,
#   'change24h': 0.04006631666206134,
#   'changeBod': 0.022270505160239002,
#   'quoteVolume24h': 114907.5765,
#   'volumeUsd24h': 114907.5765,
#   'priceHigh24h': 3.807,
#   'priceLow24h': 3.558},
#  {'name': 'NEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.749,
#   'bid': 3.759,
#   'ask': 3.763,
#   'price': 3.759,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'NEAR',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.006081438392384982,
#   'change24h': 0.03954646017699115,
#   'changeBod': 0.021745039412883936,
#   'quoteVolume24h': 7516.5415,
#   'volumeUsd24h': 7516.290973671805,
#   'priceHigh24h': 3.805,
#   'priceLow24h': 3.559},
#  {'name': 'PAXG/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 1622.4,
#   'bid': 1620.6,
#   'ask': 1623.5,
#   'price': 1622.4,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'PAXG',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.002029894814541428,
#   'changeBod': 0.002285784889108544,
#   'quoteVolume24h': 53931.92619,
#   'volumeUsd24h': 53931.92619,
#   'priceHigh24h': 1641.0,
#   'priceLow24h': 1611.0},
#  {'name': 'PAXG/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 1619.0,
#   'bid': 1620.6,
#   'ask': 1623.4,
#   'price': 1620.6,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'PAXG',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': -0.007957884427032321,
#   'changeBod': 0.0009882643607164916,
#   'quoteVolume24h': 649.72285,
#   'volumeUsd24h': 649.7011947374095,
#   'priceHigh24h': 1640.2,
#   'priceLow24h': 1613.2},
#  {'name': 'SHIB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 100000.0,
#   'minProvideSize': 100000.0,
#   'last': 1.135e-05,
#   'bid': 1.136e-05,
#   'ask': 1.138e-05,
#   'price': 1.136e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SHIB',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0026338893766461808,
#   'change24h': 0.03555150410209663,
#   'changeBod': 0.02158273381294964,
#   'quoteVolume24h': 36237.715,
#   'volumeUsd24h': 36237.715,
#   'priceHigh24h': 1.153e-05,
#   'priceLow24h': 1.078e-05},
#  {'name': 'SOL/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.00173275,
#   'bid': 0.0017315,
#   'ask': 0.00173275,
#   'price': 0.00173275,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.0008664259927797834,
#   'change24h': 0.008732353369233009,
#   'changeBod': -0.015343088506890184,
#   'quoteVolume24h': 17.6071361275,
#   'volumeUsd24h': 353095.5201449384,
#   'priceHigh24h': 0.00178225,
#   'priceLow24h': 0.001703},
#  {'name': 'SOL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 34.745,
#   'bid': 34.745,
#   'ask': 34.7475,
#   'price': 34.745,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.0005034160373966199,
#   'change24h': 0.0776985111662531,
#   'changeBod': 0.028947952913304213,
#   'quoteVolume24h': 24191681.1132,
#   'volumeUsd24h': 24191681.1132,
#   'priceHigh24h': 35.005,
#   'priceLow24h': 31.8575},
#  {'name': 'SOL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 34.7525,
#   'bid': 34.73,
#   'ask': 34.74,
#   'price': 34.74,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.0001439055979277594,
#   'change24h': 0.0777105630525826,
#   'changeBod': 0.02879988154290368,
#   'quoteVolume24h': 1891945.22185,
#   'volumeUsd24h': 1891882.1633157558,
#   'priceHigh24h': 35.015,
#   'priceLow24h': 31.8725},
#  {'name': 'SUSHI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 5.59e-05,
#   'bid': 5.615e-05,
#   'ask': 5.634e-05,
#   'price': 5.615e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 576.0,
#   'change1h': 0.009892086330935251,
#   'change24h': 0.032358889501746646,
#   'changeBod': 0.020537986186841148,
#   'quoteVolume24h': 6.254466995,
#   'volumeUsd24h': 125427.7959139312,
#   'priceHigh24h': 5.616e-05,
#   'priceLow24h': 5.414e-05},
#  {'name': 'SUSHI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 1.129,
#   'bid': 1.1287,
#   'ask': 1.1301,
#   'price': 1.129,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.01301031852848811,
#   'change24h': 0.1044805321854823,
#   'changeBod': 0.06730951030440536,
#   'quoteVolume24h': 233522.6152,
#   'volumeUsd24h': 233522.6152,
#   'priceHigh24h': 1.129,
#   'priceLow24h': 1.0126},
#  {'name': 'SUSHI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 1.1265,
#   'bid': 1.1287,
#   'ask': 1.1296,
#   'price': 1.1287,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.0115612116866822,
#   'change24h': 0.10440313111545989,
#   'changeBod': 0.06621953523521633,
#   'quoteVolume24h': 91205.62315,
#   'volumeUsd24h': 91202.5832665804,
#   'priceHigh24h': 1.1287,
#   'priceLow24h': 1.0124},
#  {'name': 'TRX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0603525,
#   'bid': 0.060345,
#   'ask': 0.060385,
#   'price': 0.0603525,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'TRX',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 720.0,
#   'change1h': 4.142502071251036e-05,
#   'change24h': 0.01830682920656346,
#   'changeBod': 0.012668316624019463,
#   'quoteVolume24h': 31618.28151,
#   'volumeUsd24h': 31618.28151,
#   'priceHigh24h': 0.06061,
#   'priceLow24h': 0.0589825},
#  {'name': 'TRX/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0604575,
#   'bid': 0.0603475,
#   'ask': 0.0603875,
#   'price': 0.0603875,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'TRX',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 504.0,
#   'change1h': 0.0007042837020465656,
#   'change24h': 0.018467765737656534,
#   'changeBod': 0.013510678471027568,
#   'quoteVolume24h': 26030.6417425,
#   'volumeUsd24h': 26029.77414121072,
#   'priceHigh24h': 0.06061,
#   'priceLow24h': 0.058975},
#  {'name': 'UNI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 0.05,
#   'minProvideSize': 0.05,
#   'last': 0.00032105,
#   'bid': 0.0003209,
#   'ask': 0.00032135,
#   'price': 0.00032105,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 168.0,
#   'change1h': 0.017913760304375397,
#   'change24h': 0.07123790457123791,
#   'changeBod': 0.04118696286687206,
#   'quoteVolume24h': 13.1454245825,
#   'volumeUsd24h': 263619.84691163665,
#   'priceHigh24h': 0.00032435,
#   'priceLow24h': 0.0002967},
#  {'name': 'UNI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 6.44,
#   'bid': 6.44,
#   'ask': 6.445,
#   'price': 6.44,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.017699115044247787,
#   'change24h': 0.14570361145703611,
#   'changeBod': 0.08728684788114131,
#   'quoteVolume24h': 363173.1825,
#   'volumeUsd24h': 363173.1825,
#   'priceHigh24h': 6.45,
#   'priceLow24h': 5.555},
#  {'name': 'UNI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.05,
#   'minProvideSize': 0.05,
#   'last': 6.452,
#   'bid': 6.436,
#   'ask': 6.446,
#   'price': 6.446,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.019291587602783048,
#   'change24h': 0.1457518663348738,
#   'changeBod': 0.08903531001858422,
#   'quoteVolume24h': 146950.3616,
#   'volumeUsd24h': 146945.46374444786,
#   'priceHigh24h': 6.452,
#   'priceLow24h': 5.557},
#  {'name': 'USDT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.9999,
#   'bid': 0.9998,
#   'ask': 0.9999,
#   'price': 0.9999,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'USDT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': 0.0,
#   'change24h': -0.0001,
#   'changeBod': 0.0,
#   'quoteVolume24h': 1261365.709285,
#   'volumeUsd24h': 1261365.709285,
#   'priceHigh24h': 1.0001,
#   'priceLow24h': 0.9998},
#  {'name': 'WBTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 20257.0,
#   'bid': 20053.0,
#   'ask': 20061.0,
#   'price': 20061.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'WBTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0008466978782747285,
#   'change24h': 0.06889386189258312,
#   'changeBod': 0.04511591560302162,
#   'quoteVolume24h': 1160.7833,
#   'volumeUsd24h': 1160.7833,
#   'priceHigh24h': 20295.0,
#   'priceLow24h': 18704.0},
#  {'name': 'YFI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.00025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.42725,
#   'bid': 0.427,
#   'ask': 0.43,
#   'price': 0.42725,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 576.0,
#   'change1h': 0.0017584994138335288,
#   'change24h': -0.007549361207897794,
#   'changeBod': -0.014985590778097982,
#   'quoteVolume24h': 1.657088,
#   'volumeUsd24h': 33231.432133478615,
#   'priceHigh24h': 0.43675,
#   'priceLow24h': 0.42275},
#  {'name': 'YFI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 8580.0,
#   'bid': 8570.0,
#   'ask': 8580.0,
#   'price': 8580.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': 0.0017513134851138354,
#   'change24h': 0.06451612903225806,
#   'changeBod': 0.032490974729241874,
#   'quoteVolume24h': 161441.705,
#   'volumeUsd24h': 161441.705,
#   'priceHigh24h': 8620.0,
#   'priceLow24h': 7940.0},
#  {'name': 'YFI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 8585.0,
#   'bid': 8570.0,
#   'ask': 8585.0,
#   'price': 8585.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': 0.0011661807580174927,
#   'change24h': 0.06513647642679901,
#   'changeBod': 0.03309265944645006,
#   'quoteVolume24h': 65321.33,
#   'volumeUsd24h': 65319.1528400711,
#   'priceHigh24h': 8615.0,
#   'priceLow24h': 7955.0}]

# %% [markdown]
# > Since JSON format isn’t that easy to read, let’s convert it into a pandas dataframe.

# %%
df = pd.DataFrame(data)
df = df.set_index('name')
# using iloc to make it readable
df.iloc[:,:4].head()
# Out:
#            enabled  postOnly  priceIncrement  sizeIncrement
# name
# AAVE/USD      True     False          0.0100           0.01
# AAVE/USDT     True     False          0.0100           0.01
# ALGO/USD      True     False          0.0001           1.00
# ALGO/USDT     True     False          0.0001           1.00
# AUD/USD       True     False          0.0001           1.00

# %% [markdown]
# > Pretty easy, right? This will become second nature soon enough.

# %% [markdown]
# ## 3. Get an Individual Market Data

# %% [markdown]
# > You can use the following to get a single market.

# %%
# GET /markets/{market_name}
market_name = 'ETH/USD'
path = f'/markets/{market_name}'
url = api_url + path
url

'https://ftx.us/api/markets/ETH/USD'
# Out:
# 'https://ftx.us/api/markets/ETH/USD'

# %% [markdown]
# > Now let’s make the request and output the response as a dataframe.

# %%
res = requests.get(url).json()
df = pd.DataFrame(res)['result']
df = pd.DataFrame(data)
df = df.set_index('name')
# using iloc to make it readable
df.iloc[:,:].head()
# Out:
#            enabled  postOnly  priceIncrement  sizeIncrement  minProvideSize  \
# name
# AAVE/USD      True     False          0.0100           0.01            0.01
# AAVE/USDT     True     False          0.0100           0.01            0.01
# ALGO/USD      True     False          0.0001           1.00            1.00
# ALGO/USDT     True     False          0.0001           1.00            1.00
# AUD/USD       True     False          0.0001           1.00            1.00
#
#               last      bid      ask    price  type  ... restricted  \
# name                                                 ...
# AAVE/USD   79.1800  79.1400  79.2100  79.1800  spot  ...      False
# AAVE/USDT  79.0500  79.1200  79.2000  79.1200  spot  ...      False
# ALGO/USD    0.3717   0.3704   0.3711   0.3711  spot  ...      False
# ALGO/USDT   0.3739   0.3703   0.3712   0.3712  spot  ...      False
# AUD/USD     0.6520   0.6473   0.6481   0.6481  spot  ...      False
#
#           highLeverageFeeExempt largeOrderThreshold  change1h  change24h  \
# name
# AAVE/USD                   True               960.0  0.000758   0.076693
# AAVE/USDT                  True               672.0 -0.000253   0.076023
# ALGO/USD                   True               960.0 -0.007754   0.005146
# ALGO/USDT                  True               672.0 -0.007221   0.005417
# AUD/USD                    True               280.0  0.000000  -0.001848
#
#            changeBod  quoteVolume24h   volumeUsd24h  priceHigh24h  priceLow24h
# name
# AAVE/USD    0.040473     121597.7420  121597.742000       79.3400      72.6600
# AAVE/USDT   0.039548      45627.0429   45625.522151       79.3300      72.6800
# ALGO/USD    0.012828     236697.6745  236697.674500        0.3764       0.3569
# ALGO/USDT   0.015317      13866.7899   13866.327720        0.3754       0.3570
# AUD/USD     0.001855          0.0000       0.000000        0.6520       0.6437
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 4. Get Historical Data

# %% [markdown]
# > You can also get historical data for any of the markets. Let’s get the data as daily bars starting from 2022.

# %%
# GET /markets/{market_name}/candles?resolution={resolution}&start_time={start_time}&end_time={end_time}
# Days is 60 seconds * 60 minutes * 24
resolution = 60*60*24
resolution
# Out:
# 86400

# %%
start = datetime.datetime(2022,1,1).timestamp()
start
# Out:
# 1641016800.0

# %% [markdown]
# > We’ll now construct the URL string and request as we’ve done above.

# %%
'''
# GET /markets/{market_name}
market_name = 'ETH/USD'
path = f'/markets/{market_name}'
url = api_url + path
url

'https://ftx.us/api/markets/ETH/USD'
'''
path = f'/markets/{market_name}/candles?resolution={resolution}&start={start}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/candles?resolution=86400&start=1641016800.0'

# %% [markdown]
# > And we’ll put the data into the dataframe and clean up the index.

# %%
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df['date'] = pd.to_datetime(df['startTime'])
df = df.set_index('date')
df = df.drop(columns=['startTime', 'time'])
df
# Out:
#                                open      high       low     close  \
# date
# 2020-03-23 00:00:00+00:00   130.355   136.935   129.625   136.775
# 2020-03-24 00:00:00+00:00   136.770   144.210   132.855   138.790
# 2020-03-25 00:00:00+00:00   138.785   142.980   132.750   136.115
# 2020-03-26 00:00:00+00:00   136.105   140.125   133.615   138.890
# 2020-03-27 00:00:00+00:00   138.890   141.955   129.320   131.425
# ...                             ...       ...       ...       ...
# 2022-09-23 00:00:00+00:00  1326.300  1361.100  1261.800  1327.500
# 2022-09-24 00:00:00+00:00  1327.500  1351.100  1306.700  1316.900
# 2022-09-25 00:00:00+00:00  1316.900  1336.200  1269.900  1294.600
# 2022-09-26 00:00:00+00:00  1294.600  1340.000  1278.600  1336.300
# 2022-09-27 00:00:00+00:00  1336.300  1392.100  1332.600  1380.700
#
#                                  volume
# date
# 2020-03-23 00:00:00+00:00  0.000000e+00
# 2020-03-24 00:00:00+00:00  0.000000e+00
# 2020-03-25 00:00:00+00:00  0.000000e+00
# 2020-03-26 00:00:00+00:00  0.000000e+00
# 2020-03-27 00:00:00+00:00  0.000000e+00
# ...                                 ...
# 2022-09-23 00:00:00+00:00  1.169653e+08
# 2022-09-24 00:00:00+00:00  4.605234e+07
# 2022-09-25 00:00:00+00:00  4.395761e+07
# 2022-09-26 00:00:00+00:00  4.590856e+07
# 2022-09-27 00:00:00+00:00  5.074552e+07
#
# [918 rows x 5 columns]

# %% [markdown]
# ## 5. Get Order Book Data

# %% [markdown]
# > We can also get the order book at varying depths.
# Let’s take a look at the order book for ETH/USD.

# %%
# GET /markets/{market_name}/orderbook?depth={depth}
depth = 20
path =  f'/markets/{market_name}/orderbook?depth={depth}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/orderbook?depth=20'

# %%
res = requests.get(url).json()
bids = pd.DataFrame(res['result']['bids'])
asks = pd.DataFrame(res['result']['asks'])
bids.columns = ['Bid Price', 'Bid Amount']
asks.columns = ['Ask Price','Ask Amount']
bids.head()
# Out:
#    Bid Price  Bid Amount
# 0     1380.7      36.436
# 1     1380.6       4.403
# 2     1380.5       4.450
# 3     1380.4       0.123
# 4     1380.3       1.142

# %% [markdown]
# > Let’s show the ask dataframe.

# %%
asks.head()
# Out:
#    Ask Price  Ask Amount
# 0     1380.8      12.883
# 1     1380.9      37.500
# 2     1381.0       4.450
# 3     1381.1      47.407
# 4     1381.2       6.136

# %% [markdown]
# > Now let’s merge the two dataframes and rename the columns.

# %%
df = pd.merge(bids, asks, left_index=True, right_index=True)
df.head()
# Out:
#    Bid Price  Bid Amount  Ask Price  Ask Amount
# 0     1380.7      36.436     1380.8      12.883
# 1     1380.6       4.403     1380.9      37.500
# 2     1380.5       4.450     1381.0       4.450
# 3     1380.4       0.123     1381.1      47.407
# 4     1380.3       1.142     1381.2       6.136

# %% [markdown]
# > And we can get the summary statistics using describe. Notice the depth as the count variable.

# %%
df.describe()
# Out:
#          Bid Price  Bid Amount   Ask Price  Ask Amount
# count    20.000000   20.000000    20.00000   20.000000
# mean   1379.705000   20.245300  1381.77000   25.777400
# std       0.643571   47.604213     0.62078   50.712469
# min    1378.600000    0.066000  1380.80000    0.012000
# 25%    1379.175000    4.403000  1381.27500    4.450000
# 50%    1379.750000    7.791000  1381.75000    7.521500
# 75%    1380.225000   11.313750  1382.22500   23.221000
# max    1380.700000  217.685000  1382.80000  228.255000

# %% [markdown]
# ## 6. Get Trades

# %% [markdown]
# > Getting the recent trades for any market is also easy.

# %%
# GET /markets/{market_name}/trades
path = f'/markets/{market_name}/trades'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/trades'

# %%
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df.head()
# Out:
#          id   price   size  side  liquidation  \
# 0  44773725  1380.7  0.014  sell        False
# 1  44776045  1381.2  0.001   buy        False
# 2  44773719  1381.3  0.006  sell        False
# 3  44776044  1381.3  0.014  sell        False
# 4  44773716  1381.3  0.003   buy        False
#
#                                time
# 0  2022-09-27T05:11:13.114147+00:00
# 1  2022-09-27T05:11:04.117614+00:00
# 2  2022-09-27T05:11:02.598970+00:00
# 3  2022-09-27T05:10:58.104716+00:00
# 4  2022-09-27T05:10:49.099016+00:00

# %% [markdown]
# ## 7. Working with FTX Futures

# %% [markdown]
# > Now that you’ve learned how to use the Markets API, using the Futures API is just as easy. I’ll get you started. One thing to note is that futures are not available through the ftx.us API.<br><br>
# First, check out the futures API documentation. You’ll notice we need to make a get request to /futures. Let’s create the request URL and use requests to get the data.

# %%
url = 'https://ftx.com/api/futures'
res = requests.get(url).json()
res
# Out:
# {'success': True,
#  'result': [{'name': '1INCH-PERP',
#    'underlying': '1INCH',
#    'description': '1INCH Token Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6323,
#    'bid': 0.6323,
#    'ask': 0.6325,
#    'index': 0.6325289266666667,
#    'mark': 0.6323,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.6007,
#    'upperBound': 0.6641,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.6323,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.005661267494889133,
#    'change24h': 0.041337285902503296,
#    'changeBod': 0.01265214606021781,
#    'volumeUsd24h': 4729528.7741,
#    'volume': 7635032.0,
#    'openInterest': 8059808.0,
#    'openInterestUsd': 5096216.5984},
#   {'name': '1INCH-0930',
#    'underlying': '1INCH',
#    'description': '1INCH Token September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6284,
#    'bid': 0.6266,
#    'ask': 0.6294,
#    'index': 0.6325289266666667,
#    'mark': 0.6284,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.5968,
#    'upperBound': 0.6641,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.6284,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.006167958247667246,
#    'change24h': 0.03304290646062798,
#    'changeBod': 0.013711889014357154,
#    'volumeUsd24h': 64718.0523,
#    'volume': 106809.0,
#    'openInterest': 116624.0,
#    'openInterestUsd': 73286.5216},
#   {'name': '1INCH-1230',
#    'underlying': '1INCH',
#    'description': '1INCH Token December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6117,
#    'bid': 0.6105,
#    'ask': 0.6131,
#    'index': 0.6325289266666667,
#    'mark': 0.6117,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.5801,
#    'upperBound': 0.6641,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.6117,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0039081582804103565,
#    'change24h': 0.038363605499915125,
#    'changeBod': 0.010072655217965654,
#    'volumeUsd24h': 416.7424,
#    'volume': 703.0,
#    'openInterest': 21655.0,
#    'openInterestUsd': 13246.3635},
#   {'name': 'AAPL-0930',
#    'underlying': 'AAPL',
#    'description': 'Apple September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 151.27,
#    'bid': 151.13,
#    'ask': 152.51,
#    'index': 152.24,
#    'mark': 151.27,
#    'imfFactor': 0.00125,
#    'lowerBound': 143.66,
#    'upperBound': 159.85,
#    'underlyingDescription': 'Apple',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 151.27,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.012042550344550746,
#    'changeBod': 0.0,
#    'volumeUsd24h': 9065.5713,
#    'volume': 59.71,
#    'openInterest': 8738.28,
#    'openInterestUsd': 1321839.6156},
#   {'name': 'AAPL-1230',
#    'underlying': 'AAPL',
#    'description': 'Apple December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 151.75,
#    'bid': 151.74,
#    'ask': 152.33,
#    'index': 152.24,
#    'mark': 151.75,
#    'imfFactor': 0.00125,
#    'lowerBound': 144.16,
#    'upperBound': 159.85,
#    'underlyingDescription': 'Apple',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 151.75,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.00013181308903974164,
#    'change24h': 0.009916145348063357,
#    'changeBod': 0.004235325259744557,
#    'volumeUsd24h': 136893.8353,
#    'volume': 899.78,
#    'openInterest': 676.34,
#    'openInterestUsd': 102634.595},
#   {'name': 'AAVE-PERP',
#    'underlying': 'AAVE',
#    'description': 'Aave Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 79.25,
#    'bid': 79.24,
#    'ask': 79.25,
#    'index': 79.19573680266667,
#    'mark': 79.25,
#    'imfFactor': 0.0025,
#    'lowerBound': 75.24,
#    'upperBound': 83.19,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 79.25,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0011369378473976757,
#    'change24h': 0.0779379760609358,
#    'changeBod': 0.04002624671916011,
#    'volumeUsd24h': 12577079.0685,
#    'volume': 166366.38,
#    'openInterest': 179600.53,
#    'openInterestUsd': 14233342.0025},
#   {'name': 'AAVE-0930',
#    'underlying': 'AAVE',
#    'description': 'Aave September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 78.6,
#    'bid': 79.09,
#    'ask': 79.66,
#    'index': 79.19573680266667,
#    'mark': 79.09,
#    'imfFactor': 0.0025,
#    'lowerBound': 75.12,
#    'upperBound': 83.15,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 79.09,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0007592053650512464,
#    'change24h': 0.07182545060306275,
#    'changeBod': 0.04065789473684211,
#    'volumeUsd24h': 7795.1458,
#    'volume': 101.01,
#    'openInterest': 2267.76,
#    'openInterestUsd': 179357.1384},
#   {'name': 'AAVE-1230',
#    'underlying': 'AAVE',
#    'description': 'Aave December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 78.56,
#    'bid': 78.04,
#    'ask': 78.8,
#    'index': 79.19573680266667,
#    'mark': 78.56,
#    'imfFactor': 0.0025,
#    'lowerBound': 74.61,
#    'upperBound': 83.15,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 78.56,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.07601698397479797,
#    'changeBod': 0.04066763809776129,
#    'volumeUsd24h': 537.1674,
#    'volume': 7.2,
#    'openInterest': 984.51,
#    'openInterestUsd': 77343.1056},
#   {'name': 'ABNB-0930',
#    'underlying': 'ABNB',
#    'description': 'Airbnb September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.025,
#    'last': 105.18,
#    'bid': 103.86,
#    'ask': 104.375,
#    'index': 103.565,
#    'mark': 104.375,
#    'imfFactor': 0.005,
#    'lowerBound': 98.39,
#    'upperBound': 109.63,
#    'underlyingDescription': 'Airbnb',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 104.375,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 4.790648653827728e-05,
#    'change24h': 0.020732482519192217,
#    'changeBod': 0.0035575212730157204,
#    'volumeUsd24h': 68.367,
#    'volume': 0.65,
#    'openInterest': 150.0,
#    'openInterestUsd': 15656.25},
#   {'name': 'ABNB-1230',
#    'underlying': 'ABNB',
#    'description': 'Airbnb December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.025,
#    'last': 110.24,
#    'bid': 103.95,
#    'ask': 104.355,
#    'index': 103.565,
#    'mark': 104.355,
#    'imfFactor': 0.005,
#    'lowerBound': 98.39,
#    'upperBound': 109.615,
#    'underlyingDescription': 'Airbnb',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 104.355,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0001437607820586544,
#    'change24h': 0.018147226693985073,
#    'changeBod': 0.0014394702749388226,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 100.0,
#    'openInterestUsd': 10435.5},
#   {'name': 'ACB-0930',
#    'underlying': 'ACB',
#    'description': 'Aurora Cannabis Inc September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 1.174,
#    'bid': 1.166,
#    'ask': 1.177,
#    'index': 1.177,
#    'mark': 1.174,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.116,
#    'upperBound': 1.235,
#    'underlyingDescription': 'Aurora Cannabis Inc',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1.174,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.01839464882943144,
#    'changeBod': 0.003418803418803419,
#    'volumeUsd24h': 11936.1607,
#    'volume': 9625.5,
#    'openInterest': 0.1,
#    'openInterestUsd': 0.1174},
#   {'name': 'ACB-1230',
#    'underlying': 'ACB',
#    'description': 'Aurora Cannabis Inc December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 1.25,
#    'bid': 1.15,
#    'ask': 1.235,
#    'index': 1.177,
#    'mark': 1.235,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.119,
#    'upperBound': 1.293,
#    'underlyingDescription': 'Aurora Cannabis Inc',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1.235,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.012,
#    'changeBod': 0.0,
#    'volumeUsd24h': 2008.8231,
#    'volume': 1675.8,
#    'openInterest': 2429.2,
#    'openInterestUsd': 3000.062},
#   {'name': 'ADA-PERP',
#    'underlying': 'ADA',
#    'description': 'Cardano Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.45769,
#    'bid': 0.45767,
#    'ask': 0.45769,
#    'index': 0.45772804005555556,
#    'mark': 0.457715,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.434845,
#    'upperBound': 0.48061,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.457715,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.006285143613903302,
#    'change24h': 0.038679737672181,
#    'changeBod': 0.023696099481123636,
#    'volumeUsd24h': 47924188.463525,
#    'volume': 107329588.0,
#    'openInterest': 123114382.0,
#    'openInterestUsd': 56351299.35713},
#   {'name': 'ADA-0930',
#    'underlying': 'ADA',
#    'description': 'Cardano September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.457035,
#    'bid': 0.45692,
#    'ask': 0.457145,
#    'index': 0.45772804005555556,
#    'mark': 0.457035,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.434145,
#    'upperBound': 0.48061,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.457035,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.005754002784545771,
#    'change24h': 0.03890480087288598,
#    'changeBod': 0.02554695388757994,
#    'volumeUsd24h': 479508.42298,
#    'volume': 1064364.0,
#    'openInterest': 7351451.0,
#    'openInterestUsd': 3359870.407785},
#   {'name': 'ADA-1230',
#    'underlying': 'ADA',
#    'description': 'Cardano December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.44747,
#    'bid': 0.44747,
#    'ask': 0.44863,
#    'index': 0.45772804005555556,
#    'mark': 0.447535,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.42443,
#    'upperBound': 0.48061,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.447535,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.005776044964288491,
#    'change24h': 0.03905134485680787,
#    'changeBod': 0.023311382448438285,
#    'volumeUsd24h': 32254.72061,
#    'volume': 73117.0,
#    'openInterest': 3302389.0,
#    'openInterestUsd': 1477934.661115},
#   {'name': 'AGLD-PERP',
#    'underlying': 'AGLD',
#    'description': 'Adventure Gold Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 0.3345,
#    'bid': 0.3345,
#    'ask': 0.335,
#    'index': 0.3341851311111111,
#    'mark': 0.3345,
#    'imfFactor': 0.001,
#    'lowerBound': 0.3175,
#    'upperBound': 0.351,
#    'underlyingDescription': 'Adventure Gold',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.3345,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0029985007496251873,
#    'change24h': 0.019817073170731708,
#    'changeBod': 0.02450229709035222,
#    'volumeUsd24h': 1479677.51685,
#    'volume': 4560354.0,
#    'openInterest': 1440023.8,
#    'openInterestUsd': 481687.9611},
#   {'name': 'ALCX-PERP',
#    'underlying': 'ALCX',
#    'description': 'Alchemix Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 21.5,
#    'bid': 21.5,
#    'ask': 21.6,
#    'index': 21.7,
#    'mark': 21.5,
#    'imfFactor': 0.025,
#    'lowerBound': 20.6,
#    'upperBound': 22.7,
#    'underlyingDescription': 'Alchemix',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 21.5,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.028708133971291867,
#    'change24h': 0.06965174129353234,
#    'changeBod': 0.06435643564356436,
#    'volumeUsd24h': 232367.9126,
#    'volume': 11243.985,
#    'openInterest': 23839.769,
#    'openInterestUsd': 512555.0335},
#   {'name': 'ALGO-PERP',
#    'underlying': 'ALGO',
#    'description': 'Algorand Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.3706,
#    'bid': 0.3705,
#    'ask': 0.3706,
#    'index': 0.3707827796666667,
#    'mark': 0.3707,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3523,
#    'upperBound': 0.3893,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.3707,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.00669882100750268,
#    'change24h': 0.005424464334147003,
#    'changeBod': 0.0098065922092073,
#    'volumeUsd24h': 31358733.7102,
#    'volume': 85610578.0,
#    'openInterest': 42371799.0,
#    'openInterestUsd': 15707225.8893},
#   {'name': 'ALGO-0930',
#    'underlying': 'ALGO',
#    'description': 'Algorand September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.3707,
#    'bid': 0.3706,
#    'ask': 0.3723,
#    'index': 0.3707827796666667,
#    'mark': 0.3707,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3522,
#    'upperBound': 0.3893,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.3707,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.008823529411764706,
#    'change24h': 0.002704895861509332,
#    'changeBod': 0.005424464334147003,
#    'volumeUsd24h': 71747.0344,
#    'volume': 196065.0,
#    'openInterest': 439742.0,
#    'openInterestUsd': 163012.3594},
#   {'name': 'ALGO-1230',
#    'underlying': 'ALGO',
#    'description': 'Algorand December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.3729,
#    'bid': 0.3719,
#    'ask': 0.3747,
#    'index': 0.3707827796666667,
#    'mark': 0.3729,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3523,
#    'upperBound': 0.3913,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.3729,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.00824468085106383,
#    'change24h': 0.0005366246310705661,
#    'changeBod': 0.01524639259460931,
#    'volumeUsd24h': 20204.3691,
#    'volume': 54806.0,
#    'openInterest': 389345.0,
#    'openInterestUsd': 145186.7505},
#   {'name': 'ALICE-PERP',
#    'underlying': 'ALICE',
#    'description': 'MyNeighborAlice Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 1.7675,
#    'bid': 1.765,
#    'ask': 1.7675,
#    'index': 1.7662940666666667,
#    'mark': 1.7675,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.68,
#    'upperBound': 1.855,
#    'underlyingDescription': 'MyNeighborAlice',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.7675,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.05680119581464873,
#    'changeBod': 0.02911208151382824,
#    'volumeUsd24h': 1213122.715,
#    'volume': 713234.4,
#    'openInterest': 863306.7,
#    'openInterestUsd': 1525894.59225},
#   {'name': 'ALPHA-PERP',
#    'underlying': 'ALPHA',
#    'description': 'Alpha Finance Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.1093,
#    'bid': 0.10925,
#    'ask': 0.10935,
#    'index': 0.10931479027777778,
#    'mark': 0.1093,
#    'imfFactor': 0.00025,
#    'lowerBound': 0.10385,
#    'upperBound': 0.1148,
#    'underlyingDescription': 'Alpha Finance',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.1093,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0032124827902707664,
#    'change24h': 0.06426484907497566,
#    'changeBod': 0.0404569252736792,
#    'volumeUsd24h': 802916.03525,
#    'volume': 7627762.0,
#    'openInterest': 7112800.0,
#    'openInterestUsd': 777429.04},
#   {'name': 'ALT-PERP',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1917.65,
#    'bid': 1917.95,
#    'ask': 1918.1,
#    'index': 1916.8442097811565,
#    'mark': 1917.95,
#    'imfFactor': 0.0008,
#    'lowerBound': 1821.05,
#    'upperBound': 2013.25,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1917.95,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 2.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0012267696805178534,
#    'change24h': 0.04551773010984219,
#    'changeBod': 0.02814334342919939,
#    'volumeUsd24h': 3062543.22715,
#    'volume': 1630.737,
#    'openInterest': 5242.714,
#    'openInterestUsd': 10055263.3163},
#   {'name': 'ALT-0930',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1915.1,
#    'bid': 1912.7,
#    'ask': 1915.5,
#    'index': 1916.8442097811565,
#    'mark': 1915.1,
#    'imfFactor': 0.0008,
#    'lowerBound': 1819.6,
#    'upperBound': 2012.6,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1915.1,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0005485750111021133,
#    'change24h': 0.04464748397654439,
#    'changeBod': 0.030038994218098695,
#    'volumeUsd24h': 49753.77135,
#    'volume': 26.705,
#    'openInterest': 596.572,
#    'openInterestUsd': 1142495.0372},
#   {'name': 'ALT-1230',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1882.75,
#    'bid': 1882.75,
#    'ask': 1885.5,
#    'index': 1916.8442097811565,
#    'mark': 1882.75,
#    'imfFactor': 0.0008,
#    'lowerBound': 1786.15,
#    'upperBound': 2012.6,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1882.75,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0012497340991278452,
#    'change24h': 0.043537301851236006,
#    'changeBod': 0.02787028443522411,
#    'volumeUsd24h': 1924.38705,
#    'volume': 1.036,
#    'openInterest': 131.534,
#    'openInterestUsd': 247645.6385},
#   {'name': 'AMC-0930',
#    'underlying': 'AMC',
#    'description': 'AMC Entertainment Holdings September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 12.78,
#    'bid': 12.7975,
#    'ask': 13.2,
#    'index': 13.05,
#    'mark': 12.7975,
#    'imfFactor': 0.0025,
#    'indexAdjustment': 6.0,
#    'lowerBound': 10.19,
#    'upperBound': 15.66,
#    'underlyingDescription': 'AMC Entertainment Holdings',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 12.7975,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.11066712995135511,
#    'changeBod': 0.0037254901960784314,
#    'volumeUsd24h': 12009.465,
#    'volume': 931.2,
#    'openInterest': 33833.4,
#    'openInterestUsd': 432982.9365},
#   {'name': 'AMC-1230',
#    'underlying': 'AMC',
#    'description': 'AMC Entertainment Holdings December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 7.1275,
#    'bid': 6.8925,
#    'ask': 7.125,
#    'index': 7.05,
#    'mark': 7.125,
#    'imfFactor': 0.0025,
#    'lowerBound': 5.64,
#    'upperBound': 8.535,
#    'underlyingDescription': 'AMC Entertainment Holdings',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 7.125,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.10965323336457357,
#    'changeBod': 0.02591792656587473,
#    'volumeUsd24h': 1262.79025,
#    'volume': 179.3,
#    'openInterest': 1362.3,
#    'openInterestUsd': 9706.3875},
#   {'name': 'AMD-0930',
#    'underlying': 'AMD',
#    'description': 'Advanced Micro Devices September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 66.75,
#    'bid': 66.75,
#    'ask': 67.21,
#    'index': 67.1,
#    'mark': 66.75,
#    'imfFactor': 0.001,
#    'lowerBound': 63.4,
#    'upperBound': 70.45,
#    'underlyingDescription': 'Advanced Micro Devices',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 66.75,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.03274887697435154,
#    'changeBod': -0.003285053008809915,
#    'volumeUsd24h': 4026.0493,
#    'volume': 59.98,
#    'openInterest': 934.76,
#    'openInterestUsd': 62395.23},
#   {'name': 'AMD-1230',
#    'underlying': 'AMD',
#    'description': 'Advanced Micro Devices December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 67.18,
#    'bid': 66.89,
#    'ask': 67.21,
#    'index': 67.1,
#    'mark': 67.18,
#    'imfFactor': 0.001,
#    'lowerBound': 63.75,
#    'upperBound': 70.53,
#    'underlyingDescription': 'Advanced Micro Devices',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 67.18,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.02155549082435188,
#    'changeBod': 0.00358530026889752,
#    'volumeUsd24h': 5027.4492,
#    'volume': 74.83,
#    'openInterest': 1149.74,
#    'openInterestUsd': 77239.5332},
#   {'name': 'AMPL-PERP',
#    'underlying': 'AMPL',
#    'description': 'Ampleforth Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 10.0,
#    'last': 1.1725,
#    'bid': 1.1714,
#    'ask': 1.1725,
#    'index': 1.1705015786,
#    'mark': 1.1725,
#    'imfFactor': 0.0005,
#    'lowerBound': 1.112,
#    'upperBound': 1.2311,
#    'underlyingDescription': 'Ampleforth',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.1725,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0010224077702990543,
#    'change24h': 0.006869901245169601,
#    'changeBod': 0.012346744949058885,
#    'volumeUsd24h': 146802.334,
#    'volume': 125930.0,
#    'openInterest': 435990.0,
#    'openInterestUsd': 511198.275},
#   {'name': 'AMZN-0930',
#    'underlying': 'AMZN',
#    'description': 'Amazon September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 116.7,
#    'bid': 115.1,
#    'ask': 115.8,
#    'index': 115.4,
#    'mark': 115.8,
#    'imfFactor': 0.00067,
#    'lowerBound': 109.7,
#    'upperBound': 121.6,
#    'underlyingDescription': 'Amazon',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 115.8,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0008628127696289905,
#    'change24h': 0.030249110320284697,
#    'changeBod': 0.0034662045060658577,
#    'volumeUsd24h': 411.4682,
#    'volume': 3.586,
#    'openInterest': 11000.701,
#    'openInterestUsd': 1273881.1758},
#   {'name': 'AMZN-1230',
#    'underlying': 'AMZN',
#    'description': 'Amazon December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 115.2,
#    'bid': 115.2,
#    'ask': 115.8,
#    'index': 115.4,
#    'mark': 115.2,
#    'imfFactor': 0.00067,
#    'lowerBound': 109.4,
#    'upperBound': 121.1,
#    'underlyingDescription': 'Amazon',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 115.2,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.01856763925729443,
#    'changeBod': 0.004359197907585004,
#    'volumeUsd24h': 427.2817,
#    'volume': 3.721,
#    'openInterest': 135.93,
#    'openInterestUsd': 15659.136},
#   {'name': 'ANC-PERP',
#    'underlying': 'ANC',
#    'description': 'Anchor Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': False,
#    'postOnly': False,
#    'priceIncrement': 0.00025,
#    'sizeIncrement': 1.0,
#    'last': None,
#    'bid': None,
#    'ask': None,
#    'index': 0.09985334266666666,
#    'mark': 0.10020606266666666,
#    'imfFactor': 0.0003,
#    'lowerBound': 0.137,
#    'upperBound': 0.1515,
#    'underlyingDescription': 'Anchor',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.10020606266666666,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.3065324382929642,
#    'change24h': -0.3065324382929642,
#    'changeBod': -0.3065324382929642,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 0.0,
#    'openInterestUsd': 0.0},
#   {'name': 'APE-PERP',
#    'underlying': 'APE',
#    'description': 'ApeCoin Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.6995,
#    'bid': 5.6995,
#    'ask': 5.7,
#    'index': 5.7005,
#    'mark': 5.7005,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.416,
#    'upperBound': 5.985,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 5.7005,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.004974690172805027,
#    'change24h': 0.01767383736499152,
#    'changeBod': 0.03438577390673199,
#    'volumeUsd24h': 45000809.02395,
#    'volume': 8120628.7,
#    'openInterest': 6370411.0,
#    'openInterestUsd': 36314527.9055},
#   {'name': 'APE-0930',
#    'underlying': 'APE',
#    'description': 'ApeCoin September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.641,
#    'bid': 5.6815,
#    'ask': 5.7025,
#    'index': 5.7005,
#    'mark': 5.6815,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.395,
#    'upperBound': 5.985,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 5.6815,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0009671179883945841,
#    'change24h': 0.014281888779791127,
#    'changeBod': 0.03516443472715678,
#    'volumeUsd24h': 5797.53915,
#    'volume': 1048.0,
#    'openInterest': 35692.3,
#    'openInterestUsd': 202785.80245},
#   {'name': 'APE-1230',
#    'underlying': 'APE',
#    'description': 'ApeCoin December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.5945,
#    'bid': 5.554,
#    'ask': 5.5745,
#    'index': 5.7005,
#    'mark': 5.5745,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.2945,
#    'upperBound': 5.985,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 5.5745,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.00357493967289302,
#    'change24h': 0.019756699899387175,
#    'changeBod': 0.03837198472571482,
#    'volumeUsd24h': 161871.1236,
#    'volume': 30089.7,
#    'openInterest': 208767.4,
#    'openInterestUsd': 1163773.8713},
#   {'name': 'AR-PERP',
#    'underlying': 'AR',
#    'description': 'Arweave Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 9.751,
#    'bid': 9.746,
#    'ask': 9.75,
#    'index': 9.746900163333333,
#    'mark': 9.75,
#    'imfFactor': 0.0025,
#    'lowerBound': 9.26,
#    'upperBound': 10.234,
#    'underlyingDescription': 'Arweave',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 9.75,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0003077870113881194,
#    'change24h': 0.05782792665726375,
#    'changeBod': 0.032948405551435536,
#    'volumeUsd24h': 1691707.942,
#    'volume': 179044.0,
#    'openInterest': 257639.6,
#    'openInterestUsd': 2511986.1},
#   {'name': 'ARKK-0930',
#    'underlying': 'ARKK',
#    'description': 'ARK Innovation ETF September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 37.68,
#    'bid': 37.75,
#    'ask': 37.95,
#    'index': 37.7,
#    'mark': 37.75,
#    'imfFactor': 0.005,
#    'lowerBound': 35.82,
#    'upperBound': 39.63,
#    'underlyingDescription': 'ARK Innovation ETF',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 37.75,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.008665966386554622,
#    'changeBod': 0.003989361702127659,
#    'volumeUsd24h': 55472.3923,
#    'volume': 1432.81,
#    'openInterest': 11416.24,
#    'openInterestUsd': 430963.06},
#   {'name': 'ARKK-1230',
#    'underlying': 'ARKK',
#    'description': 'ARK Innovation ETF December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 37.88,
#    'bid': 37.8,
#    'ask': 37.95,
#    'index': 37.7,
#    'mark': 37.88,
#    'imfFactor': 0.005,
#    'lowerBound': 35.82,
#    'upperBound': 39.76,
#    'underlyingDescription': 'ARK Innovation ETF',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 37.88,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.00785751702462022,
#    'changeBod': 0.006376195536663124,
#    'volumeUsd24h': 17597.2102,
#    'volume': 466.72,
#    'openInterest': 2251.16,
#    'openInterestUsd': 85273.9408},
#   {'name': 'ASD-PERP',
#    'underlying': 'ASD',
#    'description': 'AscendEx Token (BTMX) Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 0.1,
#    'last': 0.10701,
#    'bid': 0.1067,
#    'ask': 0.10694,
#    'index': 0.10673,
#    'mark': 0.10694,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.1014,
#    'upperBound': 0.11226,
#    'underlyingDescription': 'AscendEx Token (BTMX)',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.10694,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.00028045246330746937,
#    'change24h': 0.04077858880778589,
#    'changeBod': 0.0017798594847775176,
#    'volumeUsd24h': 429914.463044,
#    'volume': 4111403.1,
#    'openInterest': 17242898.7,
#    'openInterestUsd': 1843955.586978},
#   {'name': 'ATLAS-PERP',
#    'underlying': 'ATLAS',
#    'description': 'Atlas Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-07,
#    'sizeIncrement': 10.0,
#    'last': 0.00460325,
#    'bid': 0.0046005,
#    'ask': 0.0046035,
#    'index': 0.00460225,
#    'mark': 0.00460325,
#    'imfFactor': 2.5e-05,
#    'lowerBound': 0.00437225,
#    'upperBound': 0.00483475,
#    'underlyingDescription': 'Atlas',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.00460325,
#    'imfWeight': 4.0,
#    'mmfWeight': 4.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.003463765762840288,
#    'change24h': 0.03408963270807593,
#    'changeBod': 0.014490358126721763,
#    'volumeUsd24h': 145568.4914325,
#    'volume': 32385450.0,
#    'openInterest': 146347510.0,
#    'openInterestUsd': 673674.1754075},
#   {'name': 'ATOM-PERP',
#    'underlying': 'ATOM',
#    'description': 'Cosmos Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 14.295,
#    'bid': 14.295,
#    'ask': 14.2955,
#    'index': 14.301342581666667,
#    'mark': 14.2955,
#    'imfFactor': 0.0004,
#    'lowerBound': 13.5805,
#    'upperBound': 15.016,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 14.2955,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.002735594290323712,
#    'change24h': 0.017147532818670177,
#    'changeBod': 0.0327626065597457,
#    'volumeUsd24h': 172453072.92107,
#    'volume': 12154233.61,
#    'openInterest': 3835357.9,
#    'openInterestUsd': 54828358.85945},
#   {'name': 'ATOM-0930',
#    'underlying': 'ATOM',
#    'description': 'Cosmos September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 14.2685,
#    'bid': 14.2335,
#    'ask': 14.28,
#    'index': 14.301342581666667,
#    'mark': 14.2685,
#    'imfFactor': 0.0004,
#    'lowerBound': 13.5525,
#    'upperBound': 15.016,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 14.2685,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.002599866493342234,
#    'change24h': 0.016709419980048455,
#    'changeBod': 0.03413661895270882,
#    'volumeUsd24h': 58987.300125,
#    'volume': 4052.87,
#    'openInterest': 19316.68,
#    'openInterestUsd': 275620.04858},
#   {'name': 'ATOM-1230',
#    'underlying': 'ATOM',
#    'description': 'Cosmos December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 13.9285,
#    'bid': 13.882,
#    'ask': 13.969,
#    'index': 14.301342581666667,
#    'mark': 13.9285,
#    'imfFactor': 0.0004,
#    'lowerBound': 13.2125,
#    'upperBound': 15.016,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 13.9285,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.00014356986468540254,
#    'change24h': 0.016975759345794393,
#    'changeBod': 0.035537712352700646,
#    'volumeUsd24h': 536624.94638,
#    'volume': 39149.05,
#    'openInterest': 148457.79,
#    'openInterestUsd': 2067794.328015},
#   {'name': 'AUDIO-PERP',
#    'underlying': 'AUDIO',
#    'description': 'Audius Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 0.227,
#    'bid': 0.2265,
#    'ask': 0.227,
#    'index': 0.2267370674225,
#    'mark': 0.227,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.2155,
#    'upperBound': 0.238,
#    'underlyingDescription': 'Audius',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.227,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.002197802197802198,
#    'change24h': 0.08353221957040573,
#    'changeBod': 0.04367816091954023,
#    'volumeUsd24h': 678710.5215,
#    'volume': 3105401.5,
#    'openInterest': 3874872.0,
#    'openInterestUsd': 879595.944},
#   {'name': 'AVAX-PERP',
#    'underlying': 'AVAX',
#    'description': 'Avalanche Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.903,
#    'bid': 17.9,
#    'ask': 17.901,
#    'index': 17.919438523333334,
#    'mark': 17.913,
#    'imfFactor': 0.0007,
#    'lowerBound': 17.021,
#    'upperBound': 18.814,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 17.913,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.003560104578071981,
#    'change24h': 0.04680925666199159,
#    'changeBod': 0.02196485623003195,
#    'volumeUsd24h': 44495342.0284,
#    'volume': 2553041.3,
#    'openInterest': 2561581.4,
#    'openInterestUsd': 45885607.6182},
#   {'name': 'AVAX-0930',
#    'underlying': 'AVAX',
#    'description': 'Avalanche September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.879,
#    'bid': 17.864,
#    'ask': 17.89,
#    'index': 17.919438523333334,
#    'mark': 17.882,
#    'imfFactor': 0.0007,
#    'lowerBound': 16.993,
#    'upperBound': 18.814,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 17.882,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0032329988851727983,
#    'change24h': 0.04646535580524345,
#    'changeBod': 0.021711804365215404,
#    'volumeUsd24h': 608858.9366,
#    'volume': 34925.0,
#    'openInterest': 34603.8,
#    'openInterestUsd': 618785.1516},
#   {'name': 'AVAX-1230',
#    'underlying': 'AVAX',
#    'description': 'Avalanche December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.551,
#    'bid': 16.951,
#    'ask': 17.537,
#    'index': 17.919438523333334,
#    'mark': 17.537,
#    'imfFactor': 0.0007,
#    'lowerBound': 16.64,
#    'upperBound': 18.814,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 17.537,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0001140575990875392,
#    'change24h': 0.04698507462686567,
#    'changeBod': 0.025735509153652688,
#    'volumeUsd24h': 16718.0048,
#    'volume': 977.1,
#    'openInterest': 34592.1,
#    'openInterestUsd': 606641.6577},
#   {'name': 'AXS-PERP',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 12.723,
#    'bid': 12.723,
#    'ask': 12.724,
#    'index': 12.728234102222222,
#    'mark': 12.716,
#    'imfFactor': 0.001,
#    'lowerBound': 12.083,
#    'upperBound': 13.364,
#    'underlyingDescription': 'Axie Infinity',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 12.716,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0019621693744604034,
#    'change24h': 0.04357816988100123,
#    'changeBod': 0.022104332449160036,
#    'volumeUsd24h': 12817011.2929,
#    'volume': 1032924.2,
#    'openInterest': 1595465.1,
#    'openInterestUsd': 20287934.2116},
#   {'name': 'AXS-0930',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 12.716,
#    'bid': 12.617,
#    'ask': 12.699,
#    'index': 12.728234102222222,
#    'mark': 12.676,
#    'imfFactor': 0.001,
#    'lowerBound': 12.071,
#    'upperBound': 13.364,
#    'underlyingDescription': 'Axie Infinity',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 12.676,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.000630715862503942,
#    'change24h': 0.04234849107803634,
#    'changeBod': 0.025649324378995066,
#    'volumeUsd24h': 13343.8419,
#    'volume': 1089.2,
#    'openInterest': 71897.4,
#    'openInterestUsd': 911371.4424},
#   {'name': 'AXS-1230',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 10.604,
#    'bid': 10.783,
#    'ask': 10.946,
#    'index': 12.728234102222222,
#    'mark': 10.783,
#    'imfFactor': 0.001,
#    'lowerBound': 10.153,
# ...
#   {'name': 'XLM-PERP',
#    'underlying': 'XLM',
#    'description': 'Stellar Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.11585,
#    'bid': 0.115825,
#    'ask': 0.115875,
#    'index': 0.11585189433333333,
#    'mark': 0.115875,
#    'imfFactor': 5e-05,
#    'lowerBound': 0.11005,
#    'upperBound': 0.121625,
#    'underlyingDescription': 'Stellar',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.115875,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.006217838765008576,
#    'change24h': -0.0010775862068965517,
#    'changeBod': 0.017116524028966424,
#    'volumeUsd24h': 8621380.679475,
#    'volume': 75346210.0,
#    'openInterest': 110272286.0,
#    'openInterestUsd': 12777801.14025},
#   {'name': 'XMR-PERP',
#    'underlying': 'XMR',
#    'description': 'Monero Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 151.41,
#    'bid': 151.35,
#    'ask': 151.38,
#    'index': 151.2857899,
#    'mark': 151.42,
#    'imfFactor': 0.002,
#    'lowerBound': 143.73,
#    'upperBound': 158.94,
#    'underlyingDescription': 'Monero',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 151.42,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0011901613329806928,
#    'change24h': 0.07687931157101202,
#    'changeBod': 0.03897351447783724,
#    'volumeUsd24h': 4740123.3414,
#    'volume': 32542.99,
#    'openInterest': 52250.42,
#    'openInterestUsd': 7911758.5964},
#   {'name': 'XRP-PERP',
#    'underlying': 'XRP',
#    'description': 'XRP Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.4764,
#    'bid': 0.476475,
#    'ask': 0.4765,
#    'index': 0.47631,
#    'mark': 0.476425,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.45255,
#    'upperBound': 0.500175,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.476425,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0022087825400999212,
#    'change24h': -0.005583385514506366,
#    'changeBod': 0.020400514028699936,
#    'volumeUsd24h': 250619102.708825,
#    'volume': 532611179.0,
#    'openInterest': 207205164.0,
#    'openInterestUsd': 98717720.2587},
#   {'name': 'XRP-0930',
#    'underlying': 'XRP',
#    'description': 'XRP September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.47535,
#    'bid': 0.475975,
#    'ask': 0.4762,
#    'index': 0.47631,
#    'mark': 0.475825,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.452225,
#    'upperBound': 0.500075,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.475825,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 8.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0012625598400757537,
#    'change24h': -0.005694284818723226,
#    'changeBod': 0.019934623010556776,
#    'volumeUsd24h': 1153562.0798,
#    'volume': 2458738.0,
#    'openInterest': 3539164.0,
#    'openInterestUsd': 1684022.7103},
#   {'name': 'XRP-1230',
#    'underlying': 'XRP',
#    'description': 'XRP December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.47395,
#    'bid': 0.474075,
#    'ask': 0.4746,
#    'index': 0.47631,
#    'mark': 0.474075,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.45035,
#    'upperBound': 0.500075,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.474075,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 8.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0009501187648456057,
#    'change24h': -0.005975782355716308,
#    'changeBod': 0.020668496689811078,
#    'volumeUsd24h': 219947.46195,
#    'volume': 469684.0,
#    'openInterest': 1516441.0,
#    'openInterestUsd': 718906.767075},
#   {'name': 'XTZ-PERP',
#    'underlying': 'XTZ',
#    'description': 'Tezos Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.5381,
#    'bid': 1.5381,
#    'ask': 1.5386,
#    'index': 1.5375795766666667,
#    'mark': 1.5386,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.4607,
#    'upperBound': 1.6144,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.5386,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.003194888178913738,
#    'change24h': 0.06847222222222223,
#    'changeBod': 0.044393157751832744,
#    'volumeUsd24h': 3678135.1045986,
#    'volume': 2496158.654,
#    'openInterest': 5092160.109,
#    'openInterestUsd': 7834797.5437074},
#   {'name': 'XTZ-0930',
#    'underlying': 'XTZ',
#    'description': 'Tezos September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.5163,
#    'bid': 1.5316,
#    'ask': 1.5413,
#    'index': 1.5375795766666667,
#    'mark': 1.5316,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.4546,
#    'upperBound': 1.6144,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1.5316,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0021592619250147224,
#    'change24h': 0.061105722599418044,
#    'changeBod': 0.039923954372623575,
#    'volumeUsd24h': 34825.9968441,
#    'volume': 23589.649,
#    'openInterest': 652344.212,
#    'openInterestUsd': 999130.3950992},
#   {'name': 'XTZ-1230',
#    'underlying': 'XTZ',
#    'description': 'Tezos December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.5012,
#    'bid': 1.5101,
#    'ask': 1.5217,
#    'index': 1.5375795766666667,
#    'mark': 1.5101,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.4331,
#    'upperBound': 1.6144,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1.5101,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0021900716750730023,
#    'change24h': 0.060165683796686326,
#    'changeBod': 0.044690418540297476,
#    'volumeUsd24h': 894.9451636,
#    'volume': 623.035,
#    'openInterest': 266449.998,
#    'openInterestUsd': 402366.1419798},
#   {'name': 'YFI-PERP',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8580.0,
#    'bid': 8575.0,
#    'ask': 8580.0,
#    'index': 8576.5712,
#    'mark': 8580.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 8150.0,
#    'upperBound': 9005.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 8580.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 50.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0017513134851138354,
#    'change24h': 0.06650093225605966,
#    'changeBod': 0.03063063063063063,
#    'volumeUsd24h': 4743905.88,
#    'volume': 571.324,
#    'openInterest': 824.75,
#    'openInterestUsd': 7076355.0},
#   {'name': 'YFI-0930',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8270.0,
#    'bid': 8555.0,
#    'ask': 8605.0,
#    'index': 8576.5712,
#    'mark': 8565.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 8135.0,
#    'upperBound': 9005.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 8565.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0017543859649122807,
#    'change24h': 0.06397515527950311,
#    'changeBod': 0.030685920577617327,
#    'volumeUsd24h': 118035.525,
#    'volume': 14.212,
#    'openInterest': 27.709,
#    'openInterestUsd': 237327.585},
#   {'name': 'YFI-1230',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8200.0,
#    'bid': 8470.0,
#    'ask': 8525.0,
#    'index': 8576.5712,
#    'mark': 8465.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 8030.0,
#    'upperBound': 9005.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 8465.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0011827321111768185,
#    'change24h': 0.058786741713570984,
#    'changeBod': 0.029805352798053526,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 5.95,
#    'openInterestUsd': 50366.75},
#   {'name': 'YFII-PERP',
#    'underlying': 'YFII',
#    'description': 'DFI.Money Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.25,
#    'sizeIncrement': 0.001,
#    'last': 897.5,
#    'bid': 897.0,
#    'ask': 897.25,
#    'index': 896.67867432,
#    'mark': 897.5,
#    'imfFactor': 0.025,
#    'lowerBound': 852.0,
#    'upperBound': 942.25,
#    'underlyingDescription': 'DFI.Money',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 897.5,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.00388457269700333,
#    'change24h': 0.049094097019286964,
#    'changeBod': 0.019017882486517174,
#    'volumeUsd24h': 1480854.1725,
#    'volume': 1691.864,
#    'openInterest': 2169.79,
#    'openInterestUsd': 1947386.525},
#   {'name': 'ZEC-PERP',
#    'underlying': 'ZEC',
#    'description': 'Zcash Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.05,
#    'last': 60.1,
#    'bid': 60.09,
#    'ask': 60.11,
#    'index': 60.050665333333335,
#    'mark': 60.1,
#    'imfFactor': 0.001,
#    'lowerBound': 57.05,
#    'upperBound': 63.08,
#    'underlyingDescription': 'Zcash',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 60.1,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 3.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0016666666666666668,
#    'change24h': 0.0553116769095698,
#    'changeBod': 0.02245661789724396,
#    'volumeUsd24h': 4850419.613,
#    'volume': 83546.4,
#    'openInterest': 58360.15,
#    'openInterestUsd': 3507445.015},
#   {'name': 'ZIL-PERP',
#    'underlying': 'ZIL',
#    'description': 'Zilliqa Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 10.0,
#    'last': 0.03268,
#    'bid': 0.03268,
#    'ask': 0.03269,
#    'index': 0.03268048782222222,
#    'mark': 0.03268,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.03105,
#    'upperBound': 0.03432,
#    'underlyingDescription': 'Zilliqa',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.03268,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.05385359561431796,
#    'changeBod': 0.02702702702702703,
#    'volumeUsd24h': 1515878.9903,
#    'volume': 47898860.0,
#    'openInterest': 121666440.0,
#    'openInterestUsd': 3976059.2592},
#   {'name': 'ZM-0930',
#    'underlying': 'ZM',
#    'description': 'Zoom September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.005,
#    'last': 75.0,
#    'bid': 73.5,
#    'ask': 73.85,
#    'index': 73.56,
#    'mark': 73.85,
#    'imfFactor': 0.002,
#    'lowerBound': 69.9,
#    'upperBound': 77.55,
#    'underlyingDescription': 'Zoom',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 73.85,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.010716677829872739,
#    'changeBod': 0.0006775067750677507,
#    'volumeUsd24h': 365.30875,
#    'volume': 4.815,
#    'openInterest': 1118.025,
#    'openInterestUsd': 82566.14625},
#   {'name': 'ZM-1230',
#    'underlying': 'ZM',
#    'description': 'Zoom December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.005,
#    'last': 75.25,
#    'bid': 73.55,
#    'ask': 73.85,
#    'index': 73.56,
#    'mark': 73.85,
#    'imfFactor': 0.002,
#    'lowerBound': 69.9,
#    'upperBound': 77.55,
#    'underlyingDescription': 'Zoom',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 73.85,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': -0.014018691588785047,
#    'changeBod': 0.0006775067750677507,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 0.0,
#    'openInterestUsd': 0.0},
#   {'name': 'ZRX-PERP',
#    'underlying': 'ZRX',
#    'description': '0x Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.00025,
#    'sizeIncrement': 1.0,
#    'last': 0.276,
#    'bid': 0.276,
#    'ask': 0.27625,
#    'index': 0.2759740666666667,
#    'mark': 0.276,
#    'imfFactor': 0.0003,
#    'lowerBound': 0.26225,
#    'upperBound': 0.28975,
#    'underlyingDescription': '0x',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.276,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': 0.0,
#    'change24h': 0.046445497630331754,
#    'changeBod': 0.03081232492997199,
#    'volumeUsd24h': 572394.84325,
#    'volume': 2142041.0,
#    'openInterest': 4138999.0,
#    'openInterestUsd': 1142363.724}]}

# %%
df = pd.DataFrame(res['result'])
df.head()
# Out:
#          name underlying                         description       type  \
# 0  1INCH-PERP      1INCH       1INCH Token Perpetual Futures  perpetual
# 1  1INCH-0930      1INCH  1INCH Token September 2022 Futures     future
# 2  1INCH-1230      1INCH   1INCH Token December 2022 Futures     future
# 3   AAPL-0930       AAPL        Apple September 2022 Futures     future
# 4   AAPL-1230       AAPL         Apple December 2022 Futures     future
#
#                       expiry  perpetual  expired  enabled  postOnly  \
# 0                       None       True    False     True     False
# 1  2022-09-30T03:00:00+00:00      False    False     True     False
# 2  2022-12-30T03:00:00+00:00      False    False     True     False
# 3  2022-09-30T20:00:00+00:00      False    False     True     False
# 4  2022-12-30T21:00:00+00:00      False    False     True     False
#
#    priceIncrement  ...      group  closeOnly  change1h  change24h  changeBod  \
# 0          0.0001  ...  perpetual      False -0.005661   0.041337   0.012652
# 1          0.0001  ...  quarterly      False -0.006168   0.033043   0.013712
# 2          0.0001  ...  quarterly      False -0.003908   0.038364   0.010073
# 3          0.0100  ...  quarterly      False  0.000000   0.012043   0.000000
# 4          0.0100  ...  quarterly      False  0.000132   0.009916   0.004235
#
#    volumeUsd24h      volume  openInterest  openInterestUsd indexAdjustment
# 0  4.729529e+06  7635032.00    8059808.00     5.096217e+06             NaN
# 1  6.471805e+04   106809.00     116624.00     7.328652e+04             NaN
# 2  4.167424e+02      703.00      21655.00     1.324636e+04             NaN
# 3  9.065571e+03       59.71       8738.28     1.321840e+06             NaN
# 4  1.368938e+05      899.78        676.34     1.026346e+05             NaN
#
# [5 rows x 36 columns]

# %%
df = pd.DataFrame(res['result'])
# Using iloc to make it readable
df.iloc[:,:4].head()
# Out:
#          name underlying                         description       type
# 0  1INCH-PERP      1INCH       1INCH Token Perpetual Futures  perpetual
# 1  1INCH-0930      1INCH  1INCH Token September 2022 Futures     future
# 2  1INCH-1230      1INCH   1INCH Token December 2022 Futures     future
# 3   AAPL-0930       AAPL        Apple September 2022 Futures     future
# 4   AAPL-1230       AAPL         Apple December 2022 Futures     future

# %% [markdown]
# ## 8. The Bottom Line

# %% [markdown]
# > FTX and its U.S. counterpart FTX.US are two of the best exchanges in the crypto space. If you’re interested in algo trading or simply looking for a great data source, FTX has an easy-to-use REST API to get you what you need.
