# %% [markdown]
# # FTX.US API Python Tutorial

# %% [markdown]
# ## 1. Get imports

# %%
import datetime
import requests
import pandas as pd
from client import FtxClient
#from local_settings import ftx as settings

# %% [markdown]
# ## 2. Using the FTX Market API

# %% [markdown]
# > Using the Markets API is easy. The Markets API allows us to get all of the market data. We’ll be greeted with the following information when we make a request.

# %%
# GET /markets
api_url = 'https://ftx.us/api'
api = '/markets'
url = api_url+api
url

'https://ftx.us/api/markets'
# Out:
# 'https://ftx.us/api/markets'

# %% [markdown]
# > Now we’ll use requests to get the market response data.

# %%
markets = requests.get(url).json()
data = markets['result']
data
# Out:
# [{'name': 'AAVE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.92,
#   'bid': 76.92,
#   'ask': 76.95,
#   'price': 76.92,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.02484787018255578,
#   'change24h': 0.026147278548559232,
#   'changeBod': 0.010775295663600526,
#   'quoteVolume24h': 238548.3062,
#   'volumeUsd24h': 238548.3062,
#   'priceHigh24h': 80.86,
#   'priceLow24h': 74.81},
#  {'name': 'AAVE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 76.91,
#   'bid': 76.87,
#   'ask': 77.01,
#   'price': 76.91,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.02472736495054527,
#   'change24h': 0.026150767178118747,
#   'changeBod': 0.01051110235185915,
#   'quoteVolume24h': 38966.8792,
#   'volumeUsd24h': 38960.38459024374,
#   'priceHigh24h': 80.85,
#   'priceLow24h': 74.81},
#  {'name': 'ALGO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3548,
#   'bid': 0.3541,
#   'ask': 0.3552,
#   'price': 0.3548,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.030601092896174863,
#   'change24h': -0.0116991643454039,
#   'changeBod': -0.03165938864628821,
#   'quoteVolume24h': 203420.5371,
#   'volumeUsd24h': 203420.5371,
#   'priceHigh24h': 0.3747,
#   'priceLow24h': 0.3538},
#  {'name': 'ALGO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3551,
#   'bid': 0.3535,
#   'ask': 0.3549,
#   'price': 0.3549,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.03349673202614379,
#   'change24h': -0.011971046770601337,
#   'changeBod': -0.029266958424507657,
#   'quoteVolume24h': 2148.542,
#   'volumeUsd24h': 2148.18390250486,
#   'priceHigh24h': 0.3747,
#   'priceLow24h': 0.354},
#  {'name': 'AUD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.6501,
#   'bid': 0.6415,
#   'ask': 0.6426,
#   'price': 0.6426,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AUD',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.003102699348433137,
#   'change24h': -0.002793296089385475,
#   'changeBod': -0.006647086102952543,
#   'quoteVolume24h': 0.6501,
#   'volumeUsd24h': 0.6501,
#   'priceHigh24h': 0.6502,
#   'priceLow24h': 0.6426},
#  {'name': 'AVAX/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-07,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.0009039,
#   'bid': 0.0009004,
#   'ask': 0.000903,
#   'price': 0.000903,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.011878081577767817,
#   'change24h': -0.004739336492890996,
#   'changeBod': -0.009976976208749041,
#   'quoteVolume24h': 2.04343487,
#   'volumeUsd24h': 39649.14627766604,
#   'priceHigh24h': 0.0009153,
#   'priceLow24h': 0.0008893},
#  {'name': 'AVAX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 17.504,
#   'bid': 17.503,
#   'ask': 17.5035,
#   'price': 17.5035,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.026014133882366033,
#   'change24h': 0.016079876933793865,
#   'changeBod': -0.0008562376915831834,
#   'quoteVolume24h': 3289531.3055,
#   'volumeUsd24h': 3289531.3055,
#   'priceHigh24h': 18.475,
#   'priceLow24h': 17.206},
#  {'name': 'AVAX/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 17.412,
#   'bid': 17.484,
#   'ask': 17.525,
#   'price': 17.484,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.026150889798646503,
#   'change24h': 0.013565217391304348,
#   'changeBod': -0.002453357676727335,
#   'quoteVolume24h': 42866.6897,
#   'volumeUsd24h': 42859.545108827704,
#   'priceHigh24h': 18.4715,
#   'priceLow24h': 17.223},
#  {'name': 'BAT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.30125,
#   'bid': 0.30095,
#   'ask': 0.301725,
#   'price': 0.30125,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BAT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.018809543196808078,
#   'change24h': 0.00980474314924998,
#   'changeBod': 0.005759118604457057,
#   'quoteVolume24h': 7805.93415,
#   'volumeUsd24h': 7805.93415,
#   'priceHigh24h': 0.312375,
#   'priceLow24h': 0.29655},
#  {'name': 'BCH/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.005957,
#   'bid': 0.005958,
#   'ask': 0.005968,
#   'price': 0.005958,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 432.0,
#   'change1h': 0.005569620253164557,
#   'change24h': -0.01601981833195706,
#   'changeBod': -0.013249420337860219,
#   'quoteVolume24h': 10.638642184,
#   'volumeUsd24h': 206423.55004403176,
#   'priceHigh24h': 0.006068,
#   'priceLow24h': 0.005871},
#  {'name': 'BCH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 115.9,
#   'bid': 115.775,
#   'ask': 115.825,
#   'price': 115.825,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 720.0,
#   'change1h': -0.030753138075313807,
#   'change24h': 0.00651748859439496,
#   'changeBod': -0.0008626266982963123,
#   'quoteVolume24h': 1329803.39805,
#   'volumeUsd24h': 1329803.39805,
#   'priceHigh24h': 120.6,
#   'priceLow24h': 114.9},
#  {'name': 'BCH/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 115.625,
#   'bid': 115.775,
#   'ask': 115.875,
#   'price': 115.775,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 504.0,
#   'change1h': -0.030766010883214734,
#   'change24h': 0.0058644656820156385,
#   'changeBod': -0.0010785159620362382,
#   'quoteVolume24h': 152753.170825,
#   'volumeUsd24h': 152727.7114540186,
#   'priceHigh24h': 120.65,
#   'priceLow24h': 114.975},
#  {'name': 'BRZ/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.19033,
#   'bid': 0.18772,
#   'ask': 0.1879,
#   'price': 0.1879,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BRZ',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.004345061466723188,
#   'change24h': 0.006104090811736989,
#   'changeBod': 0.0037393162393162395,
#   'quoteVolume24h': 135.43731,
#   'volumeUsd24h': 135.43731,
#   'priceHigh24h': 0.19033,
#   'priceLow24h': 0.18609},
#  {'name': 'BRZ/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.17802,
#   'bid': 0.18747,
#   'ask': 0.18793,
#   'price': 0.18747,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BRZ',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.0031372966074657022,
#   'change24h': 0.0086624340901754,
#   'changeBod': 0.0025133689839572193,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 0.1893,
#   'priceLow24h': 0.17802},
#  {'name': 'BTC/AUD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 29566.0,
#   'bid': 30103.0,
#   'ask': 30316.0,
#   'price': 30103.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'AUD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': -0.036303102090469636,
#   'change24h': 0.018162754515321653,
#   'changeBod': 0.018162754515321653,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 31411.0,
#   'priceLow24h': 29531.0},
#  {'name': 'BTC/BRZ',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 109105.0,
#   'bid': 102925.0,
#   'ask': 103535.0,
#   'price': 103535.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'BRZ',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': -0.03436858795000933,
#   'change24h': 0.015746100264887666,
#   'changeBod': 0.013508883559297146,
#   'quoteVolume24h': 8576.3155,
#   'volumeUsd24h': 1610.889340365,
#   'priceHigh24h': 109340.0,
#   'priceLow24h': 101200.0},
#  {'name': 'BTC/EUR',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 19727.0,
#   'bid': 20185.0,
#   'ask': 20271.0,
#   'price': 20185.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'EUR',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.032219398763005225,
#   'change24h': 0.023216910832868656,
#   'changeBod': 0.015904172328753335,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 21103.0,
#   'priceLow24h': 19727.0},
#  {'name': 'BTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 19414.0,
#   'bid': 19413.0,
#   'ask': 19414.0,
#   'price': 19414.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': -0.0366694784895549,
#   'change24h': 0.02162816397410935,
#   'changeBod': 0.011514614703277236,
#   'quoteVolume24h': 122158765.0766,
#   'volumeUsd24h': 122158765.0766,
#   'priceHigh24h': 20375.0,
#   'priceLow24h': 18970.0},
#  {'name': 'BTC/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 19398.0,
#   'bid': 19409.0,
#   'ask': 19416.0,
#   'price': 19409.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.03686978959904724,
#   'change24h': 0.02115010259378124,
#   'changeBod': 0.01120141710951339,
#   'quoteVolume24h': 5349627.7203,
#   'volumeUsd24h': 5348736.0978478575,
#   'priceHigh24h': 20379.0,
#   'priceLow24h': 18970.0},
#  {'name': 'CAD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.7331,
#   'bid': 0.7281,
#   'ask': 0.7285,
#   'price': 0.7285,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CAD',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0012338908692075678,
#   'change24h': 0.0024769505985963946,
#   'changeBod': -0.0023281292796494112,
#   'quoteVolume24h': 0.7331,
#   'volumeUsd24h': 0.7331,
#   'priceHigh24h': 0.7345,
#   'priceLow24h': 0.7265},
#  {'name': 'CUSDT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0220075,
#   'bid': 0.0219925,
#   'ask': 0.02202,
#   'price': 0.0220075,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CUSDT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.0010213345438039039,
#   'changeBod': 0.0,
#   'quoteVolume24h': 125.54291,
#   'volumeUsd24h': 125.54291,
#   'priceHigh24h': 0.0220325,
#   'priceLow24h': 0.022005},
#  {'name': 'CUSDT/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.02202,
#   'bid': 0.0219925,
#   'ask': 0.02202,
#   'price': 0.02202,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'CUSDT',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': -0.0006807351940095302,
#   'changeBod': -0.00045392646391284613,
#   'quoteVolume24h': 1.84968,
#   'volumeUsd24h': 1.8493717138344,
#   'priceHigh24h': 0.022035,
#   'priceLow24h': 0.02202},
#  {'name': 'DAI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.9993,
#   'bid': 0.9993,
#   'ask': 1.0,
#   'price': 0.9993,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DAI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0007,
#   'change24h': -0.0007,
#   'changeBod': 0.0,
#   'quoteVolume24h': 1937.54085,
#   'volumeUsd24h': 1937.54085,
#   'priceHigh24h': 1.0,
#   'priceLow24h': 0.9991},
#  {'name': 'DAI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.0001,
#   'bid': 0.9993,
#   'ask': 1.0004,
#   'price': 1.0001,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DAI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': -9.998000399920016e-05,
#   'changeBod': -9.998000399920016e-05,
#   'quoteVolume24h': 5005.501,
#   'volumeUsd24h': 5004.66673314833,
#   'priceHigh24h': 1.0002,
#   'priceLow24h': 0.9991},
#  {'name': 'DOGE/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 3.13e-06,
#   'bid': 3.13e-06,
#   'ask': 3.14e-06,
#   'price': 3.13e-06,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.016233766233766232,
#   'change24h': -0.018808777429467086,
#   'changeBod': -0.015723270440251572,
#   'quoteVolume24h': 4.90409978,
#   'volumeUsd24h': 95155.15879274873,
#   'priceHigh24h': 3.2e-06,
#   'priceLow24h': 3.07e-06},
#  {'name': 'DOGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0607845,
#   'bid': 0.0608615,
#   'ask': 0.060886,
#   'price': 0.0608615,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.019888399507218605,
#   'change24h': 0.0057923352778833604,
#   'changeBod': -0.003250900753357353,
#   'quoteVolume24h': 3347304.605216,
#   'volumeUsd24h': 3347304.605216,
#   'priceHigh24h': 0.063089,
#   'priceLow24h': 0.060347},
#  {'name': 'DOGE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0607925,
#   'bid': 0.060863,
#   'ask': 0.060898,
#   'price': 0.060863,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.019532665866565713,
#   'change24h': 0.006241165237949591,
#   'changeBod': -0.0031528691108909106,
#   'quoteVolume24h': 64546.4766605,
#   'volumeUsd24h': 64535.718699234996,
#   'priceHigh24h': 0.063046,
#   'priceLow24h': 0.0603455},
#  {'name': 'ETH/AUD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 2095.3,
#   'bid': 2078.2,
#   'ask': 2092.9,
#   'price': 2092.9,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'AUD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': -0.02036135555139487,
#   'change24h': 0.030528337190408192,
#   'changeBod': 0.01933567114747711,
#   'quoteVolume24h': 4.1878,
#   'volumeUsd24h': 2.6885676,
#   'priceHigh24h': 2155.9,
#   'priceLow24h': 2028.1},
#  {'name': 'ETH/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.0689975,
#   'bid': 0.0690125,
#   'ask': 0.06904,
#   'price': 0.0690125,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1440.0,
#   'change1h': 0.0075185225738165625,
#   'change24h': -0.0011578680754061584,
#   'changeBod': -0.006657070888808924,
#   'quoteVolume24h': 32.9118210675,
#   'volumeUsd24h': 638594.1763681846,
#   'priceHigh24h': 0.0697475,
#   'priceLow24h': 0.0681825},
#  {'name': 'ETH/EUR',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1341.7,
#   'bid': 1391.4,
#   'ask': 1399.3,
#   'price': 1391.4,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'EUR',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.02678883681891306,
#   'change24h': 0.02331396631609914,
#   'changeBod': 0.008480104370515329,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1446.6,
#   'priceLow24h': 1358.7},
#  {'name': 'ETH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1339.8,
#   'bid': 1339.7,
#   'ask': 1340.0,
#   'price': 1339.8,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': -0.029763197914403648,
#   'change24h': 0.020488993830451673,
#   'changeBod': 0.00502587952891756,
#   'quoteVolume24h': 135545615.6542,
#   'volumeUsd24h': 135545615.6542,
#   'priceHigh24h': 1400.0,
#   'priceLow24h': 1311.1},
#  {'name': 'ETH/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1339.5,
#   'bid': 1339.8,
#   'ask': 1340.4,
#   'price': 1339.8,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1680.0,
#   'change1h': -0.02969293163383546,
#   'change24h': 0.02056672760511883,
#   'changeBod': 0.004875121878046951,
#   'quoteVolume24h': 3313619.9073,
#   'volumeUsd24h': 3313067.62627005,
#   'priceHigh24h': 1400.1,
#   'priceLow24h': 1311.3},
#  {'name': 'ETHW/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 10.0,
#   'bid': 9.991,
#   'ask': 10.049,
#   'price': 10.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ETHW',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.07054558973882331,
#   'change24h': -0.029503105590062112,
#   'changeBod': -0.08609029427892524,
#   'quoteVolume24h': 670827.465532,
#   'volumeUsd24h': 670827.465532,
#   'priceHigh24h': 11.967,
#   'priceLow24h': 9.9},
#  {'name': 'EUR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.961,
#   'bid': 0.96,
#   'ask': 0.9605,
#   'price': 0.9605,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'EUR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0033205354363391097,
#   'change24h': -0.002077922077922078,
#   'changeBod': -0.0029066749714522994,
#   'quoteVolume24h': 3.8501,
#   'volumeUsd24h': 3.8501,
#   'priceHigh24h': 0.9675,
#   'priceLow24h': 0.9597},
#  {'name': 'GBP/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.0698,
#   'bid': 1.0704,
#   'ask': 1.072,
#   'price': 1.0704,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'GBP',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.007234279354479688,
#   'change24h': 0.0038450717434117977,
#   'changeBod': -0.004556867850832326,
#   'quoteVolume24h': 75143.6992,
#   'volumeUsd24h': 75143.6992,
#   'priceHigh24h': 1.0829,
#   'priceLow24h': 1.0656},
#  {'name': 'GRT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1009,
#   'bid': 0.1008,
#   'ask': 0.10095,
#   'price': 0.1009,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'GRT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0199125789218067,
#   'change24h': 0.010515773660490736,
#   'changeBod': -0.014167073766487542,
#   'quoteVolume24h': 246076.29135,
#   'volumeUsd24h': 246076.29135,
#   'priceHigh24h': 0.10565,
#   'priceLow24h': 0.09985},
#  {'name': 'KSHIB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.011277,
#   'bid': 0.010984,
#   'ask': 0.011042,
#   'price': 0.011042,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'KSHIB',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.02179305457122608,
#   'change24h': 0.008862494289629968,
#   'changeBod': -0.005045954225986664,
#   'quoteVolume24h': 419.3361,
#   'volumeUsd24h': 419.3361,
#   'priceHigh24h': 0.01151,
#   'priceLow24h': 0.010945},
#  {'name': 'LINK/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.00040935,
#   'bid': 0.000409,
#   'ask': 0.0004101,
#   'price': 0.00040935,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.007878862489228118,
#   'change24h': 0.00036656891495601173,
#   'changeBod': -0.008117276472013569,
#   'quoteVolume24h': 5.48208469,
#   'volumeUsd24h': 106369.90734153592,
#   'priceHigh24h': 0.0004168,
#   'priceLow24h': 0.00040445},
#  {'name': 'LINK/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.9565,
#   'bid': 7.9505,
#   'ask': 7.955,
#   'price': 7.955,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.028100183262064753,
#   'change24h': 0.022362164246240844,
#   'changeBod': 0.005498325222776971,
#   'quoteVolume24h': 1842191.27145,
#   'volumeUsd24h': 1842191.27145,
#   'priceHigh24h': 8.3945,
#   'priceLow24h': 7.747},
#  {'name': 'LINK/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.952,
#   'bid': 7.9525,
#   'ask': 7.9575,
#   'price': 7.9525,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.02834626428004154,
#   'change24h': 0.022040868782932786,
#   'changeBod': 0.005436500410898287,
#   'quoteVolume24h': 225181.23495,
#   'volumeUsd24h': 225143.70399357087,
#   'priceHigh24h': 8.4015,
#   'priceLow24h': 7.7475},
#  {'name': 'LTC/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.00274175,
#   'bid': 0.00273775,
#   'ask': 0.0027495,
#   'price': 0.00274175,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.009016468856380532,
#   'change24h': -0.009393912022400867,
#   'changeBod': -0.013492848790141225,
#   'quoteVolume24h': 1.3128380825,
#   'volumeUsd24h': 25473.241127539877,
#   'priceHigh24h': 0.002792,
#   'priceLow24h': 0.002703},
#  {'name': 'LTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 53.255,
#   'bid': 53.235,
#   'ask': 53.26,
#   'price': 53.255,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.027661128354938835,
#   'change24h': 0.011683130699088147,
#   'changeBod': -0.0014999531264647979,
#   'quoteVolume24h': 899703.53565,
#   'volumeUsd24h': 899703.53565,
#   'priceHigh24h': 55.58,
#   'priceLow24h': 52.595},
#  {'name': 'LTC/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 53.185,
#   'bid': 53.26,
#   'ask': 53.265,
#   'price': 53.26,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.027924803796313197,
#   'change24h': 0.011874228175168615,
#   'changeBod': -0.0012189404594467885,
#   'quoteVolume24h': 991666.95065,
#   'volumeUsd24h': 991501.6695193351,
#   'priceHigh24h': 55.59,
#   'priceLow24h': 52.6},
#  {'name': 'MATIC/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 3.865e-05,
#   'bid': 3.857e-05,
#   'ask': 3.864e-05,
#   'price': 3.864e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MATIC',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': 0.006512112529304506,
#   'change24h': -0.015792154865002548,
#   'changeBod': -0.016042780748663103,
#   'quoteVolume24h': 3.1657419,
#   'volumeUsd24h': 61425.478009209284,
#   'priceHigh24h': 3.944e-05,
#   'priceLow24h': 3.82e-05},
#  {'name': 'MATIC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.749375,
#   'bid': 0.748886,
#   'ask': 0.749154,
#   'price': 0.749154,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MATIC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.03162659751997425,
#   'change24h': 0.005196697621434063,
#   'changeBod': -0.006724774802247602,
#   'quoteVolume24h': 2009717.26228,
#   'volumeUsd24h': 2009717.26228,
#   'priceHigh24h': 0.793196,
#   'priceLow24h': 0.742517},
#  {'name': 'MKR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 744.0,
#   'bid': 744.0,
#   'ask': 745.0,
#   'price': 744.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'MKR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.022339027595269383,
#   'change24h': 0.07982583454281568,
#   'changeBod': 0.03765690376569038,
#   'quoteVolume24h': 150057.4915,
#   'volumeUsd24h': 150057.4915,
#   'priceHigh24h': 770.0,
#   'priceLow24h': 687.0},
#  {'name': 'NEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.621,
#   'bid': 3.619,
#   'ask': 3.626,
#   'price': 3.621,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'NEAR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.03388473852721451,
#   'change24h': -0.005492996429552321,
#   'changeBod': -0.016567083107007063,
#   'quoteVolume24h': 63799.5683,
#   'volumeUsd24h': 63799.5683,
#   'priceHigh24h': 3.82,
#   'priceLow24h': 3.602},
#  {'name': 'NEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.61,
#   'bid': 3.62,
#   'ask': 3.627,
#   'price': 3.62,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'NEAR',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.033893781692020286,
#   'change24h': -0.007403345215245407,
#   'changeBod': -0.016036966567001903,
#   'quoteVolume24h': 12325.7238,
#   'volumeUsd24h': 12323.669471614254,
#   'priceHigh24h': 3.817,
#   'priceLow24h': 3.605},
#  {'name': 'PAXG/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 1623.4,
#   'bid': 1619.0,
#   'ask': 1626.6,
#   'price': 1623.4,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'PAXG',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0014761963341124369,
#   'change24h': 0.0003697313285679073,
#   'changeBod': 0.0029035645888676096,
#   'quoteVolume24h': 39044.00438,
#   'volumeUsd24h': 39044.00438,
#   'priceHigh24h': 1633.4,
#   'priceLow24h': 1611.0},
#  {'name': 'PAXG/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 1619.0,
#   'bid': 1619.4,
#   'ask': 1627.0,
#   'price': 1619.4,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'PAXG',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.0008637709772951629,
#   'change24h': -0.0020951441952181413,
#   'changeBod': 0.0002470660901791229,
#   'quoteVolume24h': 500.9186,
#   'volumeUsd24h': 500.835111896938,
#   'priceHigh24h': 1632.9,
#   'priceLow24h': 1613.2},
#  {'name': 'SHIB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 100000.0,
#   'minProvideSize': 100000.0,
#   'last': 1.099e-05,
#   'bid': 1.101e-05,
#   'ask': 1.104e-05,
#   'price': 1.101e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SHIB',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.022202486678507993,
#   'change24h': 0.006398537477148081,
#   'changeBod': -0.009892086330935251,
#   'quoteVolume24h': 47407.969,
#   'volumeUsd24h': 47407.969,
#   'priceHigh24h': 1.153e-05,
#   'priceLow24h': 1.092e-05},
#  {'name': 'SOL/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.00171175,
#   'bid': 0.00171,
#   'ask': 0.0017125,
#   'price': 0.00171175,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.004217568353694008,
#   'change24h': -0.007968704723268617,
#   'changeBod': -0.027276601790026993,
#   'quoteVolume24h': 16.907156225,
#   'volumeUsd24h': 328052.69213418924,
#   'priceHigh24h': 0.00178225,
#   'priceLow24h': 0.00169925},
#  {'name': 'SOL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 33.1825,
#   'bid': 33.1825,
#   'ask': 33.2025,
#   'price': 33.1825,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.04186818739623186,
#   'change24h': 0.0128195345288058,
#   'changeBod': -0.017324350336862367,
#   'quoteVolume24h': 22921812.931375,
#   'volumeUsd24h': 22921812.931375,
#   'priceHigh24h': 35.42,
#   'priceLow24h': 32.685},
#  {'name': 'SOL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 33.215,
#   'bid': 33.215,
#   'ask': 33.2275,
#   'price': 33.215,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.04072202166064982,
#   'change24h': 0.013424866514111365,
#   'changeBod': -0.016361886429258902,
#   'quoteVolume24h': 2377385.2311,
#   'volumeUsd24h': 2376988.9923035325,
#   'priceHigh24h': 35.4225,
#   'priceLow24h': 32.695},
#  {'name': 'SUSHI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 5.589e-05,
#   'bid': 5.599e-05,
#   'ask': 5.624e-05,
#   'price': 5.599e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 576.0,
#   'change1h': 0.018926296633303002,
#   'change24h': 0.02208835341365462,
#   'changeBod': 0.01762995274445656,
#   'quoteVolume24h': 0.949866905,
#   'volumeUsd24h': 18430.443961572855,
#   'priceHigh24h': 5.627e-05,
#   'priceLow24h': 5.454e-05},
#  {'name': 'SUSHI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 1.0885,
#   'bid': 1.0869,
#   'ask': 1.0889,
#   'price': 1.0885,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.018308080808080808,
#   'change24h': 0.04542835190165194,
#   'changeBod': 0.029022499527320854,
#   'quoteVolume24h': 249690.80025,
#   'volumeUsd24h': 249690.80025,
#   'priceHigh24h': 1.1402,
#   'priceLow24h': 1.0403},
#  {'name': 'SUSHI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 1.0895,
#   'bid': 1.0875,
#   'ask': 1.0893,
#   'price': 1.0893,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.017675173595454955,
#   'change24h': 0.04629718566900394,
#   'changeBod': 0.02900056678632156,
#   'quoteVolume24h': 79508.51105,
#   'volumeUsd24h': 79495.2593664633,
#   'priceHigh24h': 1.1405,
#   'priceLow24h': 1.04},
#  {'name': 'TRX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0599075,
#   'bid': 0.0598375,
#   'ask': 0.0598975,
#   'price': 0.0598975,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'TRX',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 720.0,
#   'change1h': -0.009303671849156467,
#   'change24h': 0.010416666666666666,
#   'changeBod': 0.005033768194974622,
#   'quoteVolume24h': 30066.1292675,
#   'volumeUsd24h': 30066.1292675,
#   'priceHigh24h': 0.060875,
#   'priceLow24h': 0.0591425},
#  {'name': 'TRX/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0599625,
#   'bid': 0.0598575,
#   'ask': 0.059915,
#   'price': 0.059915,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'TRX',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 504.0,
#   'change1h': -0.009055199503824685,
#   'change24h': 0.009647385937565825,
#   'changeBod': 0.005580497629337473,
#   'quoteVolume24h': 16195.8033775,
#   'volumeUsd24h': 16193.104022951073,
#   'priceHigh24h': 0.0609075,
#   'priceLow24h': 0.05919},
#  {'name': 'UNI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 0.05,
#   'minProvideSize': 0.05,
#   'last': 0.00032635,
#   'bid': 0.0003258,
#   'ask': 0.0003266,
#   'price': 0.00032635,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 168.0,
#   'change1h': 0.0050816137973514015,
#   'change24h': 0.06406912292142158,
#   'changeBod': 0.058375222960921035,
#   'quoteVolume24h': 15.9266521175,
#   'volumeUsd24h': 309027.78884274256,
#   'priceHigh24h': 0.00033135,
#   'priceLow24h': 0.00030605},
#  {'name': 'UNI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 6.328,
#   'bid': 6.331,
#   'ask': 6.336,
#   'price': 6.331,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.03210518269377771,
#   'change24h': 0.08537630721755529,
#   'changeBod': 0.06888401148066858,
#   'quoteVolume24h': 362059.3716,
#   'volumeUsd24h': 362059.3716,
#   'priceHigh24h': 6.703,
#   'priceLow24h': 5.828},
#  {'name': 'UNI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.05,
#   'minProvideSize': 0.05,
#   'last': 6.317,
#   'bid': 6.33,
#   'ask': 6.34,
#   'price': 6.33,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.03240599205136044,
#   'change24h': 0.08520486884964855,
#   'changeBod': 0.06943740496705525,
#   'quoteVolume24h': 125006.8051,
#   'volumeUsd24h': 124985.97021579399,
#   'priceHigh24h': 6.701,
#   'priceLow24h': 5.826},
#  {'name': 'USDT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 1.0,
#   'bid': 0.9999,
#   'ask': 1.0,
#   'price': 1.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'USDT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2400.0,
#   'change1h': 0.00020004000800160032,
#   'change24h': 0.0,
#   'changeBod': 0.00010001000100010001,
#   'quoteVolume24h': 1456855.767614,
#   'volumeUsd24h': 1456855.767614,
#   'priceHigh24h': 1.0001,
#   'priceLow24h': 0.9998},
#  {'name': 'WBTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 19628.0,
#   'bid': 19400.0,
#   'ask': 19414.0,
#   'price': 19414.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'WBTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.03705173354496305,
#   'change24h': 0.021090832588229108,
#   'changeBod': 0.011409221151341496,
#   'quoteVolume24h': 6164.6507,
#   'volumeUsd24h': 6164.6507,
#   'priceHigh24h': 20363.0,
#   'priceLow24h': 18977.0},
#  {'name': 'YFI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.00025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.43025,
#   'bid': 0.429,
#   'ask': 0.4335,
#   'price': 0.43025,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 576.0,
#   'change1h': 0.0,
#   'change24h': -0.0028968713789107765,
#   'changeBod': -0.008069164265129682,
#   'quoteVolume24h': 2.30337575,
#   'volumeUsd24h': 44692.827447042015,
#   'priceHigh24h': 0.43575,
#   'priceLow24h': 0.42275},
#  {'name': 'YFI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 8335.0,
#   'bid': 8340.0,
#   'ask': 8360.0,
#   'price': 8340.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.03750721292556261,
#   'change24h': 0.01707317073170732,
#   'changeBod': 0.0036101083032490976,
#   'quoteVolume24h': 173449.74,
#   'volumeUsd24h': 173449.74,
#   'priceHigh24h': 8855.0,
#   'priceLow24h': 8185.0},
#  {'name': 'YFI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 8390.0,
#   'bid': 8340.0,
#   'ask': 8365.0,
#   'price': 8365.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.034064665127020784,
#   'change24h': 0.019500304692260818,
#   'changeBod': 0.006618531889290012,
#   'quoteVolume24h': 100998.015,
#   'volumeUsd24h': 100981.18166083995,
#   'priceHigh24h': 8850.0,
#   'priceLow24h': 8195.0}]

# %% [markdown]
# > Since JSON format isn’t that easy to read, let’s convert it into a pandas dataframe.

# %%
df = pd.DataFrame(data)
df = df.set_index('name')
# using iloc to make it readable
df.iloc[:,:4].head()
# Out:
#            enabled  postOnly  priceIncrement  sizeIncrement
# name
# AAVE/USD      True     False          0.0100           0.01
# AAVE/USDT     True     False          0.0100           0.01
# ALGO/USD      True     False          0.0001           1.00
# ALGO/USDT     True     False          0.0001           1.00
# AUD/USD       True     False          0.0001           1.00

# %% [markdown]
# > Pretty easy, right? This will become second nature soon enough.

# %% [markdown]
# ## 3. Get an Individual Market Data

# %% [markdown]
# > You can use the following to get a single market.

# %%
# GET /markets/{market_name}
market_name = 'ETH/USD'
path = f'/markets/{market_name}'
url = api_url + path
url

'https://ftx.us/api/markets/ETH/USD'
# Out:
# 'https://ftx.us/api/markets/ETH/USD'

# %% [markdown]
# > Now let’s make the request and output the response as a dataframe.

# %%
res = requests.get(url).json()
df = pd.DataFrame(res)['result']
df = pd.DataFrame(data)
df = df.set_index('name')
# using iloc to make it readable
df.iloc[:,:].head()
# Out:
#            enabled  postOnly  priceIncrement  sizeIncrement  minProvideSize  \
# name
# AAVE/USD      True     False          0.0100           0.01            0.01
# AAVE/USDT     True     False          0.0100           0.01            0.01
# ALGO/USD      True     False          0.0001           1.00            1.00
# ALGO/USDT     True     False          0.0001           1.00            1.00
# AUD/USD       True     False          0.0001           1.00            1.00
#
#               last      bid      ask    price  type  ... restricted  \
# name                                                 ...
# AAVE/USD   76.9200  76.9200  76.9500  76.9200  spot  ...      False
# AAVE/USDT  76.9100  76.8700  77.0100  76.9100  spot  ...      False
# ALGO/USD    0.3548   0.3541   0.3552   0.3548  spot  ...      False
# ALGO/USDT   0.3551   0.3535   0.3549   0.3549  spot  ...      False
# AUD/USD     0.6501   0.6415   0.6426   0.6426  spot  ...      False
#
#           highLeverageFeeExempt largeOrderThreshold  change1h  change24h  \
# name
# AAVE/USD                   True               960.0 -0.024848   0.026147
# AAVE/USDT                  True               672.0 -0.024727   0.026151
# ALGO/USD                   True               960.0 -0.030601  -0.011699
# ALGO/USDT                  True               672.0 -0.033497  -0.011971
# AUD/USD                    True               280.0 -0.003103  -0.002793
#
#            changeBod  quoteVolume24h   volumeUsd24h  priceHigh24h  priceLow24h
# name
# AAVE/USD    0.010775     238548.3062  238548.306200       80.8600      74.8100
# AAVE/USDT   0.010511      38966.8792   38960.384590       80.8500      74.8100
# ALGO/USD   -0.031659     203420.5371  203420.537100        0.3747       0.3538
# ALGO/USDT  -0.029267       2148.5420    2148.183903        0.3747       0.3540
# AUD/USD    -0.006647          0.6501       0.650100        0.6502       0.6426
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 4. Get Historical Data

# %% [markdown]
# > You can also get historical data for any of the markets. Let’s get the data as daily bars starting from 2022.

# %%
# GET /markets/{market_name}/candles?resolution={resolution}&start_time={start_time}&end_time={end_time}
# Days is 60 seconds * 60 minutes * 24
resolution = 60*60*24
resolution
# Out:
# 86400

# %%
start = datetime.datetime(2019,1,1).timestamp()
start
# Out:
# 1546322400.0

# %% [markdown]
# > We’ll now construct the URL string and request as we’ve done above.

# %%
'''
# GET /markets/{market_name}
market_name = 'ETH/USD'
path = f'/markets/{market_name}'
url = api_url + path
url

'https://ftx.us/api/markets/ETH/USD'
'''
path = f'/markets/{market_name}/candles?resolution={resolution}&start={start}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/candles?resolution=86400&start=1546322400.0'

# %% [markdown]
# > And we’ll put the data into the dataframe and clean up the index.

# %%
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df['date'] = pd.to_datetime(df['startTime'])
df = df.set_index('date')
df = df.drop(columns=['startTime', 'time'])
df
# Out:
#                                open      high       low     close  \
# date
# 2020-03-23 00:00:00+00:00   130.355   136.935   129.625   136.775
# 2020-03-24 00:00:00+00:00   136.770   144.210   132.855   138.790
# 2020-03-25 00:00:00+00:00   138.785   142.980   132.750   136.115
# 2020-03-26 00:00:00+00:00   136.105   140.125   133.615   138.890
# 2020-03-27 00:00:00+00:00   138.890   141.955   129.320   131.425
# ...                             ...       ...       ...       ...
# 2022-09-23 00:00:00+00:00  1326.300  1361.100  1261.800  1327.500
# 2022-09-24 00:00:00+00:00  1327.500  1351.100  1306.700  1316.900
# 2022-09-25 00:00:00+00:00  1316.900  1336.200  1269.900  1294.600
# 2022-09-26 00:00:00+00:00  1294.600  1340.000  1278.600  1336.300
# 2022-09-27 00:00:00+00:00  1336.300  1400.000  1332.600  1339.300
#
#                                  volume
# date
# 2020-03-23 00:00:00+00:00  0.000000e+00
# 2020-03-24 00:00:00+00:00  0.000000e+00
# 2020-03-25 00:00:00+00:00  0.000000e+00
# 2020-03-26 00:00:00+00:00  0.000000e+00
# 2020-03-27 00:00:00+00:00  0.000000e+00
# ...                                 ...
# 2022-09-23 00:00:00+00:00  1.169653e+08
# 2022-09-24 00:00:00+00:00  4.605234e+07
# 2022-09-25 00:00:00+00:00  4.395761e+07
# 2022-09-26 00:00:00+00:00  4.590856e+07
# 2022-09-27 00:00:00+00:00  1.186708e+08
#
# [918 rows x 5 columns]

# %% [markdown]
# ## 5. Get Order Book Data

# %% [markdown]
# > We can also get the order book at varying depths.
# Let’s take a look at the order book for ETH/USD.

# %%
# GET /markets/{market_name}/orderbook?depth={depth}
depth = 20
path =  f'/markets/{market_name}/orderbook?depth={depth}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/orderbook?depth=20'

# %%
res = requests.get(url).json()
bids = pd.DataFrame(res['result']['bids'])
asks = pd.DataFrame(res['result']['asks'])
bids.columns = ['Bid Price', 'Bid Amount']
asks.columns = ['Ask Price','Ask Amount']
bids.head()
# Out:
#    Bid Price  Bid Amount
# 0     1340.4       6.400
# 1     1340.3      73.900
# 2     1340.2      49.491
# 3     1340.1      64.448
# 4     1340.0      65.000

# %% [markdown]
# > Let’s show the ask dataframe.

# %%
asks.head()
# Out:
#    Ask Price  Ask Amount
# 0     1340.5       6.962
# 1     1340.6       4.450
# 2     1340.7       9.385
# 3     1340.8      31.210
# 4     1340.9       4.450

# %% [markdown]
# > Now let’s merge the two dataframes and rename the columns.

# %%
df = pd.merge(bids, asks, left_index=True, right_index=True)
df.head()
# Out:
#    Bid Price  Bid Amount  Ask Price  Ask Amount
# 0     1340.4       6.400     1340.5       6.962
# 1     1340.3      73.900     1340.6       4.450
# 2     1340.2      49.491     1340.7       9.385
# 3     1340.1      64.448     1340.8      31.210
# 4     1340.0      65.000     1340.9       4.450

# %% [markdown]
# > And we can get the summary statistics using describe. Notice the depth as the count variable.

# %%
df.describe()
# Out:
#          Bid Price  Bid Amount    Ask Price  Ask Amount
# count    20.000000   20.000000    20.000000    20.00000
# mean   1339.255000   31.809700  1341.555000    34.43835
# std       0.733754   54.300258     0.697722    77.70467
# min    1338.100000    4.450000  1340.500000     4.45000
# 25%    1338.675000    4.450000  1340.975000     4.45000
# 50%    1339.150000    7.075000  1341.550000     7.56950
# 75%    1339.925000   34.785750  1342.050000    11.88400
# max    1340.400000  240.002000  1342.700000   314.25700

# %% [markdown]
# ## 6. Get Trades

# %% [markdown]
# > Getting the recent trades for any market is also easy.

# %%
# GET /markets/{market_name}/trades
path = f'/markets/{market_name}/trades'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/trades'

# %%
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df.head()
# Out:
#          id   price    size  side  liquidation  \
# 0  44830410  1340.2   0.002   buy        False
# 1  44830404  1339.8  32.000   buy        False
# 2  44829365  1339.1   0.003   buy        False
# 3  44830293  1339.7   0.171  sell        False
# 4  44830292  1339.7  18.025  sell        False
#
#                                time
# 0  2022-09-27T16:34:04.116730+00:00
# 1  2022-09-27T16:33:56.490561+00:00
# 2  2022-09-27T16:33:49.130319+00:00
# 3  2022-09-27T16:33:35.404527+00:00
# 4  2022-09-27T16:33:35.404527+00:00

# %% [markdown]
# ## 7. Working with FTX Futures

# %% [markdown]
# > Now that you’ve learned how to use the Markets API, using the Futures API is just as easy. I’ll get you started. One thing to note is that futures are not available through the ftx.us API.<br><br>
# First, check out the futures API documentation. You’ll notice we need to make a get request to /futures. Let’s create the request URL and use requests to get the data.

# %%
url = 'https://ftx.com/api/futures'
res = requests.get(url).json()
res
# Out:
# {'success': True,
#  'result': [{'name': '1INCH-PERP',
#    'underlying': '1INCH',
#    'description': '1INCH Token Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6261,
#    'bid': 0.6261,
#    'ask': 0.6264,
#    'index': 0.626668655,
#    'mark': 0.6253,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.595,
#    'upperBound': 0.658,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.6253,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.017750549795790136,
#    'change24h': 0.005143867545410706,
#    'changeBod': 0.0014413837283792441,
#    'volumeUsd24h': 4820313.8768,
#    'volume': 7595719.0,
#    'openInterest': 8303163.0,
#    'openInterestUsd': 5191967.8239},
#   {'name': '1INCH-0930',
#    'underlying': '1INCH',
#    'description': '1INCH Token September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6241,
#    'bid': 0.621,
#    'ask': 0.6241,
#    'index': 0.626668655,
#    'mark': 0.6241,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.5937,
#    'upperBound': 0.658,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.6241,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.012343725272986232,
#    'change24h': 0.00938055959890021,
#    'changeBod': 0.006775286336505888,
#    'volumeUsd24h': 8855.529,
#    'volume': 14056.0,
#    'openInterest': 116320.0,
#    'openInterestUsd': 72595.312},
#   {'name': '1INCH-1230',
#    'underlying': '1INCH',
#    'description': '1INCH Token December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.6234,
#    'bid': 0.6025,
#    'ask': 0.6077,
#    'index': 0.626668655,
#    'mark': 0.6099,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.5768,
#    'upperBound': 0.658,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.6099,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.011827608554763449,
#    'change24h': 0.01027000165645188,
#    'changeBod': 0.007100396301188904,
#    'volumeUsd24h': 327.167,
#    'volume': 532.0,
#    'openInterest': 21391.0,
#    'openInterestUsd': 13046.3709},
#   {'name': 'AAPL-0930',
#    'underlying': 'AAPL',
#    'description': 'Apple September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 150.9,
#    'bid': 150.59,
#    'ask': 151.5,
#    'index': 151.05,
#    'mark': 150.9,
#    'imfFactor': 0.00125,
#    'lowerBound': 143.36,
#    'upperBound': 158.6,
#    'underlyingDescription': 'Apple',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 150.9,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.010362014690451206,
#    'change24h': -0.0003312355084465055,
#    'changeBod': -0.0024459575593309977,
#    'volumeUsd24h': 14693.123,
#    'volume': 96.1,
#    'openInterest': 8659.12,
#    'openInterestUsd': 1306661.208},
#   {'name': 'AAPL-1230',
#    'underlying': 'AAPL',
#    'description': 'Apple December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 150.42,
#    'bid': 150.69,
#    'ask': 151.02,
#    'index': 151.05,
#    'mark': 150.42,
#    'imfFactor': 0.00125,
#    'lowerBound': 143.16,
#    'upperBound': 158.6,
#    'underlyingDescription': 'Apple',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 150.42,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.010199381456866486,
#    'change24h': -0.0019904458598726115,
#    'changeBod': -0.0045662100456621,
#    'volumeUsd24h': 68675.4079,
#    'volume': 450.47,
#    'openInterest': 789.21,
#    'openInterestUsd': 118712.9682},
#   {'name': 'AAVE-PERP',
#    'underlying': 'AAVE',
#    'description': 'Aave Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 76.95,
#    'bid': 76.95,
#    'ask': 76.97,
#    'index': 76.974321152,
#    'mark': 76.89,
#    'imfFactor': 0.0025,
#    'lowerBound': 73.12,
#    'upperBound': 80.82,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 76.89,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.024857324032974002,
#    'change24h': 0.02698009883798584,
#    'changeBod': 0.00905511811023622,
#    'volumeUsd24h': 14215982.7574,
#    'volume': 181011.6,
#    'openInterest': 194219.57,
#    'openInterestUsd': 14933542.7373},
#   {'name': 'AAVE-0930',
#    'underlying': 'AAVE',
#    'description': 'Aave September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 78.39,
#    'bid': 76.79,
#    'ask': 77.45,
#    'index': 76.974321152,
#    'mark': 77.45,
#    'imfFactor': 0.0025,
#    'lowerBound': 73.13,
#    'upperBound': 81.36,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 77.45,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.023452275879460346,
#    'change24h': 0.02637158759607739,
#    'changeBod': 0.019078947368421053,
#    'volumeUsd24h': 5436.9297,
#    'volume': 68.89,
#    'openInterest': 2253.31,
#    'openInterestUsd': 174518.8595},
#   {'name': 'AAVE-1230',
#    'underlying': 'AAVE',
#    'description': 'Aave December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 76.62,
#    'bid': 75.89,
#    'ask': 76.69,
#    'index': 76.974321152,
#    'mark': 76.62,
#    'imfFactor': 0.0025,
#    'lowerBound': 72.79,
#    'upperBound': 80.82,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 76.62,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.026429479034307497,
#    'change24h': 0.02556552001070807,
#    'changeBod': 0.014968870049013115,
#    'volumeUsd24h': 3124.5374,
#    'volume': 39.61,
#    'openInterest': 984.97,
#    'openInterestUsd': 75468.4014},
#   {'name': 'ABNB-0930',
#    'underlying': 'ABNB',
#    'description': 'Airbnb September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.025,
#    'last': 105.18,
#    'bid': 104.865,
#    'ask': 105.335,
#    'index': 105.365,
#    'mark': 105.18,
#    'imfFactor': 0.005,
#    'lowerBound': 100.015,
#    'upperBound': 110.625,
#    'underlyingDescription': 'Airbnb',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 105.18,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.013089373680506685,
#    'change24h': 0.015055008685581933,
#    'changeBod': 0.011297533772414789,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 150.0,
#    'openInterestUsd': 15777.0},
#   {'name': 'ABNB-1230',
#    'underlying': 'ABNB',
#    'description': 'Airbnb December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.025,
#    'last': 110.24,
#    'bid': 104.855,
#    'ask': 105.46,
#    'index': 105.365,
#    'mark': 105.21,
#    'imfFactor': 0.005,
#    'lowerBound': 100.105,
#    'upperBound': 110.75,
#    'underlyingDescription': 'Airbnb',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 105.21,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.018151276188698613,
#    'change24h': 0.015197568389057751,
#    'changeBod': 0.00964445084209011,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 100.0,
#    'openInterestUsd': 10521.0},
#   {'name': 'ACB-0930',
#    'underlying': 'ACB',
#    'description': 'Aurora Cannabis Inc September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 1.196,
#    'bid': 1.186,
#    'ask': 1.193,
#    'index': 1.194,
#    'mark': 1.193,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.134,
#    'upperBound': 1.253,
#    'underlyingDescription': 'Aurora Cannabis Inc',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1.193,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.025326797385620915,
#    'change24h': 0.017050298380221655,
#    'changeBod': 0.019658119658119658,
#    'volumeUsd24h': 6597.3919,
#    'volume': 5535.6,
#    'openInterest': 107.1,
#    'openInterestUsd': 127.7703},
#   {'name': 'ACB-1230',
#    'underlying': 'ACB',
#    'description': 'Aurora Cannabis Inc December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 1.25,
#    'bid': 1.183,
#    'ask': 1.194,
#    'index': 1.194,
#    'mark': 1.194,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.135,
#    'upperBound': 1.253,
#    'underlyingDescription': 'Aurora Cannabis Inc',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1.194,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.024509803921568627,
#    'change24h': 0.013582342954159592,
#    'changeBod': -0.03319838056680162,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 2429.2,
#    'openInterestUsd': 2900.4648},
#   {'name': 'ADA-PERP',
#    'underlying': 'ADA',
#    'description': 'Cardano Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.4439,
#    'bid': 0.443865,
#    'ask': 0.443895,
#    'index': 0.4441453141452381,
#    'mark': 0.443675,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.42171,
#    'upperBound': 0.46635,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.443675,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.025243592982764494,
#    'change24h': 0.001896869037000237,
#    'changeBod': -0.007704866702451243,
#    'volumeUsd24h': 39193457.18824,
#    'volume': 86463879.0,
#    'openInterest': 122359767.0,
#    'openInterestUsd': 54287969.623725},
#   {'name': 'ADA-0930',
#    'underlying': 'ADA',
#    'description': 'Cardano September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.443225,
#    'bid': 0.44249,
#    'ask': 0.44317,
#    'index': 0.4441453141452381,
#    'mark': 0.44317,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.42096,
#    'upperBound': 0.46635,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.44317,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.02338137423421041,
#    'change24h': 0.0031236560356730572,
#    'changeBod': -0.005564905194659486,
#    'volumeUsd24h': 701778.571435,
#    'volume': 1544374.0,
#    'openInterest': 7234566.0,
#    'openInterestUsd': 3206142.61422},
#   {'name': 'ADA-1230',
#    'underlying': 'ADA',
#    'description': 'Cardano December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.434325,
#    'bid': 0.434325,
#    'ask': 0.43687,
#    'index': 0.4441453141452381,
#    'mark': 0.434325,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.412445,
#    'upperBound': 0.46635,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.434325,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.02580580041719938,
#    'change24h': 0.0013602775888503348,
#    'changeBod': -0.0068939497873508025,
#    'volumeUsd24h': 24198.82825,
#    'volume': 54271.0,
#    'openInterest': 3318454.0,
#    'openInterestUsd': 1441287.53355},
#   {'name': 'AGLD-PERP',
#    'underlying': 'AGLD',
#    'description': 'Adventure Gold Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 0.3205,
#    'bid': 0.3205,
#    'ask': 0.321,
#    'index': 0.32141192333333335,
#    'mark': 0.3205,
#    'imfFactor': 0.001,
#    'lowerBound': 0.305,
#    'upperBound': 0.337,
#    'underlyingDescription': 'Adventure Gold',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.3205,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.025835866261398176,
#    'change24h': 0.007861635220125786,
#    'changeBod': -0.018376722817764167,
#    'volumeUsd24h': 1508127.42865,
#    'volume': 4577092.1,
#    'openInterest': 1492348.8,
#    'openInterestUsd': 478297.7904},
#   {'name': 'ALCX-PERP',
#    'underlying': 'ALCX',
#    'description': 'Alchemix Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 20.2,
#    'bid': 20.2,
#    'ask': 20.3,
#    'index': 20.3,
#    'mark': 20.2,
#    'imfFactor': 0.025,
#    'lowerBound': 19.2,
#    'upperBound': 21.3,
#    'underlyingDescription': 'Alchemix',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 20.2,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.024154589371980676,
#    'change24h': 0.004975124378109453,
#    'changeBod': 0.0,
#    'volumeUsd24h': 362145.9007,
#    'volume': 17346.779,
#    'openInterest': 24210.923,
#    'openInterestUsd': 489060.6446},
#   {'name': 'ALGO-PERP',
#    'underlying': 'ALGO',
#    'description': 'Algorand Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.354,
#    'bid': 0.354,
#    'ask': 0.3541,
#    'index': 0.3542970829593798,
#    'mark': 0.3537,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3363,
#    'upperBound': 0.372,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.3537,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.03545132260703572,
#    'change24h': -0.012287070650656241,
#    'changeBod': -0.03650231544538273,
#    'volumeUsd24h': 25012246.6954,
#    'volume': 67607664.0,
#    'openInterest': 39551220.0,
#    'openInterestUsd': 13989266.514},
#   {'name': 'ALGO-0930',
#    'underlying': 'ALGO',
#    'description': 'Algorand September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.3546,
#    'bid': 0.3532,
#    'ask': 0.3559,
#    'index': 0.3542970829593798,
#    'mark': 0.3546,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3366,
#    'upperBound': 0.3723,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.3546,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.03510204081632653,
#    'change24h': -0.013630041724617525,
#    'changeBod': -0.03824247355573637,
#    'volumeUsd24h': 32443.5445,
#    'volume': 88529.0,
#    'openInterest': 435286.0,
#    'openInterestUsd': 154352.4156},
#   {'name': 'ALGO-1230',
#    'underlying': 'ALGO',
#    'description': 'Algorand December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.3562,
#    'bid': 0.3551,
#    'ask': 0.3579,
#    'index': 0.3542970829593798,
#    'mark': 0.3562,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.3366,
#    'upperBound': 0.3743,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.3562,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.034688346883468835,
#    'change24h': -0.013569648296870672,
#    'changeBod': -0.0302205281786006,
#    'volumeUsd24h': 32436.0445,
#    'volume': 87125.0,
#    'openInterest': 336115.0,
#    'openInterestUsd': 119724.163},
#   {'name': 'ALICE-PERP',
#    'underlying': 'ALICE',
#    'description': 'MyNeighborAlice Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 1.72,
#    'bid': 1.7175,
#    'ask': 1.72,
#    'index': 1.7172760333333332,
#    'mark': 1.7175,
#    'imfFactor': 0.0025,
#    'lowerBound': 1.6325,
#    'upperBound': 1.8025,
#    'underlyingDescription': 'MyNeighborAlice',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.7175,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.019971469329529243,
#    'change24h': 0.025373134328358207,
#    'changeBod': 0.0,
#    'volumeUsd24h': 1163621.44325,
#    'volume': 667420.3,
#    'openInterest': 856876.3,
#    'openInterestUsd': 1471685.04525},
#   {'name': 'ALPHA-PERP',
#    'underlying': 'ALPHA',
#    'description': 'Alpha Finance Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.1084,
#    'bid': 0.10835,
#    'ask': 0.10845,
#    'index': 0.10839223437619047,
#    'mark': 0.10825,
#    'imfFactor': 0.00025,
#    'lowerBound': 0.103,
#    'upperBound': 0.1138,
#    'underlyingDescription': 'Alpha Finance',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.10825,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.01635620172648796,
#    'change24h': 0.04136604136604136,
#    'changeBod': 0.03046168491194669,
#    'volumeUsd24h': 1206145.72805,
#    'volume': 11053337.0,
#    'openInterest': 6812198.0,
#    'openInterestUsd': 737420.4335},
#   {'name': 'ALT-PERP',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1854.75,
#    'bid': 1854.6,
#    'ask': 1856.25,
#    'index': 1856.3431313724373,
#    'mark': 1853.95,
#    'imfFactor': 0.0008,
#    'lowerBound': 1762.8,
#    'upperBound': 1949.15,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1853.95,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 2.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.027257463665459888,
#    'change24h': 0.006788128920144451,
#    'changeBod': -0.006164732370205581,
#    'volumeUsd24h': 3389790.36875,
#    'volume': 1780.714,
#    'openInterest': 5181.806,
#    'openInterestUsd': 9606809.2337},
#   {'name': 'ALT-0930',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1850.0,
#    'bid': 1846.1,
#    'ask': 1857.8,
#    'index': 1856.3431313724373,
#    'mark': 1850.0,
#    'imfFactor': 0.0008,
#    'lowerBound': 1756.7,
#    'upperBound': 1949.15,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1850.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.028871391076115485,
#    'change24h': 0.006255099265705739,
#    'changeBod': -0.004975124378109453,
#    'volumeUsd24h': 35335.90555,
#    'volume': 18.669,
#    'openInterest': 605.916,
#    'openInterestUsd': 1120944.6},
#   {'name': 'ALT-1230',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 1821.6,
#    'bid': 1816.75,
#    'ask': 1829.1,
#    'index': 1856.3431313724373,
#    'mark': 1821.6,
#    'imfFactor': 0.0008,
#    'lowerBound': 1726.75,
#    'upperBound': 1949.15,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1821.6,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.02759835584263065,
#    'change24h': 0.0064088397790055245,
#    'changeBod': -0.005514003384833761,
#    'volumeUsd24h': 5658.5761,
#    'volume': 3.016,
#    'openInterest': 132.922,
#    'openInterestUsd': 242130.7152},
#   {'name': 'AMC-0930',
#    'underlying': 'AMC',
#    'description': 'AMC Entertainment Holdings September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 12.9,
#    'bid': 12.99,
#    'ask': 13.325,
#    'index': 13.1275,
#    'mark': 12.98,
#    'imfFactor': 0.0025,
#    'indexAdjustment': 6.0,
#    'lowerBound': 10.35,
#    'upperBound': 15.75,
#    'underlyingDescription': 'AMC Entertainment Holdings',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 12.98,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.03548207319338659,
#    'change24h': -0.02240632649218603,
#    'changeBod': 0.01803921568627451,
#    'volumeUsd24h': 15680.395,
#    'volume': 1205.3,
#    'openInterest': 33553.5,
#    'openInterestUsd': 435524.43},
#   {'name': 'AMC-1230',
#    'underlying': 'AMC',
#    'description': 'AMC Entertainment Holdings December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 7.3375,
#    'bid': 7.0875,
#    'ask': 7.1375,
#    'index': 7.1275,
#    'mark': 7.1275,
#    'imfFactor': 0.0025,
#    'lowerBound': 5.7,
#    'upperBound': 8.55,
#    'underlyingDescription': 'AMC Entertainment Holdings',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 7.1275,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.01825068870523416,
#    'change24h': -0.04071332436069987,
#    'changeBod': 0.026277897768178547,
#    'volumeUsd24h': 2908.5865,
#    'volume': 406.3,
#    'openInterest': 1135.2,
#    'openInterestUsd': 8091.138},
#   {'name': 'AMD-0930',
#    'underlying': 'AMD',
#    'description': 'Advanced Micro Devices September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 66.52,
#    'bid': 66.44,
#    'ask': 66.77,
#    'index': 66.58,
#    'mark': 66.52,
#    'imfFactor': 0.001,
#    'lowerBound': 63.26,
#    'upperBound': 70.02,
#    'underlyingDescription': 'Advanced Micro Devices',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 66.52,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.017865052413996753,
#    'change24h': -0.003296373988612526,
#    'changeBod': -0.006719426608929371,
#    'volumeUsd24h': 4028.7101,
#    'volume': 60.02,
#    'openInterest': 934.76,
#    'openInterestUsd': 62180.2352},
#   {'name': 'AMD-1230',
#    'underlying': 'AMD',
#    'description': 'Advanced Micro Devices December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 66.23,
#    'bid': 66.44,
#    'ask': 66.78,
#    'index': 66.58,
#    'mark': 66.44,
#    'imfFactor': 0.001,
#    'lowerBound': 63.25,
#    'upperBound': 69.9,
#    'underlyingDescription': 'Advanced Micro Devices',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 66.44,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.017740981667652277,
#    'change24h': -0.0038980509745127436,
#    'changeBod': -0.007469375560203167,
#    'volumeUsd24h': 7308.95,
#    'volume': 108.75,
#    'openInterest': 1151.24,
#    'openInterestUsd': 76488.3856},
#   {'name': 'AMPL-PERP',
#    'underlying': 'AMPL',
#    'description': 'Ampleforth Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 10.0,
#    'last': 1.0969,
#    'bid': 1.096,
#    'ask': 1.0979,
#    'index': 1.0956771387828572,
#    'mark': 1.0969,
#    'imfFactor': 0.0005,
#    'lowerBound': 1.0409,
#    'upperBound': 1.1518,
#    'underlyingDescription': 'Ampleforth',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.0969,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.03458898081323711,
#    'change24h': -0.060953685472134235,
#    'changeBod': -0.05292695562079088,
#    'volumeUsd24h': 303595.839,
#    'volume': 263940.0,
#    'openInterest': 431640.0,
#    'openInterestUsd': 473465.916},
#   {'name': 'AMZN-0930',
#    'underlying': 'AMZN',
#    'description': 'Amazon September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 116.7,
#    'bid': 113.3,
#    'ask': 113.8,
#    'index': 113.5,
#    'mark': 113.9,
#    'imfFactor': 0.00067,
#    'lowerBound': 107.9,
#    'upperBound': 119.5,
#    'underlyingDescription': 'Amazon',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 113.9,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.0078397212543554,
#    'change24h': -0.006108202443280977,
#    'changeBod': -0.012998266897746967,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 11000.701,
#    'openInterestUsd': 1252979.8439},
#   {'name': 'AMZN-1230',
#    'underlying': 'AMZN',
#    'description': 'Amazon December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 113.2,
#    'bid': 113.2,
#    'ask': 113.9,
#    'index': 113.5,
#    'mark': 113.4,
#    'imfFactor': 0.00067,
#    'lowerBound': 107.7,
#    'upperBound': 119.1,
#    'underlyingDescription': 'Amazon',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 113.4,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.00960698689956332,
#    'change24h': -0.007874015748031496,
#    'changeBod': -0.011333914559721011,
#    'volumeUsd24h': 662.8973,
#    'volume': 5.751,
#    'openInterest': 138.656,
#    'openInterestUsd': 15723.5904},
#   {'name': 'ANC-PERP',
#    'underlying': 'ANC',
#    'description': 'Anchor Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': False,
#    'postOnly': False,
#    'priceIncrement': 0.00025,
#    'sizeIncrement': 1.0,
#    'last': None,
#    'bid': None,
#    'ask': None,
#    'index': 0.092430756,
#    'mark': 0.092783476,
#    'imfFactor': 0.0003,
#    'lowerBound': 0.137,
#    'upperBound': 0.1515,
#    'underlyingDescription': 'Anchor',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.092783476,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.3578998200692042,
#    'change24h': -0.3578998200692042,
#    'changeBod': -0.3578998200692042,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 0.0,
#    'openInterestUsd': 0.0},
#   {'name': 'APE-PERP',
#    'underlying': 'APE',
#    'description': 'ApeCoin Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.412,
#    'bid': 5.4105,
#    'ask': 5.4125,
#    'index': 5.4195,
#    'mark': 5.41,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.1465,
#    'upperBound': 5.69,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 5.41,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.04298602511940563,
#    'change24h': 0.0004623208506703652,
#    'changeBod': -0.018326982398838686,
#    'volumeUsd24h': 36368880.8705,
#    'volume': 6454837.5,
#    'openInterest': 6445314.4,
#    'openInterestUsd': 34869150.904},
#   {'name': 'APE-0930',
#    'underlying': 'APE',
#    'description': 'ApeCoin September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.58,
#    'bid': 5.3975,
#    'ask': 5.417,
#    'index': 5.4195,
#    'mark': 5.417,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.149,
#    'upperBound': 5.6915,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 5.417,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.039794380927058406,
#    'change24h': 0.0007389617587289858,
#    'changeBod': -0.013027238771977772,
#    'volumeUsd24h': 4072.5136,
#    'volume': 724.7,
#    'openInterest': 35592.3,
#    'openInterestUsd': 192803.4891},
#   {'name': 'APE-1230',
#    'underlying': 'APE',
#    'description': 'ApeCoin December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 5.317,
#    'bid': 5.2715,
#    'ask': 5.303,
#    'index': 5.4195,
#    'mark': 5.298,
#    'imfFactor': 0.0005,
#    'lowerBound': 5.0305,
#    'upperBound': 5.69,
#    'underlyingDescription': 'ApeCoin',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 5.298,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.03969548667754214,
#    'change24h': 0.00122838514598885,
#    'changeBod': -0.0131321598211791,
#    'volumeUsd24h': 2702.63375,
#    'volume': 490.9,
#    'openInterest': 208746.8,
#    'openInterestUsd': 1105940.5464},
#   {'name': 'AR-PERP',
#    'underlying': 'AR',
#    'description': 'Arweave Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 9.604,
#    'bid': 9.597,
#    'ask': 9.601,
#    'index': 9.59234067,
#    'mark': 9.595,
#    'imfFactor': 0.0025,
#    'lowerBound': 9.113,
#    'upperBound': 10.075,
#    'underlyingDescription': 'Arweave',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 9.595,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.029828109201213347,
#    'change24h': 0.02719194947007815,
#    'changeBod': 0.016527174488822967,
#    'volumeUsd24h': 2239213.4506,
#    'volume': 229927.2,
#    'openInterest': 255187.5,
#    'openInterestUsd': 2448524.0625},
#   {'name': 'ARKK-0930',
#    'underlying': 'ARKK',
#    'description': 'ARK Innovation ETF September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 38.87,
#    'bid': 37.84,
#    'ask': 38.08,
#    'index': 37.97,
#    'mark': 38.08,
#    'imfFactor': 0.005,
#    'lowerBound': 36.08,
#    'upperBound': 39.93,
#    'underlyingDescription': 'ARK Innovation ETF',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 38.08,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.016020671834625324,
#    'change24h': 0.011152416356877323,
#    'changeBod': 0.01276595744680851,
#    'volumeUsd24h': 59711.3919,
#    'volume': 1546.52,
#    'openInterest': 11436.4,
#    'openInterestUsd': 435498.112},
#   {'name': 'ARKK-1230',
#    'underlying': 'ARKK',
#    'description': 'ARK Innovation ETF December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 38.92,
#    'bid': 37.85,
#    'ask': 38.08,
#    'index': 37.97,
#    'mark': 38.08,
#    'imfFactor': 0.005,
#    'lowerBound': 36.08,
#    'upperBound': 39.95,
#    'underlyingDescription': 'ARK Innovation ETF',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 38.08,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.018556701030927835,
#    'change24h': 0.011152416356877323,
#    'changeBod': 0.011689691817215728,
#    'volumeUsd24h': 34138.5435,
#    'volume': 889.21,
#    'openInterest': 2711.9,
#    'openInterestUsd': 103269.152},
#   {'name': 'ASD-PERP',
#    'underlying': 'ASD',
#    'description': 'AscendEx Token (BTMX) Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 0.1,
#    'last': 0.10624,
#    'bid': 0.10595,
#    'ask': 0.10625,
#    'index': 0.10626,
#    'mark': 0.10624,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.10089,
#    'upperBound': 0.11157,
#    'underlyingDescription': 'AscendEx Token (BTMX)',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.10624,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.0007524454477050414,
#    'change24h': 0.027168133036836507,
#    'changeBod': -0.00477751756440281,
#    'volumeUsd24h': 188116.026224,
#    'volume': 1771176.0,
#    'openInterest': 17229911.8,
#    'openInterestUsd': 1830505.829632},
#   {'name': 'ATLAS-PERP',
#    'underlying': 'ATLAS',
#    'description': 'Atlas Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-07,
#    'sizeIncrement': 10.0,
#    'last': 0.00449925,
#    'bid': 0.00448475,
#    'ask': 0.0044995,
#    'index': 0.00449675,
#    'mark': 0.00449925,
#    'imfFactor': 2.5e-05,
#    'lowerBound': 0.004272,
#    'upperBound': 0.00472275,
#    'underlyingDescription': 'Atlas',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.00449925,
#    'imfWeight': 4.0,
#    'mmfWeight': 4.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.009575697540036322,
#    'change24h': 0.0045771699692994695,
#    'changeBod': -0.008429752066115702,
#    'volumeUsd24h': 129414.2010075,
#    'volume': 28489840.0,
#    'openInterest': 146077020.0,
#    'openInterestUsd': 657237.032235},
#   {'name': 'ATOM-PERP',
#    'underlying': 'ATOM',
#    'description': 'Cosmos Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 13.629,
#    'bid': 13.631,
#    'ask': 13.6335,
#    'index': 13.627809437264286,
#    'mark': 13.608,
#    'imfFactor': 0.0004,
#    'lowerBound': 12.927,
#    'upperBound': 14.309,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 13.608,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.032595172928589204,
#    'change24h': -0.02633085289066972,
#    'changeBod': -0.016905071521456438,
#    'volumeUsd24h': 154716840.66276,
#    'volume': 10933061.22,
#    'openInterest': 3751477.93,
#    'openInterestUsd': 51050111.67144},
#   {'name': 'ATOM-0930',
#    'underlying': 'ATOM',
#    'description': 'Cosmos September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 13.5515,
#    'bid': 13.553,
#    'ask': 13.6385,
#    'index': 13.627809437264286,
#    'mark': 13.5515,
#    'imfFactor': 0.0004,
#    'lowerBound': 12.884,
#    'upperBound': 14.309,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 13.5515,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.03255398893449937,
#    'change24h': -0.0292621776504298,
#    'changeBod': -0.017829316905236457,
#    'volumeUsd24h': 41789.407325,
#    'volume': 2936.51,
#    'openInterest': 19287.86,
#    'openInterestUsd': 261379.43479},
#   {'name': 'ATOM-1230',
#    'underlying': 'ATOM',
#    'description': 'Cosmos December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 13.283,
#    'bid': 13.177,
#    'ask': 13.2855,
#    'index': 13.627809437264286,
#    'mark': 13.276,
#    'imfFactor': 0.0004,
#    'lowerBound': 12.592,
#    'upperBound': 14.309,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 13.276,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.02860905831565084,
#    'change24h': -0.02525697503671072,
#    'changeBod': -0.012973495409092598,
#    'volumeUsd24h': 581847.491005,
#    'volume': 42273.59,
#    'openInterest': 155035.9,
#    'openInterestUsd': 2058256.6084},
#   {'name': 'AUDIO-PERP',
#    'underlying': 'AUDIO',
#    'description': 'Audius Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 0.216,
#    'bid': 0.2155,
#    'ask': 0.216,
#    'index': 0.21559502057142857,
#    'mark': 0.216,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.205,
#    'upperBound': 0.2265,
#    'underlyingDescription': 'Audius',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.216,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.02040816326530612,
#    'change24h': 0.006993006993006993,
#    'changeBod': -0.006896551724137931,
#    'volumeUsd24h': 763718.2161,
#    'volume': 3428678.2,
#    'openInterest': 3918341.9,
#    'openInterestUsd': 846361.8504},
#   {'name': 'AVAX-PERP',
#    'underlying': 'AVAX',
#    'description': 'Avalanche Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.488,
#    'bid': 17.484,
#    'ask': 17.486,
#    'index': 17.51079009757143,
#    'mark': 17.47,
#    'imfFactor': 0.0007,
#    'lowerBound': 16.607,
#    'upperBound': 18.386,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 17.47,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.02717451832052567,
#    'change24h': 0.015107495642068565,
#    'changeBod': -0.0033089913281606573,
#    'volumeUsd24h': 52541966.8758,
#    'volume': 2926937.1,
#    'openInterest': 2661301.2,
#    'openInterestUsd': 46492931.964},
#   {'name': 'AVAX-0930',
#    'underlying': 'AVAX',
#    'description': 'Avalanche September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.48,
#    'bid': 17.448,
#    'ask': 17.476,
#    'index': 17.51079009757143,
#    'mark': 17.478,
#    'imfFactor': 0.0007,
#    'lowerBound': 16.573,
#    'upperBound': 18.386,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 17.478,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.025752508361204015,
#    'change24h': 0.016221873364730507,
#    'changeBod': -0.0013712718546451835,
#    'volumeUsd24h': 493468.615,
#    'volume': 27903.3,
#    'openInterest': 32386.5,
#    'openInterestUsd': 566051.247},
#   {'name': 'AVAX-1230',
#    'underlying': 'AVAX',
#    'description': 'Avalanche December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 17.236,
#    'bid': 16.618,
#    'ask': 17.441,
#    'index': 17.51079009757143,
#    'mark': 17.236,
#    'imfFactor': 0.0007,
#    'lowerBound': 16.331,
#    'upperBound': 18.386,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 17.236,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.016041559627790147,
#    'change24h': 0.024488825487398953,
#    'changeBod': 0.008130081300813009,
#    'volumeUsd24h': 23805.7636,
#    'volume': 1369.4,
#    'openInterest': 35128.1,
#    'openInterestUsd': 605467.9316},
#   {'name': 'AXS-PERP',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 12.487,
#    'bid': 12.485,
#    'ask': 12.491,
#    'index': 12.493733843333333,
#    'mark': 12.474,
#    'imfFactor': 0.001,
#    'lowerBound': 11.852,
#    'upperBound': 13.118,
#    'underlyingDescription': 'Axie Infinity',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 12.474,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.01918540651045762,
#    'change24h': 0.021788990825688075,
#    'changeBod': 0.002652519893899204,
#    'volumeUsd24h': 11372147.3654,
#    'volume': 900915.0,
#    'openInterest': 1569792.4,
#    'openInterestUsd': 19581590.3976},
#   {'name': 'AXS-0930',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 12.528,
#    'bid': 12.391,
#    'ask': 12.476,
#    'index': 12.493733843333333,
#    'mark': 12.475,
#    'imfFactor': 0.001,
#    'lowerBound': 11.861,
#    'upperBound': 13.118,
#    'underlyingDescription': 'Axie Infinity',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 12.475,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.01848937844217152,
#    'change24h': 0.029120607160534565,
#    'changeBod': 0.009385872643417753,
#    'volumeUsd24h': 3386.6548,
#    'volume': 269.5,
#    'openInterest': 72169.1,
#    'openInterestUsd': 900309.5225},
#   {'name': 'AXS-1230',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
# ...
#   {'name': 'XLM-PERP',
#    'underlying': 'XLM',
#    'description': 'Stellar Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.111575,
#    'bid': 0.111575,
#    'ask': 0.1116,
#    'index': 0.11162239441428572,
#    'mark': 0.111475,
#    'imfFactor': 5e-05,
#    'lowerBound': 0.106,
#    'upperBound': 0.1172,
#    'underlyingDescription': 'Stellar',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.111475,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.024715660542432197,
#    'change24h': -0.012403100775193798,
#    'changeBod': -0.021505376344086023,
#    'volumeUsd24h': 7764658.45435,
#    'volume': 67923569.0,
#    'openInterest': 106098955.0,
#    'openInterestUsd': 11827381.008625},
#   {'name': 'XMR-PERP',
#    'underlying': 'XMR',
#    'description': 'Monero Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 147.84,
#    'bid': 147.86,
#    'ask': 147.9,
#    'index': 147.85702683857141,
#    'mark': 147.84,
#    'imfFactor': 0.002,
#    'lowerBound': 140.47,
#    'upperBound': 155.29,
#    'underlyingDescription': 'Monero',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 147.84,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.011764705882352941,
#    'change24h': 0.028881620154499268,
#    'changeBod': 0.01440922190201729,
#    'volumeUsd24h': 5393038.6844,
#    'volume': 36127.19,
#    'openInterest': 53365.83,
#    'openInterestUsd': 7889604.3072},
#   {'name': 'XRP-PERP',
#    'underlying': 'XRP',
#    'description': 'XRP Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.4512,
#    'bid': 0.451225,
#    'ask': 0.45135,
#    'index': 0.4504675,
#    'mark': 0.4509,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.42795,
#    'upperBound': 0.473025,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.4509,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 4.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.04272596995913168,
#    'change24h': -0.03105189642204792,
#    'changeBod': -0.034268579995716426,
#    'volumeUsd24h': 182018652.7836,
#    'volume': 385689584.0,
#    'openInterest': 202644369.0,
#    'openInterestUsd': 91372345.9821},
#   {'name': 'XRP-0930',
#    'underlying': 'XRP',
#    'description': 'XRP September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.45,
#    'bid': 0.45035,
#    'ask': 0.451,
#    'index': 0.4504675,
#    'mark': 0.45,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.4273,
#    'upperBound': 0.472975,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 0.45,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 8.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.043316502790326866,
#    'change24h': -0.03215399505323153,
#    'changeBod': -0.035421467231123736,
#    'volumeUsd24h': 985658.62315,
#    'volume': 2104977.0,
#    'openInterest': 3628726.0,
#    'openInterestUsd': 1632926.7},
#   {'name': 'XRP-1230',
#    'underlying': 'XRP',
#    'description': 'XRP December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.44625,
#    'bid': 0.447275,
#    'ask': 0.44835,
#    'index': 0.4504675,
#    'mark': 0.446925,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.4241,
#    'upperBound': 0.472975,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 0.446925,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 8.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.04579663730984788,
#    'change24h': -0.03664385407123996,
#    'changeBod': -0.03778459551106088,
#    'volumeUsd24h': 256723.568175,
#    'volume': 545896.0,
#    'openInterest': 1315386.0,
#    'openInterestUsd': 587878.88805},
#   {'name': 'XTZ-PERP',
#    'underlying': 'XTZ',
#    'description': 'Tezos Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.4753,
#    'bid': 1.4754,
#    'ask': 1.4756,
#    'index': 1.4751252952333334,
#    'mark': 1.474,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.4012,
#    'upperBound': 1.5488,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.474,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.020988310308182784,
#    'change24h': 0.012084592145015106,
#    'changeBod': 0.0005430355688297583,
#    'volumeUsd24h': 4376433.0884782,
#    'volume': 2900026.431,
#    'openInterest': 5113302.582,
#    'openInterestUsd': 7537008.005868},
#   {'name': 'XTZ-0930',
#    'underlying': 'XTZ',
#    'description': 'Tezos September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.4799,
#    'bid': 1.4671,
#    'ask': 1.4771,
#    'index': 1.4751252952333334,
#    'mark': 1.4771,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.4014,
#    'upperBound': 1.5517,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 1.4771,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.019059636073847787,
#    'change24h': 0.012336371736001646,
#    'changeBod': 0.002919608908202064,
#    'volumeUsd24h': 3607.2822508,
#    'volume': 2436.654,
#    'openInterest': 652363.498,
#    'openInterestUsd': 963606.1228958},
#   {'name': 'XTZ-1230',
#    'underlying': 'XTZ',
#    'description': 'Tezos December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 1.5012,
#    'bid': 1.4487,
#    'ask': 1.4616,
#    'index': 1.4751252952333334,
#    'mark': 1.459,
#    'imfFactor': 0.0003,
#    'lowerBound': 1.3867,
#    'upperBound': 1.5488,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 1.459,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.02264201500535906,
#    'change24h': 0.020636586218957677,
#    'changeBod': 0.00933932895191975,
#    'volumeUsd24h': 300.0012447,
#    'volume': 201.81,
#    'openInterest': 266449.998,
#    'openInterestUsd': 388750.547082},
#   {'name': 'YFI-PERP',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8350.0,
#    'bid': 8345.0,
#    'ask': 8355.0,
#    'index': 8358.123,
#    'mark': 8345.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 7935.0,
#    'upperBound': 8775.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 8345.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 50.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.03693017888055395,
#    'change24h': 0.018303843807199512,
#    'changeBod': 0.0024024024024024023,
#    'volumeUsd24h': 7689957.37,
#    'volume': 895.662,
#    'openInterest': 927.193,
#    'openInterestUsd': 7737425.585},
#   {'name': 'YFI-0930',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8270.0,
#    'bid': 8325.0,
#    'ask': 8410.0,
#    'index': 8358.123,
#    'mark': 8320.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 7920.0,
#    'upperBound': 8775.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 8320.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.03536231884057971,
#    'change24h': 0.010935601458080195,
#    'changeBod': 0.0012033694344163659,
#    'volumeUsd24h': 33.08,
#    'volume': 0.004,
#    'openInterest': 27.709,
#    'openInterestUsd': 230538.88},
#   {'name': 'YFI-1230',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 8530.0,
#    'bid': 8245.0,
#    'ask': 8410.0,
#    'index': 8358.123,
#    'mark': 8410.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 7945.0,
#    'upperBound': 8785.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 8410.0,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 100.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.02605674580196873,
#    'change24h': 0.03126916002452483,
#    'changeBod': 0.023114355231143552,
#    'volumeUsd24h': 798.225,
#    'volume': 0.093,
#    'openInterest': 5.949,
#    'openInterestUsd': 50031.09},
#   {'name': 'YFII-PERP',
#    'underlying': 'YFII',
#    'description': 'DFI.Money Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.25,
#    'sizeIncrement': 0.001,
#    'last': 878.75,
#    'bid': 877.75,
#    'ask': 878.5,
#    'index': 877.7177307033334,
#    'mark': 877.75,
#    'imfFactor': 0.025,
#    'lowerBound': 834.0,
#    'upperBound': 922.5,
#    'underlyingDescription': 'DFI.Money',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 877.75,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.016526610644257703,
#    'change24h': 0.00948821161587119,
#    'changeBod': -0.0034061879080329264,
#    'volumeUsd24h': 1373680.60075,
#    'volume': 1546.389,
#    'openInterest': 2160.584,
#    'openInterestUsd': 1896452.606},
#   {'name': 'ZEC-PERP',
#    'underlying': 'ZEC',
#    'description': 'Zcash Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.05,
#    'last': 58.12,
#    'bid': 58.16,
#    'ask': 58.18,
#    'index': 58.14945566666667,
#    'mark': 58.09,
#    'imfFactor': 0.001,
#    'lowerBound': 55.25,
#    'upperBound': 61.06,
#    'underlyingDescription': 'Zcash',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 58.09,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 3.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.025662529352566254,
#    'change24h': 0.001724435247456458,
#    'changeBod': -0.011738686628104797,
#    'volumeUsd24h': 3128434.1905,
#    'volume': 52551.75,
#    'openInterest': 61810.35,
#    'openInterestUsd': 3590563.2315},
#   {'name': 'ZIL-PERP',
#    'underlying': 'ZIL',
#    'description': 'Zilliqa Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 10.0,
#    'last': 0.03163,
#    'bid': 0.0316,
#    'ask': 0.03162,
#    'index': 0.0315741756,
#    'mark': 0.03157,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.03,
#    'upperBound': 0.03315,
#    'underlyingDescription': 'Zilliqa',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.03157,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.02471424158171146,
#    'change24h': 0.005093919134033747,
#    'changeBod': -0.00785669390320553,
#    'volumeUsd24h': 1280091.323,
#    'volume': 39720060.0,
#    'openInterest': 120113540.0,
#    'openInterestUsd': 3791984.4578},
#   {'name': 'ZM-0930',
#    'underlying': 'ZM',
#    'description': 'Zoom September 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-09-30T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.005,
#    'last': 75.0,
#    'bid': 73.2,
#    'ask': 73.55,
#    'index': 73.31,
#    'mark': 73.5,
#    'imfFactor': 0.002,
#    'lowerBound': 69.65,
#    'upperBound': 77.25,
#    'underlyingDescription': 'Zoom',
#    'expiryDescription': 'September 2022',
#    'moveStart': None,
#    'marginPrice': 73.5,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.018036072144288578,
#    'change24h': -0.008097165991902834,
#    'changeBod': -0.0040650406504065045,
#    'volumeUsd24h': 263.3125,
#    'volume': 3.5,
#    'openInterest': 1118.025,
#    'openInterestUsd': 82174.8375},
#   {'name': 'ZM-1230',
#    'underlying': 'ZM',
#    'description': 'Zoom December 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-12-30T21:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.005,
#    'last': 75.25,
#    'bid': 73.25,
#    'ask': 73.6,
#    'index': 73.31,
#    'mark': 73.8,
#    'imfFactor': 0.002,
#    'lowerBound': 69.65,
#    'upperBound': 77.25,
#    'underlyingDescription': 'Zoom',
#    'expiryDescription': 'December 2022',
#    'moveStart': None,
#    'marginPrice': 73.8,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'closeOnly': False,
#    'change1h': -0.016,
#    'change24h': -0.004720161834120027,
#    'changeBod': 0.0,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 0.0,
#    'openInterestUsd': 0.0},
#   {'name': 'ZRX-PERP',
#    'underlying': 'ZRX',
#    'description': '0x Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.00025,
#    'sizeIncrement': 1.0,
#    'last': 0.27,
#    'bid': 0.26975,
#    'ask': 0.27025,
#    'index': 0.27003366333333334,
#    'mark': 0.26975,
#    'imfFactor': 0.0003,
#    'lowerBound': 0.25675,
#    'upperBound': 0.2835,
#    'underlyingDescription': '0x',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.26975,
#    'imfWeight': 1.0,
#    'mmfWeight': 1.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'closeOnly': False,
#    'change1h': -0.019981834695731154,
#    'change24h': 0.023719165085388995,
#    'changeBod': 0.007469654528478058,
#    'volumeUsd24h': 864940.7915,
#    'volume': 3151613.0,
#    'openInterest': 4276173.0,
#    'openInterestUsd': 1153497.66675}]}

# %%
df = pd.DataFrame(res['result'])
df.head()
# Out:
#          name underlying                         description       type  \
# 0  1INCH-PERP      1INCH       1INCH Token Perpetual Futures  perpetual
# 1  1INCH-0930      1INCH  1INCH Token September 2022 Futures     future
# 2  1INCH-1230      1INCH   1INCH Token December 2022 Futures     future
# 3   AAPL-0930       AAPL        Apple September 2022 Futures     future
# 4   AAPL-1230       AAPL         Apple December 2022 Futures     future
#
#                       expiry  perpetual  expired  enabled  postOnly  \
# 0                       None       True    False     True     False
# 1  2022-09-30T03:00:00+00:00      False    False     True     False
# 2  2022-12-30T03:00:00+00:00      False    False     True     False
# 3  2022-09-30T20:00:00+00:00      False    False     True     False
# 4  2022-12-30T21:00:00+00:00      False    False     True     False
#
#    priceIncrement  ...      group  closeOnly  change1h  change24h  changeBod  \
# 0          0.0001  ...  perpetual      False -0.017751   0.005144   0.001441
# 1          0.0001  ...  quarterly      False -0.012344   0.009381   0.006775
# 2          0.0001  ...  quarterly      False -0.011828   0.010270   0.007100
# 3          0.0100  ...  quarterly      False -0.010362  -0.000331  -0.002446
# 4          0.0100  ...  quarterly      False -0.010199  -0.001990  -0.004566
#
#    volumeUsd24h      volume  openInterest  openInterestUsd indexAdjustment
# 0  4.820314e+06  7595719.00    8303163.00     5.191968e+06             NaN
# 1  8.855529e+03    14056.00     116320.00     7.259531e+04             NaN
# 2  3.271670e+02      532.00      21391.00     1.304637e+04             NaN
# 3  1.469312e+04       96.10       8659.12     1.306661e+06             NaN
# 4  6.867541e+04      450.47        789.21     1.187130e+05             NaN
#
# [5 rows x 36 columns]

# %%
df = pd.DataFrame(res['result'])
# Using iloc to make it readable
df.iloc[:,:4].head()
# Out:
#          name underlying                         description       type
# 0  1INCH-PERP      1INCH       1INCH Token Perpetual Futures  perpetual
# 1  1INCH-0930      1INCH  1INCH Token September 2022 Futures     future
# 2  1INCH-1230      1INCH   1INCH Token December 2022 Futures     future
# 3   AAPL-0930       AAPL        Apple September 2022 Futures     future
# 4   AAPL-1230       AAPL         Apple December 2022 Futures     future

# %% [markdown]
# ## 8. The Bottom Line

# %% [markdown]
# > FTX and its U.S. counterpart FTX.US are two of the best exchanges in the crypto space. If you’re interested in algo trading or simply looking for a great data source, FTX has an easy-to-use REST API to get you what you need.
